# %%
import json

# %%
with open('workflow_asset/tag_set_example.json', 'r') as f:
    c = json.loads(f.read())

# %%
tags = [k for k, v in c.items() if v > 1]
len(tags)
# Out:
# 156

# %%
tags
# Out:
# ['薄荷口味',
#  '套餐',
#  '茶',
#  '無糖',
#  '500ml',
#  '辣椒',
#  '醬油',
#  '台灣味',
#  '草莓',
#  '零食',
#  '牛肉',
#  '小包裝',
#  '巧克力',
#  '300g',
#  '家福',
#  '盒裝',
#  '品牌',
#  '起司',
#  '調味料',
#  '牛奶',
#  '信用卡',
#  '卡片',
#  '金融',
#  '可愛',
#  '咖啡',
#  '咖啡因',
#  '薄荷',
#  '綠茶',
#  '口感',
#  '兒童',
#  '黑色',
#  '美味',
#  '果汁',
#  '水果味',
#  '手機殼',
#  '義大利',
#  '甜品',
#  '包裝',
#  '美食',
#  '黑巧克力',
#  '獅王',
#  '紅茶',
#  '按摩',
#  '支付',
#  '2023-05-10',
#  '玉米',
#  '小說',
#  '韓系',
#  '簡約',
#  '冰淇淋',
#  '益生菌',
#  '汽車配件',
#  '電子書',
#  '250ml',
#  '日本',
#  '光泉',
#  '原味',
#  '食品',
#  '韓式',
#  '免運',
#  '奶油',
#  '蘋果',
#  '蔬菜',
#  '健康飲食',
#  '葡萄',
#  '有機',
#  '飲品',
#  '可可',
#  '口罩',
#  '活性碳',
#  '可可粉',
#  '蕃茄醬',
#  '女款',
#  '甜點',
#  '隱形眼鏡',
#  '花生',
#  '薄荷味',
#  '蘋果口味',
#  '500毫升',
#  '蛋白質',
#  '糖果',
#  '蠟筆小新',
#  '醋',
#  '不鏽鋼',
#  '修護',
#  '拿鐵',
#  '糕點',
#  '韓國',
#  '海鮮',
#  '肉泥',
#  'CIAO',
#  '辣味',
#  '辣椒醬',
#  '保濕',
#  '玻尿酸',
#  '蜂蜜',
#  '大包裝',
#  '護膚品',
#  '池上',
#  '白蘭地',
#  '瓶裝',
#  '炸雞',
#  '書籍',
#  '內褲',
#  '寬松',
#  '焦糖',
#  '醬料',
#  '夾心',
#  '蛋糕',
#  '麻辣',
#  '麥片',
#  '3M',
#  '醫用',
#  '優惠',
#  '便當',
#  '五香',
#  '超薄',
#  '柔濕巾',
#  '口味',
#  '收納',
#  '襪子',
#  '果醬',
#  '控油',
#  '濃縮',
#  '香蕉',
#  '外送員小費',
#  '烏龍茶',
#  '美容',
#  '香辣',
#  '川味麻辣火鍋底料',
#  '川味火鍋料理',
#  '川味麻辣滷肉',
#  '川味麻辣底料',
#  '川味火鍋底料',
#  '川味麻辣火鍋料',
#  '川味麻辣火鍋底',
#  '川味火鍋底料理',
#  '川味麻辣滷肉底料',
#  '川味麻辣底',
#  '川味麻辣火鍋底料理',
#  '川味麻辣滷肉底',
#  '川味麻辣料理',
#  '川味麻辣滷肉料理',
#  '清爽',
#  '酸甜',
#  '泡麵',
#  '速食',
#  '酸辣',
#  '冷麵',
#  '香料',
#  '台灣',
#  '面膜',
#  '現貨',
#  '香草',
#  '水果',
#  '預約單']

# %%
import openai

# %%
with open('api.key', 'r') as f:
    api_key = f.read().replace('\n', '')

# %%
import re
import json
import time


class GPTGenerater:
    
    def __init__(self, api_key, model="gpt-3.5-turbo", temperature=0.0):
        self.api_key = api_key
        openai.api_key = self.api_key
        self.model = model
        self.temperature = temperature
        
    def predict(self, prompt):
        response = openai.ChatCompletion.create(
            model=self.model,
            messages=[{"role": "assistant", "content": prompt}],
            temperature=self.temperature,
        )
        return response
    
    

JSON_RE = re.compile(r'(\{.*\})')

class JsonExtract:
    
    def reply2result(self, reply: str) -> dict:

        json_str = JSON_RE.findall(reply.replace('\n', ' '))[0]
        ret = json.loads(json_str)
        return ret

    def result2products(self, result: dict, target_key='tags') -> list[str]:
        assert target_key in result
        assert isinstance(result[target_key], list)

        ret = result[target_key]

        return ret

    def reply2products(self, reply:str) -> list[str]:
        
        result = self.reply2result(reply)
        ret = self.result2products(result)


        return ret

# %%
sample_generator = GPTGenerater(api_key)

# %%
instruction = '''
Select tags to the product as "tags", out from valid set.

product: {product}
valid set: {valid_tags}

1. Return the results in JSON format with the following key: "tags".
2. Do not repeat answers.
3. Reply in Taiwan Chinese.
4. Please avoid choosing duplicate tags.
5. Your number of tags shall be no more than {max_tags}.
6. Do not apply when tag is not fit. Tags can also be empty.
7. The tags returned must strongly fit to {product}

The json result is: 
'''


class SampleAugumentation(JsonExtract):
    
    def __init__(self, sample_generator, instruction):
        self.sample_generator = sample_generator
        self.instruction = instruction
        
    def _sample_generate(self, product:str, valid_tags:list, max_tags:int=10, debug=False):
        

        prompt = self.instruction.format(product=product, valid_tags=valid_tags, max_tags=max_tags)
        response = self.sample_generator.predict(prompt)
        
        content = response.to_dict()['choices'][0]['message']['content']
        
        ret = self.reply2result(content)
        
        # print(ret['tags'])
        ret['tags'] = list(filter(lambda x: x in c, ret['tags']))
        
        return ret
    
    def sample_generate(self, product:str, valid_tags:list, max_tags:int=10):
        debug = False
        while True:
            try:
                return self._sample_generate(product=product, valid_tags=valid_tags, max_tags=max_tags, debug=debug)
            except Exception as e:
                debug = True
                print(e)
                time.sleep(1)

# %%
sa = SampleAugumentation(sample_generator, instruction)

# %%
product = '統一精品手沖咖啡'
sa._sample_generate(product=product, valid_tags=tags, max_tags=4)
# Out:
# {'tags': ['咖啡']}

# %%
import pandas as pd
df = pd.read_csv('data/samples.csv', index_col=0)
df = df[df['item_name'].apply(lambda x: '外送費' not in x)]
df = df[df['item_name'].apply(lambda x: '平台費' not in x)]

# %%
for i in df['item_name'].sample(100):
    print(i)
    print(sa._sample_generate(product=i, valid_tags=tags, max_tags=4))
# Out:
# 【113F 03006007】車用液化石油氣
# {'tags': ['汽車配件']}
# 捷康人氣紅燒牛肉麵/包(680G/包)【愛買冷凍】
# {'tags': ['牛肉', '冷凍']}
# 炎記韓式腐乳杏鮑菇(葷食)
# {'tags': ['韓式']}
# 送好禮 怡寶角落小夥伴超輕量護脊書包 IMSG601PK
# {'tags': []}
# 4573449105941【bande】日本貼紙型和紙膠帶
# {'tags': ['日本']}
# 料都亭九州醬油洋芋片
# {'tags': ['零食', '洋芋片', '醬油']}
# 💥【 LED 銅線燈 】台灣現貨 燈串 艾妮EasyPar
# {'tags': ['台灣現貨']}
# 大容量旅行包 50克DOOOG 杜格無榖貓糧 田園什錦 杜革
# {'tags': []}
# 2023052174097375210
# {'tags': ['茶', '零食', '包裝', '食品']}
# 【mamaway 媽媽餵】竹炭全彈力按摩束腹帶
# {'tags': ['按摩']}
# PowerRider L5 USB語音聲控變色燈 白色
# {'tags': ['白色']}
# 花生牛肉堡單人豪華餐  2023-05-07 e4pf-5v
# {'tags': ['套餐', '牛肉', '美食', '包裝']}
# 【CS22】3D立體可拆洗車用記憶棉頸靠枕(汽車靠枕)
# {'tags': ['汽車配件', '立體']}
# 【TP-Link】Deco X95 AX7800 三頻 AI
# {'tags': []}
# 榛果風味那堤 2023-05-13 y9i0-6kyx
# {'tags': ['咖啡', '榛果']}
# 【喜番屋】真皮頭層油蠟牛皮3隔層口金包零錢包【LH941】
# {'tags': []}
# 【歐奇斯】95%有機狗飼料-幼犬-4LB/1.81KG
# {'tags': ['有機']}
# 🔥正品現貨出清🔥 Real Techniques 美妝蛋
# {'tags': ['現貨']}
# 氧視加 去蛋白雙氧藥水 適合各種軟、硬式隱形眼鏡 無防腐劑
# {'tags': ['隱形眼鏡']}
# 雙桔紅茶
# {'tags': ['茶', '無糖', '果汁', '水果味']}
# X-FREE 700*18/25C【A/V】美嘴 48mm
# {'tags': []}
# 60秒速效精華水面膜
# {'tags': ['面膜', '現貨', '預約單', '水果']}
# TN5230518006402
# {'tags': ['茶', '無糖', '500ml', '包裝']}
# PHILIPS飛利浦 Sonicare 智能牙菌斑清除刷頭(
# {'tags': ['飛利浦']}
# X8JHAV5
# {'tags': ['茶', '無糖', '500ml', '台灣味']}
# 9ZTGNFQ
# {'tags': ['茶', '無糖', '500ml', '品牌']}
# 9789869798976季辛吉 1923-1968
# {'tags': ['小說', '台灣', '現貨']}
# 康寶鮮味炒手原
# {'tags': ['食品', '速食', '泡麵', '台灣']}
# 請提供四人份的餐
# {'tags': ['套餐', '家福', '美食', '食品']}
# 多功能透明量杯【小麥購物】24H出貨台灣現貨【G471】量杯
# {'tags': ['小麥購物']}
# 【ESTEE LAUDER雅詩蘭黛】 特潤超導全方位修護露
# {'tags': ['護膚品', '保濕', '修護', '美容']}
# 福樂低脂優酪-蔓越莓  100g*2入/組[100g*2入]
# {'tags': ['乳製品', '蔓越莓']}
# REEBOK男運動鞋
# {'tags': ['運動鞋']}
# 洛神梅子茶
# {'tags': ['茶', '無糖', '果汁', '水果味']}
# 2023050566519805310
# {'tags': ['茶', '零食', '牛肉', '巧克力']}
# 新品【正隆3C】全螢幕鏡頭保護貼 鋼化玻璃貼 鏡頭貼 適用i
# {'tags': []}
# 四角氣囊防摔防摔殼 適用iPhone 14 13 12 11
# {'tags': ['手機殼', '防摔殼']}
# 朝食鬆餅（其祥） 4入/140g
# {'tags': ['甜點', '小包裝']}
# 威拂超保水濕拖巾清新花香
# {'tags': ['清新', '保濕', '花香']}
# 加點-濃湯(小)$35
# {'tags': ['小包裝', '美食', '台灣味']}
# 澳洲冷藏和牛黃瓜條
# {'tags': ['牛肉', '零食', '澳洲', '冷藏']}
# 植物物語一般性100g
# {'tags': ['茶', '無糖', '小包裝', '美食']}
# 138118003359
# {'tags': ['茶', '無糖', '500ml', '包裝']}
# 楓康食品用PE保鮮膜40
# {'tags': ['食品', '包裝', '家庭']}
# 《盛香珍》典藏雙味威化捲禮盒(2罐入) 800g/盒
# {'tags': ['零食']}
# @豆乳美肌超微細保濕噴霧
# {'tags': ['保濕', '噴霧']}
# 女防蚊褲 棉綢夏天大人沙灘褲 薄款燈籠褲 人造棉花褲 睡褲
# {'tags': ['女款']}
# 台灣現貨免運🔥 蕾絲超薄大碼調整型內衣 告別外擴 大尺碼
# {'tags': ['內衣', '大碼']}
# Armarpot鐵鍋 28cm【深平底鍋套組】 原價1900
# {'tags': ['廚具']}
# "🔥 台灣熱賣 🔥超大超厚""牛津佈衣物棉被子防水收納袋防潮 "
# {'tags': ['收納', '防水']}
# 一王美-透氣涼爽少女胸衣-165
# {'tags': ['少女', '透氣']}
# 【OOHA】氣泡飲 柚子海鹽 寶特瓶500ml x4入/組
# {'tags': []}
# 夾式耳環造型4055
# {'tags': ['造型']}
# TR3230517003699
# {'tags': ['茶', '無糖', '500ml', '盒裝']}
# 銀欣科技 桌上型單螢幕支架「ARM12B」
# {'tags': ['桌上型']}
# SN351(黑)史努比抗菌除臭帽子襪套
# {'tags': ['黑色']}
# *限時優惠*KINYO DS-6591 LED藍牙健康管理體
# {'tags': ['健康飲食']}
# 台灣有機杏鮑菇150g+-5%/包[150g+-5%/包]
# {'tags': ['有機', '蔬菜', '食品']}
# M:436674739
# {'tags': ['茶', '無糖', '500ml', '台灣味']}
# 【日本Bmxmao】MAO Clean M7 電動濕拖地刷專
# {'tags': ['日本']}
# 日本 梭殼 工業用平車梭殼 梭殼 新輝針車有限公司
# {'tags': ['日本']}
# vivo Y16 (4G/64G) -流光金
# {'tags': ['手機殼', '金融', '美食', '活性碳']}
# 467668044
# {'tags': ['茶', '零食', '牛肉', '巧克力']}
# 6吋重乳酪蛋糕[200g+-9%/盒]
# {'tags': ['蛋糕', '200g']}
# 《青溪無線》MTS 98WAT / VU68T 電池卡榫 主
# {'tags': []}
# 9789862485064100Nippon
# {'tags': ['日本', '食品', '茶', '無糖']}
# 特斯拉 TESLA 後車廂掛鉤 掛勾 行李箱掛勾 特斯拉Y
# {'tags': ['汽車配件']}
# M:492745211
# {'tags': ['茶', '無糖', '500ml', '盒裝']}
# WINMAX 馬卡龍指甲油10ml薰衣草
# {'tags': []}
# 開票手續費(湯姆貝貝親子樂園-台中文心店)
# {'tags': []}
# 《杜達女孩》秋裝 氣質鏤空海馬毛長版開衫針織外套 防曬罩衫外
# {'tags': []}
# 【逸嵐】－蔥香油雞胸翅／600g／滿1800免運／油雞胸／油
# {'tags': []}
# 純手工蚵仔麵線 零秤賣 600公克 手工紅麵線 手工麵線 麵
# {'tags': ['麵']}
# Lumina竹炭珍珠紋洗臉巾60抽
# {'tags': []}
# 【adidas官方旗艦館】運動外套 男/女(IA8167)
# {'tags': ['女款']}
# 日本名湯溫泉粉(溫泉通)
# {'tags': ['日本']}
# 頂呱呱口袋披薩
# {'tags': ['口感', '美食', '包裝', '預約單']}
# 2023052877730388510
# {'tags': ['茶', '零食', '牛肉', '巧克力']}
# R5K34O2
# {'tags': ['茶', '無糖', '500ml', '台灣味']}
# 【Farcent香水】璀璨名媛室內擴香-同名花語/真我星夜/
# {'tags': ['香水']}
# 代收代付 - 【2件$49】罐裝基本款彈力皮筋(1000條入
# {'tags': ['罐裝']}
# ★溜溜球 現貨《木製溜溜球】3款任選 YOYO木質悠悠球 ♥
# {'tags': ['玩具', '木製']}
# 樺達硬喉糖條糖(甘草金桔) 10s
# {'tags': ['零食', '口感', '甜點', '糖果']}
# 9789865077778新手種花100問【暢
# {'tags': ['書籍']}
# Ref:PHT23032513270
# {'tags': ['茶', '無糖', '500ml', '盒裝']}
# 🐈夜貓子寵物舖🐈日本 QQ KIT 環保紙紙砂-活性碳/
# {'tags': ['寵物', '日本']}
# 【米樂銀川】有機在來米粉600g
# {'tags': ['有機', '米粉']}
# 義美傳統豆奶無加糖2L
# {'tags': ['無糖', '牛奶', '飲品', '健康飲食']}
# 洗衣機 防震墊 防滑墊 止滑墊【小麥購物】24H出貨 墊片
# {'tags': []}
# 露得清超能亮修護安瓶面膜9片組
# {'tags': ['面膜', '修護', '保濕', '現貨']}
# JUUUAFX
# {'tags': ['薄荷口味', '茶', '無糖', '500ml']}
# _11樓之三(安心送
# {'tags': ['套餐', '茶', '無糖', '小包裝']}
# KEY COFFEE 香濃即溶咖啡 (100g)
# {'tags': ['咖啡']}
# 台南大員皇冠假日酒店-煉‧瓦日式餐廳兌換券
# {'tags': ['餐廳']}
# 尚朋堂商用型電烤箱15L[SO-915LG/1200W]
# {'tags': []}
# 🏆蝦皮冠軍/最便宜🏆極速出貨🍎蘋果手錶專用 ‼️ 1～
# {'tags': []}
# armoire✨ʙʟᴜᴇ ᴛᴏɴᴇ🌐夏天一定要有的淺色褲｜
# {'tags': ['時尚']}
# 卡樂芙優質染髮霜巧克力棕
# {'tags': []}
# BEAUTE DE COCO 燃燒機 阻斷機 排空機 【醫妝
# {'tags': ['美容', '護膚品', '醫用', '預約單']}
# 【Alberta】溶解鞋 4cm休閒鞋 韓風百搭簡約 皮革厚
# {'tags': []}
