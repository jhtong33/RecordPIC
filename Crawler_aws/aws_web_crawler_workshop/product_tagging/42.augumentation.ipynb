# %%
! pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (2.29.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (1.9.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.8

# %%
import json

# %%
with open('workflow_asset/catogory.json', 'r') as f:
    config = json.loads(f.read())

# %%
import openai

# %%
with open('api.key', 'r') as f:
    api_key = f.read().replace('\n', '')

# %%
import re
import json


class GPTGenerater:
    
    def __init__(self, api_key, model="gpt-3.5-turbo", temperature=0.7):
        self.api_key = api_key
        openai.api_key = self.api_key
        self.model = model
        self.temperature = temperature
        
    def predict(self, prompt):
        response = openai.ChatCompletion.create(
            model=self.model,
            messages=[{"role": "assistant", "content": prompt}],
            temperature=self.temperature,
        )
        return response
    
    

JSON_RE = re.compile(r'(\{.*\})')

class JsonExtract:
    
    def reply2result(self, reply: str) -> dict:

        json_str = JSON_RE.findall(reply.replace('\n', ' '))[0]
        ret = json.loads(json_str)
        return ret

    def result2products(self, result: dict, target_key='product_name') -> list[str]:
        assert target_key in result
        assert isinstance(result[target_key], list)

        ret = result[target_key]

        return ret

    def reply2products(self, reply:str) -> list[str]:
        
        result = self.reply2result(reply)
        ret = self.result2products(result)


        return ret

# %%
sample_generator = GPTGenerater(api_key)

# %%
sample_generator.predict('hello')
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7lfHYtYMDjjHirEoYWTvfQXLnNFwv at 0x7f42d8301b20> JSON: {
#   "id": "chatcmpl-7lfHYtYMDjjHirEoYWTvfQXLnNFwv",
#   "object": "chat.completion",
#   "created": 1691594460,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! How can I assist you today?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 8,
#     "completion_tokens": 9,
#     "total_tokens": 17
#   }
# }

# %%
instruction = '''
Please generate {n_samples} product names for {category} category.
1. Return the results in JSON format with the following key: "product_name".
2. Example product_name: {samples} .
3. Do not repeat inputs in the output.
4. Replied answer should be as diverse as possible.
5. Do not repeat answers.
6. Reply in Taiwan Chinese.

The json result is: 
'''


class SampleAugumentation(JsonExtract):
    
    def __init__(self, sample_generator, instruction):
        self.sample_generator = sample_generator
        self.instruction = instruction
        
    def _sample_generate(self, category:str, samples:list, n_samples:int=10, debug=False):
        
        n_provided_samples = len(samples)
        
        samples = list(map(lambda x: '"{}",'.format(x.replace('"', '')), samples))
        samples = ' '.join(samples)
        
        prompt = self.instruction.format(category=category, samples=samples, n_samples=n_samples+n_provided_samples)
        response = self.sample_generator.predict(prompt)
        
        content = response.to_dict()['choices'][0]['message']['content']
        
        complete = prompt+content
        
        print('[debug]', 'prompt', prompt)
        print('[debug]', 'content', content)
        
        ret = self.reply2products(complete)[n_provided_samples:]
        
        return ret
    
    def sample_generate(self, category:str, samples:list, n_samples:int=10):
        debug = False
        while True:
            try:
                return self._sample_generate(category=category, samples=samples, n_samples=n_samples, debug=debug)
            except Exception as e:
                debug = True
                print(e)

# %%
sa = SampleAugumentation(sample_generator, instruction)

# %%
n_samples = 11
generated = dict()
for k, v in config.items():
    gen_samples = sa.sample_generate(category=k, samples=v, n_samples=n_samples)
    generated[k] = gen_samples
    
    print(k)
    print(v)
    print(gen_samples)
    
    print('----------')
# Out:
# [debug] prompt
# Please generate 11 product names for 現做咖啡飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "手工拿鐵",
#     "濃縮美式咖啡",
#     "特調卡布奇諾",
#     "覆盆子摩卡",
#     "香草拿鐵",
#     "焦糖瑪奇朵",
#     "冰滴咖啡",
#     "抹茶拿鐵",
#     "薰衣草拿鐵",
#     "巧克力瑪奇朵",
#     "檸檬莓果茶"
#   ]
# }
# 現做咖啡飲品
# []
# ['手工拿鐵', '濃縮美式咖啡', '特調卡布奇諾', '覆盆子摩卡', '香草拿鐵', '焦糖瑪奇朵', '冰滴咖啡', '抹茶拿鐵', '薰衣草拿鐵', '巧克力瑪奇朵', '檸檬莓果茶']
# ----------
# [debug] prompt
# Please generate 11 product names for 罐裝/瓶裝咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "咖啡豆濃縮飲品",
#     "經典黑咖啡",
#     "特濃拿鐵咖啡",
#     "焦糖香草拿鐵",
#     "冰滴咖啡",
#     "瑞士巧克力咖啡",
#     "蜂蜜拿鐵咖啡",
#     "摩卡咖啡",
#     "抹茶拿鐵咖啡",
#     "焦糖瑪奇朵",
#     "香草拿鐵咖啡"
#   ]
# }
# 罐裝/瓶裝咖啡
# []
# ['咖啡豆濃縮飲品', '經典黑咖啡', '特濃拿鐵咖啡', '焦糖香草拿鐵', '冰滴咖啡', '瑞士巧克力咖啡', '蜂蜜拿鐵咖啡', '摩卡咖啡', '抹茶拿鐵咖啡', '焦糖瑪奇朵', '香草拿鐵咖啡']
# ----------
# [debug] prompt
# Please generate 11 product names for 沖泡式咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "風味烘焙咖啡",
#     "特選阿拉比卡咖啡",
#     "醇香摩卡咖啡",
#     "特濃拿鐵咖啡",
#     "經典美式咖啡",
#     "香醇卡布奇諾咖啡",
#     "濃郁黑咖啡",
#     "香甜焦糖拿鐵咖啡",
#     "清新冰咖啡",
#     "純正義式咖啡",
#     "香醇拿鐵咖啡"
#   ]
# }
# 沖泡式咖啡
# []
# ['風味烘焙咖啡', '特選阿拉比卡咖啡', '醇香摩卡咖啡', '特濃拿鐵咖啡', '經典美式咖啡', '香醇卡布奇諾咖啡', '濃郁黑咖啡', '香甜焦糖拿鐵咖啡', '清新冰咖啡', '純正義式咖啡', '香醇拿鐵咖啡']
# ----------
# [debug] prompt
# Please generate 11 product names for 濾掛式咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "濾掛式咖啡",
#     "細砂金濾掛式咖啡",
#     "特選焦糖濾掛式咖啡",
#     "經典黑濾掛式咖啡",
#     "馥鬱香濾掛式咖啡",
#     "榛果風味濾掛式咖啡",
#     "藍山咖啡濾掛式咖啡",
#     "摩卡咖啡濾掛式咖啡",
#     "卡布奇諾濾掛式咖啡",
#     "拿鐵濾掛式咖啡",
#     "綠茶拿鐵濾掛式咖啡"
#   ]
# }
# 濾掛式咖啡
# []
# ['濾掛式咖啡', '細砂金濾掛式咖啡', '特選焦糖濾掛式咖啡', '經典黑濾掛式咖啡', '馥鬱香濾掛式咖啡', '榛果風味濾掛式咖啡', '藍山咖啡濾掛式咖啡', '摩卡咖啡濾掛式咖啡', '卡布奇諾濾掛式咖啡', '拿鐵濾掛式咖啡', '綠茶拿鐵濾掛式咖啡']
# ----------
# [debug] prompt
# Please generate 11 product names for 即溶咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "怡口蓮香咖啡",
#     "濃香即溶咖啡",
#     "經典黑咖啡",
#     "純正義式咖啡",
#     "香醇拿鐵咖啡",
#     "濃郁摩卡咖啡",
#     "甜蜜卡布奇諾",
#     "馥郁印度風味咖啡",
#     "瑞士巧克力咖啡",
#     "香醇焦糖咖啡",
#     "特濃維也納咖啡"
#   ]
# }
# 即溶咖啡
# []
# ['怡口蓮香咖啡', '濃香即溶咖啡', '經典黑咖啡', '純正義式咖啡', '香醇拿鐵咖啡', '濃郁摩卡咖啡', '甜蜜卡布奇諾', '馥郁印度風味咖啡', '瑞士巧克力咖啡', '香醇焦糖咖啡', '特濃維也納咖啡']
# ----------
# [debug] prompt
# Please generate 11 product names for 咖啡相關食用品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "咖啡杯套",
#     "咖啡濾紙",
#     "咖啡渣肥料",
#     "咖啡杯墊",
#     "咖啡杯蓋",
#     "咖啡機清潔劑",
#     "咖啡壺",
#     "咖啡粉罐",
#     "咖啡手沖壺",
#     "咖啡機水濾芯",
#     "咖啡機磨豆機"
#   ]
# }
# 咖啡相關食用品
# []
# ['咖啡杯套', '咖啡濾紙', '咖啡渣肥料', '咖啡杯墊', '咖啡杯蓋', '咖啡機清潔劑', '咖啡壺', '咖啡粉罐', '咖啡手沖壺', '咖啡機水濾芯', '咖啡機磨豆機']
# ----------
# [debug] prompt
# Please generate 11 product names for 現做茶飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "手工珍珠奶茶",
#     "烏龍奶茶",
#     "鮮果茶",
#     "招牌奶茶",
#     "甘蔗青茶",
#     "鮮奶綠茶",
#     "紅茶拿鐵",
#     "水果綠茶",
#     "烏龍拿鐵",
#     "草莓果茶",
#     "珍珠紅茶"
#   ]
# }
# 現做茶飲品
# []
# ['手工珍珠奶茶', '烏龍奶茶', '鮮果茶', '招牌奶茶', '甘蔗青茶', '鮮奶綠茶', '紅茶拿鐵', '水果綠茶', '烏龍拿鐵', '草莓果茶', '珍珠紅茶']
# ----------
# [debug] prompt
# Please generate 11 product names for 茶飲 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "檸檬茶",
#     "綠茶",
#     "奶茶",
#     "水果茶",
#     "冰淇淋茶",
#     "珍珠奶茶",
#     "椰果茶",
#     "薑母茶",
#     "花草茶",
#     "黑糖鮮奶",
#     "冰滴咖啡"
#   ]
# }
# 茶飲
# []
# ['檸檬茶', '綠茶', '奶茶', '水果茶', '冰淇淋茶', '珍珠奶茶', '椰果茶', '薑母茶', '花草茶', '黑糖鮮奶', '冰滴咖啡']
# ----------
# [debug] prompt
# Please generate 11 product names for 碳酸/汽水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冰爽碳酸",
#     "果香汽水",
#     "清新苏打水",
#     "绿色气泡",
#     "葡萄汽水",
#     "柠檬碳酸饮料",
#     "草莓碳酸",
#     "橘子汽水",
#     "蓝莓气泡饮料",
#     "苹果碳酸",
#     "桃子汽水"
#   ]
# }
# 碳酸/汽水
# []
# ['冰爽碳酸', '果香汽水', '清新苏打水', '绿色气泡', '葡萄汽水', '柠檬碳酸饮料', '草莓碳酸', '橘子汽水', '蓝莓气泡饮料', '苹果碳酸', '桃子汽水']
# ----------
# [debug] prompt
# Please generate 11 product names for 果汁/果醋飲 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": ["蘋果汁", "橙汁", "葡萄汁", "檸檬汁", "蔓越莓汁", "藍莓汁", "蘆薈汁", "百香果汁", "草莓汁", "木瓜汁", "薑汁"]
# }
# 果汁/果醋飲
# []
# ['蘋果汁', '橙汁', '葡萄汁', '檸檬汁', '蔓越莓汁', '藍莓汁', '蘆薈汁', '百香果汁', '草莓汁', '木瓜汁', '薑汁']
# ----------
# [debug] prompt
# Please generate 11 product names for 運動飲料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_names": [
#     "運動能量飲料",
#     "運動補給飲料",
#     "運動電解飲料",
#     "運動爽快飲料",
#     "運動維他命飲料",
#     "運動蛋白飲料",
#     "運動水分飲料",
#     "運動氨基酸飲料",
#     "運動果汁飲料",
#     "運動功能飲料",
#     "運動藥丸飲料"
#   ]
# }
#
# [debug] prompt
# Please generate 11 product names for 運動飲料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "運動能量飲料",
#     "運動補給飲料",
#     "運動保健飲料",
#     "運動強化飲料",
#     "運動增強飲料",
#     "運動恢復飲料",
#     "運動提神飲料",
#     "運動补充饮料",
#     "運動活力飲料",
#     "運動強身飲料",
#     "運動滋補飲料"
#   ]
# }
# 運動飲料
# []
# ['運動能量飲料', '運動補給飲料', '運動保健飲料', '運動強化飲料', '運動增強飲料', '運動恢復飲料', '運動提神飲料', '運動补充饮料', '運動活力飲料', '運動強身飲料', '運動滋補飲料']
# ----------
# [debug] prompt
# Please generate 11 product names for 養生飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "綠茶蜜香",
#     "冰鎮烏龍",
#     "甘醇奶茶",
#     "蔓越莓果汁",
#     "蘋果西打",
#     "檸檬汁",
#     "蜜桃百香果",
#     "芒果奶昔",
#     "草莓優酪",
#     "柚子冰茶",
#     "薰衣草果茶"
#   ]
# }
# 養生飲品
# []
# ['綠茶蜜香', '冰鎮烏龍', '甘醇奶茶', '蔓越莓果汁', '蘋果西打', '檸檬汁', '蜜桃百香果', '芒果奶昔', '草莓優酪', '柚子冰茶', '薰衣草果茶']
# ----------
# [debug] prompt
# Please generate 11 product names for 能量飲料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "超能量飲料",
#     "極速能量飲料",
#     "無限能量飲料",
#     "強效能量飲料",
#     "絕對能量飲料",
#     "全能能量飲料",
#     "瞬間能量飲料",
#     "極限能量飲料",
#     "無敵能量飲料",
#     "超級能量飲料",
#     "極致能量飲料"
#   ]
# }
# 能量飲料
# []
# ['超能量飲料', '極速能量飲料', '無限能量飲料', '強效能量飲料', '絕對能量飲料', '全能能量飲料', '瞬間能量飲料', '極限能量飲料', '無敵能量飲料', '超級能量飲料', '極致能量飲料']
# ----------
# [debug] prompt
# Please generate 11 product names for 特殊風味飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "檸檬薄荷汁",
#     "草莓巧克力奶昔",
#     "桂花蜂蜜茶",
#     "榴槤冰淇淋奶茶",
#     "玫瑰草莓冰沙",
#     "薑黃奇亞籽飲品",
#     "蘋果檸檬醋",
#     "杏仁花茶",
#     "巧克力薄荷熱飲",
#     "蜂蜜柚子茶",
#     "红豆薏仁奶茶"
#   ]
# }
# 特殊風味飲品
# []
# ['檸檬薄荷汁', '草莓巧克力奶昔', '桂花蜂蜜茶', '榴槤冰淇淋奶茶', '玫瑰草莓冰沙', '薑黃奇亞籽飲品', '蘋果檸檬醋', '杏仁花茶', '巧克力薄荷熱飲', '蜂蜜柚子茶', '红豆薏仁奶茶']
# ----------
# [debug] prompt
# Please generate 11 product names for 沖泡類飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "綠茶",
#     "奶茶",
#     "咖啡",
#     "紅茶",
#     "珍珠奶茶",
#     "蜂蜜綠茶",
#     "山藥奶茶",
#     "奶蓋紅茶",
#     "四季春茶",
#     "白玉青茶",
#     "檸檬紅茶"
#   ]
# }
# 沖泡類飲品
# []
# ['綠茶', '奶茶', '咖啡', '紅茶', '珍珠奶茶', '蜂蜜綠茶', '山藥奶茶', '奶蓋紅茶', '四季春茶', '白玉青茶', '檸檬紅茶']
# ----------
# [debug] prompt
# Please generate 11 product names for 現調果汁 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "鮮榨橙汁",
#     "新鮮壓榨蘋果汁",
#     "現調柚子汁",
#     "新鮮搾取葡萄汁",
#     "純天然檸檬汁",
#     "現調梨汁",
#     "新鮮壓榨葡萄柚汁",
#     "純果橋果汁",
#     "現調西瓜汁",
#     "新鮮榨取菠蘿汁",
#     "純天然葡萄汁"
#   ]
# }
# 現調果汁
# []
# ['鮮榨橙汁', '新鮮壓榨蘋果汁', '現調柚子汁', '新鮮搾取葡萄汁', '純天然檸檬汁', '現調梨汁', '新鮮壓榨葡萄柚汁', '純果橋果汁', '現調西瓜汁', '新鮮榨取菠蘿汁', '純天然葡萄汁']
# ----------
# [debug] prompt
# Please generate 11 product names for 礦泉水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "純淨之泉",
#     "水杉泉",
#     "淨水之星",
#     "天然泉水",
#     "山泉宝",
#     "清爽之泉",
#     "泉源之寶",
#     "湧泉寶",
#     "源泉水",
#     "冰川泉",
#     "水之秘境"
#   ]
# }
# 礦泉水
# []
# ['純淨之泉', '水杉泉', '淨水之星', '天然泉水', '山泉宝', '清爽之泉', '泉源之寶', '湧泉寶', '源泉水', '冰川泉', '水之秘境']
# ----------
# [debug] prompt
# Please generate 11 product names for 氣泡水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "泡泡水",
#     "氣泡飲料",
#     "水泡泡",
#     "氣泡水飲品",
#     "氣泡果汁",
#     "泡沫水",
#     "氣泡果味飲料",
#     "果味泡泡水",
#     "氣泡果汁飲品",
#     "果汁泡泡水",
#     "氣泡飲品"
#   ]
# }
# 氣泡水
# []
# ['泡泡水', '氣泡飲料', '水泡泡', '氣泡水飲品', '氣泡果汁', '泡沫水', '氣泡果味飲料', '果味泡泡水', '氣泡果汁飲品', '果汁泡泡水', '氣泡飲品']
# ----------
# [debug] prompt
# Please generate 11 product names for 機能水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "活力機能水",
#     "純淨機能水",
#     "深層潤澤機能水",
#     "維他命補充機能水",
#     "清爽保濕機能水",
#     "抗衰老機能水",
#     "專業修護機能水",
#     "天然舒緩機能水",
#     "強效保濕機能水",
#     "滋潤調理機能水",
#     "抗氧化機能水"
#   ]
# }
# 機能水
# []
# ['活力機能水', '純淨機能水', '深層潤澤機能水', '維他命補充機能水', '清爽保濕機能水', '抗衰老機能水', '專業修護機能水', '天然舒緩機能水', '強效保濕機能水', '滋潤調理機能水', '抗氧化機能水']
# ----------
# [debug] prompt
# Please generate 11 product names for 鮮乳類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "純鮮奶",
#     "低脂鮮乳",
#     "無糖鮮乳",
#     "有機鮮乳",
#     "草莓鮮乳",
#     "巧克力鮮乳",
#     "香蕉鮮乳",
#     "蜂蜜鮮乳",
#     "脫脂鮮乳",
#     "蓋有綠色蓋子的鮮乳",
#     "加鈣鮮乳"
#   ]
# }
# 鮮乳類
# []
# ['純鮮奶', '低脂鮮乳', '無糖鮮乳', '有機鮮乳', '草莓鮮乳', '巧克力鮮乳', '香蕉鮮乳', '蜂蜜鮮乳', '脫脂鮮乳', '蓋有綠色蓋子的鮮乳', '加鈣鮮乳']
# ----------
# [debug] prompt
# Please generate 11 product names for 保久乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "保久乳-超濃郁",
#     "保久乳-蜂蜜風味",
#     "保久乳-草莓口味",
#     "保久乳-香蕉口味",
#     "保久乳-巧克力風味",
#     "保久乳-奶蓋風味",
#     "保久乳-咖啡口味",
#     "保久乳-芒果口味",
#     "保久乳-雪糕風味",
#     "保久乳-鳳梨口味",
#     "保久乳-草莓奶茶風味"
#   ]
# }
# 保久乳
# []
# ['保久乳-超濃郁', '保久乳-蜂蜜風味', '保久乳-草莓口味', '保久乳-香蕉口味', '保久乳-巧克力風味', '保久乳-奶蓋風味', '保久乳-咖啡口味', '保久乳-芒果口味', '保久乳-雪糕風味', '保久乳-鳳梨口味', '保久乳-草莓奶茶風味']
# ----------
# [debug] prompt
# Please generate 11 product names for 調味乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "奶油口味調味乳",
#     "草莓口味調味乳",
#     "巧克力口味調味乳",
#     "香蕉口味調味乳",
#     "蜂蜜口味調味乳",
#     "檸檬口味調味乳",
#     "咖啡口味調味乳",
#     "蘋果口味調味乳",
#     "藍莓口味調味乳",
#     "榴槤口味調味乳",
#     "芒果口味調味乳"
#   ]
# }
# 調味乳
# []
# ['奶油口味調味乳', '草莓口味調味乳', '巧克力口味調味乳', '香蕉口味調味乳', '蜂蜜口味調味乳', '檸檬口味調味乳', '咖啡口味調味乳', '蘋果口味調味乳', '藍莓口味調味乳', '榴槤口味調味乳', '芒果口味調味乳']
# ----------
# [debug] prompt
# Please generate 11 product names for 優格 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "蜜桃優格",
#     "草莓優格",
#     "香蕉優格",
#     "覆盆子優格",
#     "葡萄優格",
#     "櫻桃優格",
#     "藍莓優格",
#     "巧克力優格",
#     "芒果優格",
#     "檸檬優格",
#     "黑莓優格"
#   ]
# }
# 優格
# []
# ['蜜桃優格', '草莓優格', '香蕉優格', '覆盆子優格', '葡萄優格', '櫻桃優格', '藍莓優格', '巧克力優格', '芒果優格', '檸檬優格', '黑莓優格']
# ----------
# [debug] prompt
# Please generate 11 product names for 優酪乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "優酪乳元氣藍莓口味",
#     "優酪乳天然芒果口味",
#     "優酪乳香蕉奶昔口味",
#     "優酪乳經典原味",
#     "優酪乳柳橙檸檬口味",
#     "優酪乳草莓鮮果口味",
#     "優酪乳混合堅果口味",
#     "優酪乳蜜桃果粒口味",
#     "優酪乳紅茶奶昔口味",
#     "優酪乳抹茶口味",
#     "優酪乳香草口味"
#   ]
# }
# 優酪乳
# []
# ['優酪乳元氣藍莓口味', '優酪乳天然芒果口味', '優酪乳香蕉奶昔口味', '優酪乳經典原味', '優酪乳柳橙檸檬口味', '優酪乳草莓鮮果口味', '優酪乳混合堅果口味', '優酪乳蜜桃果粒口味', '優酪乳紅茶奶昔口味', '優酪乳抹茶口味', '優酪乳香草口味']
# ----------
# [debug] prompt
# Please generate 11 product names for 發酵乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "酸奶乳",
#     "優酪乳",
#     "乳酸菌乳",
#     "有機發酵乳",
#     "無糖發酵乳",
#     "果味發酵乳",
#     "希臘式發酵乳",
#     "冰淇淋發酵乳",
#     "原味發酵乳",
#     "天然發酵乳",
#     "植物性發酵乳"
#   ]
# }
# 發酵乳
# []
# ['酸奶乳', '優酪乳', '乳酸菌乳', '有機發酵乳', '無糖發酵乳', '果味發酵乳', '希臘式發酵乳', '冰淇淋發酵乳', '原味發酵乳', '天然發酵乳', '植物性發酵乳']
# ----------
# [debug] prompt
# Please generate 11 product names for 豆漿 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#     "product_name": [
#         "豆漿霜糕",
#         "黑糖豆漿",
#         "豆漿饅頭",
#         "綠豆漿",
#         "豆漿麥片",
#         "香蕉豆漿",
#         "豆漿布丁",
#         "豆漿冰棒",
#         "花生豆漿",
#         "豆漿餅乾",
#         "紅豆豆漿"
#     ]
# }
# 豆漿
# []
# ['豆漿霜糕', '黑糖豆漿', '豆漿饅頭', '綠豆漿', '豆漿麥片', '香蕉豆漿', '豆漿布丁', '豆漿冰棒', '花生豆漿', '豆漿餅乾', '紅豆豆漿']
# ----------
# [debug] prompt
# Please generate 11 product names for 米漿 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "椰漿",
#     "燕麥漿",
#     "豆漿",
#     "杏仁漿",
#     "黑豆漿",
#     "花生漿",
#     "核桃漿",
#     "蓮藕漿",
#     "薏仁漿",
#     "紅豆漿",
#     "黑芝麻漿"
#   ]
# }
# 米漿
# []
# ['椰漿', '燕麥漿', '豆漿', '杏仁漿', '黑豆漿', '花生漿', '核桃漿', '蓮藕漿', '薏仁漿', '紅豆漿', '黑芝麻漿']
# ----------
# [debug] prompt
# Please generate 11 product names for 燕麥奶 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "燕麥奶蛋白飲料",
#     "無糖燕麥奶",
#     "有機燕麥奶",
#     "香蕉燕麥奶",
#     "蜂蜜燕麥奶",
#     "巧克力燕麥奶",
#     "草莓燕麥奶",
#     "藍莓燕麥奶",
#     "杏仁燕麥奶",
#     "蘋果燕麥奶",
#     "南瓜燕麥奶"
#   ]
# }
# 燕麥奶
# []
# ['燕麥奶蛋白飲料', '無糖燕麥奶', '有機燕麥奶', '香蕉燕麥奶', '蜂蜜燕麥奶', '巧克力燕麥奶', '草莓燕麥奶', '藍莓燕麥奶', '杏仁燕麥奶', '蘋果燕麥奶', '南瓜燕麥奶']
# ----------
# [debug] prompt
# Please generate 11 product names for 現做霜淇淋/聖代 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "手工製作的霜淇淋",
#     "純天然的聖代",
#     "特製的現做霜淇淋",
#     "冰凍的甜點",
#     "原味的霜淇淋",
#     "經典的聖代口味",
#     "濃郁的冰淇淋",
#     "新鮮的現做霜淇淋",
#     "美味的甜點選擇",
#     "創意的聖代創作",
#     "口感豐富的霜淇淋"
#   ]
# }
# 現做霜淇淋/聖代
# []
# ['手工製作的霜淇淋', '純天然的聖代', '特製的現做霜淇淋', '冰凍的甜點', '原味的霜淇淋', '經典的聖代口味', '濃郁的冰淇淋', '新鮮的現做霜淇淋', '美味的甜點選擇', '創意的聖代創作', '口感豐富的霜淇淋']
# ----------
# [debug] prompt
# Please generate 11 product names for 冰棒/雪糕 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "酸柑葡萄冰棒",
#     "香蕉巧克力雪糕",
#     "草莓牛奶冰棒",
#     "薄荷巧克力雪糕",
#     "芒果椰子冰棒",
#     "藍莓紅茶雪糕",
#     "榴槤牛奶冰棒",
#     "蜜瓜薄荷雪糕",
#     "檸檬蛋糕冰棒",
#     "葡萄柚冰棒",
#     "巧克力榛果雪糕"
#   ]
# }
# 冰棒/雪糕
# []
# ['酸柑葡萄冰棒', '香蕉巧克力雪糕', '草莓牛奶冰棒', '薄荷巧克力雪糕', '芒果椰子冰棒', '藍莓紅茶雪糕', '榴槤牛奶冰棒', '蜜瓜薄荷雪糕', '檸檬蛋糕冰棒', '葡萄柚冰棒', '巧克力榛果雪糕']
# ----------
# [debug] prompt
# Please generate 11 product names for 冰淇淋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香蕉巧克力冰淇淋",
#     "草莓奶油冰淇淋",
#     "巧克力醬奶昔冰淇淋",
#     "蜜桃冰淇淋",
#     "紅豆花生冰淇淋",
#     "檸檬冰淇淋",
#     "黑芝麻冰淇淋",
#     "薄荷朱古力冰淇淋",
#     "葡萄冰淇淋",
#     "橙汁冰淇淋",
#     "奶油雪糕棒"
#   ]
# }
# 冰淇淋
# []
# ['香蕉巧克力冰淇淋', '草莓奶油冰淇淋', '巧克力醬奶昔冰淇淋', '蜜桃冰淇淋', '紅豆花生冰淇淋', '檸檬冰淇淋', '黑芝麻冰淇淋', '薄荷朱古力冰淇淋', '葡萄冰淇淋', '橙汁冰淇淋', '奶油雪糕棒']
# ----------
# [debug] prompt
# Please generate 11 product names for 甜筒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "脆皮香蕉甜筒",
#     "巧克力杏仁甜筒",
#     "草莓奶油甜筒",
#     "焦糖咖啡甜筒",
#     "抹茶紅豆甜筒",
#     "焦糖海鹽甜筒",
#     "雲呢拿草莓甜筒",
#     "薄荷巧克力甜筒",
#     "榴槤奶油甜筒",
#     "蜜桃乳酪甜筒",
#     "蘋果肉桂甜筒"
#   ]
# }
# 甜筒
# []
# ['脆皮香蕉甜筒', '巧克力杏仁甜筒', '草莓奶油甜筒', '焦糖咖啡甜筒', '抹茶紅豆甜筒', '焦糖海鹽甜筒', '雲呢拿草莓甜筒', '薄荷巧克力甜筒', '榴槤奶油甜筒', '蜜桃乳酪甜筒', '蘋果肉桂甜筒']
# ----------
# [debug] prompt
# Please generate 11 product names for 仙草/愛玉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "仙草冰",
#     "愛玉凍",
#     "仙草凍",
#     "仙草奶茶",
#     "仙草糕",
#     "愛玉糕",
#     "仙草豆花",
#     "愛玉豆花",
#     "仙草果凍",
#     "愛玉果凍",
#     "仙草冰淇淋"
#   ]
# }
# 仙草/愛玉
# []
# ['仙草冰', '愛玉凍', '仙草凍', '仙草奶茶', '仙草糕', '愛玉糕', '仙草豆花', '愛玉豆花', '仙草果凍', '愛玉果凍', '仙草冰淇淋']
# ----------
# [debug] prompt
# Please generate 11 product names for 水果冰品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {"product_name": ["水果冰淇淋", "水果冰棒", "水果冰沙", "水果冰霜", "水果雪糕", "水果冰凍", "水果冰糕", "水果冰粉", "水果冰激凌", "水果冰蓮露", "水果冰磚"]}
# 水果冰品
# []
# ['水果冰淇淋', '水果冰棒', '水果冰沙', '水果冰霜', '水果雪糕', '水果冰凍', '水果冰糕', '水果冰粉', '水果冰激凌', '水果冰蓮露', '水果冰磚']
# ----------
# [debug] prompt
# Please generate 11 product names for 冰塊 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冰山之舞",
#     "冰块王国",
#     "冰晶宝石",
#     "冰雪奇缘",
#     "冰块大冒险",
#     "冰山探险家",
#     "冰封传说",
#     "冰山神殿",
#     "冰雪王国",
#     "冰块之夜",
#     "冰山世界"
#   ]
# }
# 冰塊
# []
# ['冰山之舞', '冰块王国', '冰晶宝石', '冰雪奇缘', '冰块大冒险', '冰山探险家', '冰封传说', '冰山神殿', '冰雪王国', '冰块之夜', '冰山世界']
# ----------
# [debug] prompt
# Please generate 11 product names for 現調冰品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香蕉冰沙",
#     "巧克力鮮奶茶",
#     "蘋果綠茶",
#     "檸檬冰",
#     "草莓冰淇淋",
#     "芒果冰沙",
#     "葡萄果汁",
#     "蜂蜜柚子茶",
#     "椰子冰淇淋",
#     "奇異果冰沙",
#     "柚子冰"
#   ]
# }
# 現調冰品
# []
# ['香蕉冰沙', '巧克力鮮奶茶', '蘋果綠茶', '檸檬冰', '草莓冰淇淋', '芒果冰沙', '葡萄果汁', '蜂蜜柚子茶', '椰子冰淇淋', '奇異果冰沙', '柚子冰']
# ----------
# [debug] prompt
# Please generate 11 product names for 蒸箱食品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "麻辣蒸箱食品",
#     "蒜香蒸箱食品",
#     "香菇蒸箱食品",
#     "豆腐蒸箱食品",
#     "海鮮蒸箱食品",
#     "韭菜蒸箱食品",
#     "玉米蒸箱食品",
#     "黑胡椒蒸箱食品",
#     "蛋黃蒸箱食品",
#     "奶油蒸箱食品",
#     "蔬菜蒸箱食品"
#   ]
# }
# 蒸箱食品
# []
# ['麻辣蒸箱食品', '蒜香蒸箱食品', '香菇蒸箱食品', '豆腐蒸箱食品', '海鮮蒸箱食品', '韭菜蒸箱食品', '玉米蒸箱食品', '黑胡椒蒸箱食品', '蛋黃蒸箱食品', '奶油蒸箱食品', '蔬菜蒸箱食品']
# ----------
# [debug] prompt
# Please generate 11 product names for 地瓜 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香烤地瓜",
#     "地瓜糕",
#     "地瓜蛋糕",
#     "地瓜粥",
#     "地瓜饼",
#     "地瓜球",
#     "地瓜丝",
#     "地瓜片",
#     "地瓜饭",
#     "地瓜炒饭",
#     "地瓜泥"
#   ]
# }
# 地瓜
# []
# ['香烤地瓜', '地瓜糕', '地瓜蛋糕', '地瓜粥', '地瓜饼', '地瓜球', '地瓜丝', '地瓜片', '地瓜饭', '地瓜炒饭', '地瓜泥']
# ----------
# [debug] prompt
# Please generate 11 product names for 熱狗 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "搖滾熱狗",
#     "麻辣熱狗",
#     "芝士熱狗",
#     "墨西哥熱狗",
#     "脆皮熱狗",
#     "椒麻熱狗",
#     "香腸熱狗",
#     "玉米熱狗",
#     "波蘿包熱狗",
#     "日式熱狗",
#     "起司蔬菜熱狗"
#   ]
# }
# 熱狗
# []
# ['搖滾熱狗', '麻辣熱狗', '芝士熱狗', '墨西哥熱狗', '脆皮熱狗', '椒麻熱狗', '香腸熱狗', '玉米熱狗', '波蘿包熱狗', '日式熱狗', '起司蔬菜熱狗']
# ----------
# [debug] prompt
# Please generate 11 product names for 關東煮 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "豪華關東煮",
#     "日式關東煮",
#     "鮮美關東煮",
#     "特製關東煮",
#     "濃郁關東煮",
#     "經典關東煮",
#     "熱騰騰關東煮",
#     "風味關東煮",
#     "美味關東煮",
#     "蔬菜關東煮",
#     "魚鮮關東煮"
#   ]
# }
# 關東煮
# []
# ['豪華關東煮', '日式關東煮', '鮮美關東煮', '特製關東煮', '濃郁關東煮', '經典關東煮', '熱騰騰關東煮', '風味關東煮', '美味關東煮', '蔬菜關東煮', '魚鮮關東煮']
# ----------
# [debug] prompt
# Please generate 11 product names for 米飯類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {"product_name": ["特色炒飯", "蛋炒飯", "海鮮炒飯", "韓式石鍋拌飯", "豬肉炒飯", "牛肉飯", "滷肉飯", "糖醋排骨飯", "鹹魚炒飯", "海南雞飯", "泰式綠咖哩飯"]}
# 米飯類
# []
# ['特色炒飯', '蛋炒飯', '海鮮炒飯', '韓式石鍋拌飯', '豬肉炒飯', '牛肉飯', '滷肉飯', '糖醋排骨飯', '鹹魚炒飯', '海南雞飯', '泰式綠咖哩飯']
# ----------
# [debug] prompt
# Please generate 11 product names for 麵食類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "炸醬麵",
#     "牛肉麵",
#     "炒麵",
#     "羊肉燴麵",
#     "担担麵",
#     "水餃",
#     "湯餃",
#     "蛋餅",
#     "蔥油餅",
#     "炒蛋麵",
#     "燙青菜"
#   ]
# }
# 麵食類
# []
# ['炸醬麵', '牛肉麵', '炒麵', '羊肉燴麵', '担担麵', '水餃', '湯餃', '蛋餅', '蔥油餅', '炒蛋麵', '燙青菜']
# ----------
# [debug] prompt
# Please generate 11 product names for 三明治 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "經典火腿蛋三明治",
#     "辣味雞肉三明治",
#     "蔬菜起司三明治",
#     "牛肉洋蔥三明治",
#     "鮪魚蛋三明治",
#     "厚切培根三明治",
#     "煙燻鮭魚三明治",
#     "烤雞起司三明治",
#     "香腸蛋三明治",
#     "招牌燒肉三明治",
#     "番茄生菜三明治"
#   ]
# }
# 三明治
# []
# ['經典火腿蛋三明治', '辣味雞肉三明治', '蔬菜起司三明治', '牛肉洋蔥三明治', '鮪魚蛋三明治', '厚切培根三明治', '煙燻鮭魚三明治', '烤雞起司三明治', '香腸蛋三明治', '招牌燒肉三明治', '番茄生菜三明治']
# ----------
# [debug] prompt
# Please generate 11 product names for 漢堡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "火山漢堡",
#     "牛肉起司漢堡",
#     "蔬菜漢堡",
#     "辣味漢堡",
#     "豬肉漢堡",
#     "香腸漢堡",
#     "鮪魚漢堡",
#     "雞肉漢堡",
#     "培根漢堡",
#     "藍莓漢堡",
#     "紅豆漢堡"
#   ]
# }
# 漢堡
# []
# ['火山漢堡', '牛肉起司漢堡', '蔬菜漢堡', '辣味漢堡', '豬肉漢堡', '香腸漢堡', '鮪魚漢堡', '雞肉漢堡', '培根漢堡', '藍莓漢堡', '紅豆漢堡']
# ----------
# [debug] prompt
# Please generate 11 product names for 生鮮蔬果/沙拉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "新鮮水果沙拉",
#     "無添加沙拉醬",
#     "有機蔬菜沙拉",
#     "綜合生鮮沙拉",
#     "蔬果沙拉套餐",
#     "清新果蔬拼盤",
#     "香橙蔬菜沙拉",
#     "時令蔬果沙拉",
#     "濃郁蔬果沙拉",
#     "五彩蔬果沙拉",
#     "精選時蔬沙拉"
#   ]
# }
# 生鮮蔬果/沙拉
# []
# ['新鮮水果沙拉', '無添加沙拉醬', '有機蔬菜沙拉', '綜合生鮮沙拉', '蔬果沙拉套餐', '清新果蔬拼盤', '香橙蔬菜沙拉', '時令蔬果沙拉', '濃郁蔬果沙拉', '五彩蔬果沙拉', '精選時蔬沙拉']
# ----------
# [debug] prompt
# Please generate 11 product names for 小菜/滷味 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "醬燒豆腐",
#     "滷雞爪",
#     "滷蛋",
#     "五香豆干",
#     "香辣鴨血",
#     "糯米肉",
#     "油豆腐",
#     "滷牛肉",
#     "五香牛肚",
#     "滷鵝肝",
#     "油條"
#   ]
# }
# 小菜/滷味
# []
# ['醬燒豆腐', '滷雞爪', '滷蛋', '五香豆干', '香辣鴨血', '糯米肉', '油豆腐', '滷牛肉', '五香牛肚', '滷鵝肝', '油條']
# ----------
# [debug] prompt
# Please generate 11 product names for 湯品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "麻辣鴨血豆腐湯",
#     "蔬菜海鮮豆腐湯",
#     "酸辣番茄豆腐湯",
#     "鮮蝦魚丸湯",
#     "豬骨拉麵湯",
#     "四神湯",
#     "麻辣牛肉湯",
#     "雞絲蔬菜湯",
#     "蛋花蟹肉湯",
#     "酸辣羊肉湯",
#     "滋補燉湯"
#   ]
# }
# 湯品
# []
# ['麻辣鴨血豆腐湯', '蔬菜海鮮豆腐湯', '酸辣番茄豆腐湯', '鮮蝦魚丸湯', '豬骨拉麵湯', '四神湯', '麻辣牛肉湯', '雞絲蔬菜湯', '蛋花蟹肉湯', '酸辣羊肉湯', '滋補燉湯']
# ----------
# [debug] prompt
# Please generate 11 product names for 水餃/點心 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "綠豆沙餃",
#     "牛肉餃",
#     "蔥油餅",
#     "燒賣",
#     "蝦餃",
#     "鮮肉小籠包",
#     "韭菜盒子",
#     "叉燒包",
#     "花枝丸",
#     "蛋黃酥",
#     "鳳梨酥"
#   ]
# }
# 水餃/點心
# []
# ['綠豆沙餃', '牛肉餃', '蔥油餅', '燒賣', '蝦餃', '鮮肉小籠包', '韭菜盒子', '叉燒包', '花枝丸', '蛋黃酥', '鳳梨酥']
# ----------
# [debug] prompt
# Please generate 11 product names for 雞胸肉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "優質雞胸肉",
#     "酥炸雞胸肉",
#     "香烤雞胸肉",
#     "蜜汁烤雞胸肉",
#     "番茄燉雞胸肉",
#     "黑胡椒炒雞胸肉",
#     "檸檬煎雞胸肉",
#     "蒜味烤雞胸肉",
#     "椒鹽雞胸肉",
#     "泰式炒雞胸肉",
#     "香辣炸雞胸肉"
#   ]
# }
# 雞胸肉
# []
# ['優質雞胸肉', '酥炸雞胸肉', '香烤雞胸肉', '蜜汁烤雞胸肉', '番茄燉雞胸肉', '黑胡椒炒雞胸肉', '檸檬煎雞胸肉', '蒜味烤雞胸肉', '椒鹽雞胸肉', '泰式炒雞胸肉', '香辣炸雞胸肉']
# ----------
# [debug] prompt
# Please generate 11 product names for 茶葉蛋/水煮蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香草茶葉蛋",
#     "五香茶葉蛋",
#     "蜂蜜茶葉蛋",
#     "咖啡茶葉蛋",
#     "玫瑰茶葉蛋",
#     "抹茶茶葉蛋",
#     "薰衣草茶葉蛋",
#     "檸檬茶葉蛋",
#     "黑糖茶葉蛋",
#     "芒果茶葉蛋",
#     "巧克力茶葉蛋"
#   ]
# }
# 茶葉蛋/水煮蛋
# []
# ['香草茶葉蛋', '五香茶葉蛋', '蜂蜜茶葉蛋', '咖啡茶葉蛋', '玫瑰茶葉蛋', '抹茶茶葉蛋', '薰衣草茶葉蛋', '檸檬茶葉蛋', '黑糖茶葉蛋', '芒果茶葉蛋', '巧克力茶葉蛋']
# ----------
# [debug] prompt
# Please generate 11 product names for 肉品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#     "product_name": [
#         "香辣肉片",
#         "黑胡椒烤肉",
#         "蒜香燒肉",
#         "麻辣牛肉",
#         "五香豬肉",
#         "櫻桃木燻肉",
#         "蜜汁叉燒",
#         "韓式烤肉",
#         "沙茶爆肚",
#         "椒鹽排骨",
#         "蒜蓉牛肉"
#     ]
# }
# 肉品
# []
# ['香辣肉片', '黑胡椒烤肉', '蒜香燒肉', '麻辣牛肉', '五香豬肉', '櫻桃木燻肉', '蜜汁叉燒', '韓式烤肉', '沙茶爆肚', '椒鹽排骨', '蒜蓉牛肉']
# ----------
# [debug] prompt
# Please generate 11 product names for 麵包 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "奶油麵包",
#     "蛋糕麵包",
#     "法國麵包",
#     "全麥麵包",
#     "蔓越莓麵包",
#     "巧克力麵包",
#     "杏仁麵包",
#     "葡萄乾麵包",
#     "抹茶麵包",
#     "紅豆麵包",
#     "黑糖麵包"
#   ]
# }
# 麵包
# []
# ['奶油麵包', '蛋糕麵包', '法國麵包', '全麥麵包', '蔓越莓麵包', '巧克力麵包', '杏仁麵包', '葡萄乾麵包', '抹茶麵包', '紅豆麵包', '黑糖麵包']
# ----------
# [debug] prompt
# Please generate 11 product names for 蛋糕 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "巧克力慕斯蛋糕",
#     "紅絲絨蛋糕",
#     "檸檬戚風蛋糕",
#     "草莓奶油蛋糕",
#     "綠茶芝士蛋糕",
#     "焦糖拿破崙蛋糕",
#     "提拉米蘇蛋糕",
#     "藍莓乳酪蛋糕",
#     "芒果慕斯蛋糕",
#     "班戟蛋糕",
#     "榴槤千層蛋糕"
#   ]
# }
# 蛋糕
# []
# ['巧克力慕斯蛋糕', '紅絲絨蛋糕', '檸檬戚風蛋糕', '草莓奶油蛋糕', '綠茶芝士蛋糕', '焦糖拿破崙蛋糕', '提拉米蘇蛋糕', '藍莓乳酪蛋糕', '芒果慕斯蛋糕', '班戟蛋糕', '榴槤千層蛋糕']
# ----------
# [debug] prompt
# Please generate 11 product names for 中式糕點 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "紅豆餅",
#     "鳳梨酥",
#     "蛋黃酥",
#     "糯米糍",
#     "麻糬",
#     "花生糖",
#     "蓮蓉酥",
#     "杏仁餅",
#     "山竹糕",
#     "豆沙酥",
#     "綠豆糕"
#   ]
# }
# 中式糕點
# []
# ['紅豆餅', '鳳梨酥', '蛋黃酥', '糯米糍', '麻糬', '花生糖', '蓮蓉酥', '杏仁餅', '山竹糕', '豆沙酥', '綠豆糕']
# ----------
# [debug] prompt
# Please generate 11 product names for 生雞蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "金牌生雞蛋",
#     "有機生雞蛋",
#     "土雞生雞蛋",
#     "大地生雞蛋",
#     "家鄉生雞蛋",
#     "紅蓮生雞蛋",
#     "綠天生雞蛋",
#     "天然生雞蛋",
#     "健康生雞蛋",
#     "自然生雞蛋",
#     "新鮮生雞蛋"
#   ]
# }
# 生雞蛋
# []
# ['金牌生雞蛋', '有機生雞蛋', '土雞生雞蛋', '大地生雞蛋', '家鄉生雞蛋', '紅蓮生雞蛋', '綠天生雞蛋', '天然生雞蛋', '健康生雞蛋', '自然生雞蛋', '新鮮生雞蛋']
# ----------
# [debug] prompt
# Please generate 11 product names for 加工蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "火烤蛋",
#     "蒸蛋糕",
#     "炒蛋麵",
#     "煎蛋餅",
#     "焗蛋",
#     "滑蛋牛肉飯",
#     "蛋包飯",
#     "煮蛋",
#     "炒蛋",
#     "炒蛋飯",
#     "蛋糕"
#   ]
# }
# 加工蛋
# []
# ['火烤蛋', '蒸蛋糕', '炒蛋麵', '煎蛋餅', '焗蛋', '滑蛋牛肉飯', '蛋包飯', '煮蛋', '炒蛋', '炒蛋飯', '蛋糕']
# ----------
# [debug] prompt
# Please generate 11 product names for 生鮮蔬菜 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "新鮮紅蘿蔔",
#     "有機蔬菜籃",
#     "清爽生菜",
#     "營養豐富青江菜",
#     "甜美櫛瓜",
#     "香嫩芥蘭",
#     "多汁番茄",
#     "爽口小黃瓜",
#     "鮮嫩洋蔥",
#     "新鮮玉米",
#     "豐富營養蘆筍"
#   ]
# }
# 生鮮蔬菜
# []
# ['新鮮紅蘿蔔', '有機蔬菜籃', '清爽生菜', '營養豐富青江菜', '甜美櫛瓜', '香嫩芥蘭', '多汁番茄', '爽口小黃瓜', '鮮嫩洋蔥', '新鮮玉米', '豐富營養蘆筍']
# ----------
# [debug] prompt
# Please generate 11 product names for 生鮮水果 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "金煌蜜柚",
#     "百香果",
#     "黃金果",
#     "夏威夷果",
#     "鳳梨蜜",
#     "紅心柚",
#     "美濃芒果",
#     "綠心瀉褲果",
#     "水晶葡萄",
#     "玉荷包",
#     "百香蜜"
#   ]
# }
# 生鮮水果
# []
# ['金煌蜜柚', '百香果', '黃金果', '夏威夷果', '鳳梨蜜', '紅心柚', '美濃芒果', '綠心瀉褲果', '水晶葡萄', '玉荷包', '百香蜜']
# ----------
# [debug] prompt
# Please generate 11 product names for 生鮮肉品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "新鮮豬肉",
#     "優質牛肉",
#     "鮮美雞肉",
#     "頂級羊肉",
#     "美味海鮮",
#     "新鮮鴨肉",
#     "精緻火雞肉",
#     "特級鵝肉",
#     "鮮嫩兔肉",
#     "高級鹿肉",
#     "鮮美魚肉"
#   ]
# }
# 生鮮肉品
# []
# ['新鮮豬肉', '優質牛肉', '鮮美雞肉', '頂級羊肉', '美味海鮮', '新鮮鴨肉', '精緻火雞肉', '特級鵝肉', '鮮嫩兔肉', '高級鹿肉', '鮮美魚肉']
# ----------
# [debug] prompt
# Please generate 11 product names for 生鮮海鮮 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "新鮮魚肉",
#     "海鮮拼盤",
#     "鮮蝦",
#     "魚子醬",
#     "活魚",
#     "生蠔",
#     "帝王蟹",
#     "鮑魚",
#     "魚排",
#     "海鮮湯",
#     "鱈魚柳"
#   ]
# }
# 生鮮海鮮
# []
# ['新鮮魚肉', '海鮮拼盤', '鮮蝦', '魚子醬', '活魚', '生蠔', '帝王蟹', '鮑魚', '魚排', '海鮮湯', '鱈魚柳']
# ----------
# [debug] prompt
# Please generate 11 product names for 豆腐 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香嫩豆腐",
#     "四川麻辣豆腐",
#     "豆腐脆片",
#     "黑豆豆腐",
#     "香菇豆腐",
#     "五香豆腐",
#     "蒸豆腐",
#     "炒豆腐絲",
#     "豆腐漿",
#     "糖醋豆腐",
#     "紅油豆腐"
#   ]
# }
# 豆腐
# []
# ['香嫩豆腐', '四川麻辣豆腐', '豆腐脆片', '黑豆豆腐', '香菇豆腐', '五香豆腐', '蒸豆腐', '炒豆腐絲', '豆腐漿', '糖醋豆腐', '紅油豆腐']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷藏調理 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冷藏醃料包",
#     "急速冷凍調理包",
#     "冷凍蔬果調理包",
#     "冷藏醬汁包",
#     "冷凍肉品調理包",
#     "冷藏海鮮調理包",
#     "冷凍湯品調理包",
#     "冷藏沙拉醬",
#     "急速冷藏調理包",
#     "冷凍甜點調理包",
#     "冷藏沙拉調味包"
#   ]
# }
# 冷藏調理
# []
# ['冷藏醃料包', '急速冷凍調理包', '冷凍蔬果調理包', '冷藏醬汁包', '冷凍肉品調理包', '冷藏海鮮調理包', '冷凍湯品調理包', '冷藏沙拉醬', '急速冷藏調理包', '冷凍甜點調理包', '冷藏沙拉調味包']
# ----------
# [debug] prompt
# Please generate 11 product names for 速食調理包 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "香辣炸雞速食調理包",
#     "蒜香烤雞速食調理包",
#     "麻辣火鍋速食調理包",
#     "紅燒牛肉速食調理包",
#     "黑胡椒豬排速食調理包",
#     "孜然羊肉速食調理包",
#     "蒜蓉蝦仁速食調理包",
#     "奶油蘑菇湯速食調理包",
#     "番茄炒蛋速食調理包",
#     "韓式泡菜速食調理包",
#     "五香豆干速食調理包"
#   ]
# }
# 速食調理包
# []
# ['香辣炸雞速食調理包', '蒜香烤雞速食調理包', '麻辣火鍋速食調理包', '紅燒牛肉速食調理包', '黑胡椒豬排速食調理包', '孜然羊肉速食調理包', '蒜蓉蝦仁速食調理包', '奶油蘑菇湯速食調理包', '番茄炒蛋速食調理包', '韓式泡菜速食調理包', '五香豆干速食調理包']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷凍蔬菜 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "雪花豌豆",
#     "冰山菜花",
#     "冷凍香菇",
#     "冰鮮玉米",
#     "冷凍紅蘿蔔",
#     "冰鏡甜椒",
#     "冷凍青江菜",
#     "冰鮮蘆筍",
#     "冷凍甜豆",
#     "雪山蕃薯",
#     "冰鏡草莓"
#   ]
# }
# 冷凍蔬菜
# []
# ['雪花豌豆', '冰山菜花', '冷凍香菇', '冰鮮玉米', '冷凍紅蘿蔔', '冰鏡甜椒', '冷凍青江菜', '冰鮮蘆筍', '冷凍甜豆', '雪山蕃薯', '冰鏡草莓']
# ----------
# Bad gateway. {"error":{"code":502,"message":"Bad gateway.","param":null,"type":"cf_bad_gateway"}} 502 {'error': {'code': 502, 'message': 'Bad gateway.', 'param': None, 'type': 'cf_bad_gateway'}} {'Date': 'Fri, 04 Aug 2023 02:48:09 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'same-origin', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Server': 'cloudflare', 'CF-RAY': '7f1373289b561ee2-NRT', 'alt-svc': 'h3=":443"; ma=86400'}
# [debug] prompt
# Please generate 11 product names for 冷凍水果 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冷凍草莓",
#     "冷凍芒果",
#     "冷凍櫻桃",
#     "冷凍菠蘿",
#     "冷凍藍莓",
#     "冷凍香蕉",
#     "冷凍葡萄",
#     "冷凍橘子",
#     "冷凍梨子",
#     "冷凍檸檬",
#     "冷凍柚子"
#   ]
# }
# 冷凍水果
# []
# ['冷凍草莓', '冷凍芒果', '冷凍櫻桃', '冷凍菠蘿', '冷凍藍莓', '冷凍香蕉', '冷凍葡萄', '冷凍橘子', '冷凍梨子', '冷凍檸檬', '冷凍柚子']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷凍肉品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冷凍鮮嫩牛排",
#     "炭烤雞翅",
#     "低脂火腿片",
#     "香辣烤雞翅",
#     "黑胡椒牛柳",
#     "櫻桃木燻雞胸",
#     "義式香腸",
#     "咖哩豬肉塊",
#     "烤鮭魚片",
#     "法式烤雞腿",
#     "泰式辣味牛肉片"
#   ]
# }
# 冷凍肉品
# []
# ['冷凍鮮嫩牛排', '炭烤雞翅', '低脂火腿片', '香辣烤雞翅', '黑胡椒牛柳', '櫻桃木燻雞胸', '義式香腸', '咖哩豬肉塊', '烤鮭魚片', '法式烤雞腿', '泰式辣味牛肉片']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷凍海鮮 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "冷凍熱帶魚",
#     "冷凍鱈魚塊",
#     "冷凍鮭魚片",
#     "冷凍海蝦",
#     "冷凍鱈魚片",
#     "冷凍鮪魚塊",
#     "冷凍鯛魚片",
#     "冷凍螃蟹腿",
#     "冷凍帶子",
#     "冷凍鱈魚排",
#     "冷凍鮭魚塊"
#   ]
# }
# 冷凍海鮮
# []
# ['冷凍熱帶魚', '冷凍鱈魚塊', '冷凍鮭魚片', '冷凍海蝦', '冷凍鱈魚片', '冷凍鮪魚塊', '冷凍鯛魚片', '冷凍螃蟹腿', '冷凍帶子', '冷凍鱈魚排', '冷凍鮭魚塊']
# ----------
# [debug] prompt
# Please generate 11 product names for 火鍋用料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "麻辣火鍋底料",
#     "鮮蔬火鍋料",
#     "牛肉片",
#     "豬肉片",
#     "羊肉片",
#     "海鮮火鍋料",
#     "魚豆腐",
#     "麻辣雞肉片",
#     "麻辣豆腐乳",
#     "麻辣鴨血",
#     "麻辣雞爪"
#   ]
# }
# 火鍋用料
# []
# ['麻辣火鍋底料', '鮮蔬火鍋料', '牛肉片', '豬肉片', '羊肉片', '海鮮火鍋料', '魚豆腐', '麻辣雞肉片', '麻辣豆腐乳', '麻辣鴨血', '麻辣雞爪']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷凍水餃/點心類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "蝦仁水餃",
#     "韭菜水餃",
#     "豬肉餛飩",
#     "牛肉水餃",
#     "香菇水餃",
#     "蔬菜水餃",
#     "酸菜魚水餃",
#     "燒賣",
#     "韭菜盒子",
#     "蒸餃",
#     "豆沙餃"
#   ]
# }
# 冷凍水餃/點心類
# []
# ['蝦仁水餃', '韭菜水餃', '豬肉餛飩', '牛肉水餃', '香菇水餃', '蔬菜水餃', '酸菜魚水餃', '燒賣', '韭菜盒子', '蒸餃', '豆沙餃']
# ----------
# [debug] prompt
# Please generate 11 product names for 冷凍微波料理 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "新鮮冷凍微波食品",
#     "營養冷凍微波料理",
#     "健康冷凍微波美食",
#     "方便冷凍微波餐點",
#     "美味冷凍微波佳餚",
#     "豐富冷凍微波菜餚",
#     "速食冷凍微波料理",
#     "精緻冷凍微波套餐",
#     "創意冷凍微波美食",
#     "口感冷凍微波食品",
#     "特色冷凍微波料理"
#   ]
# }
# 冷凍微波料理
# []
# ['新鮮冷凍微波食品', '營養冷凍微波料理', '健康冷凍微波美食', '方便冷凍微波餐點', '美味冷凍微波佳餚', '豐富冷凍微波菜餚', '速食冷凍微波料理', '精緻冷凍微波套餐', '創意冷凍微波美食', '口感冷凍微波食品', '特色冷凍微波料理']
# ----------
# [debug] prompt
# Please generate 11 product names for 保健/養生 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "活力養生補品",
#     "健康保健產品",
#     "美容養生口服液",
#     "抗衰老保健品",
#     "自然療法養生品",
#     "全方位營養保健品",
#     "健康長壽配方膠囊",
#     "天然保健食品",
#     "維他命補充品",
#     "舒緩壓力保健品",
#     "淨化身體排毒飲品"
#   ]
# }
# 保健/養生
# []
# ['活力養生補品', '健康保健產品', '美容養生口服液', '抗衰老保健品', '自然療法養生品', '全方位營養保健品', '健康長壽配方膠囊', '天然保健食品', '維他命補充品', '舒緩壓力保健品', '淨化身體排毒飲品']
# ----------
# [debug] prompt
# Please generate 11 product names for 美肌/纖體 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "絲滑嫩膚霜",
#     "水漾肌膚保濕液",
#     "緊緻身體霜",
#     "柔膚卸妝油",
#     "深層滋潤乳液",
#     "亮白美肌面膜",
#     "纖體霜",
#     "煥膚修護精油",
#     "美肌洗面乳",
#     "塑身霜",
#     "淨白精華液"
#   ]
# }
# 美肌/纖體
# []
# ['絲滑嫩膚霜', '水漾肌膚保濕液', '緊緻身體霜', '柔膚卸妝油', '深層滋潤乳液', '亮白美肌面膜', '纖體霜', '煥膚修護精油', '美肌洗面乳', '塑身霜', '淨白精華液']
# ----------
# [debug] prompt
# Please generate 11 product names for 醫材/藥品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "醫療儀器",
#     "生物藥品",
# ...
#     "優雅紳士童裝",
#     "可愛公主童裝"
#   ]
# }
# 童裝
# []
# ['可愛小狗圖案童裝', '卡通動物印花童裝', '時尚潮流童裝', '經典格紋童裝', '甜美花朵圖案童裝', '運動風格童裝', '夏日清涼童裝', '冬日保暖童裝', '可愛卡通角色童裝', '優雅紳士童裝', '可愛公主童裝']
# ----------
# [debug] prompt
# Please generate 11 product names for 女裝 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "優雅花朵洋裝",
#     "時尚牛仔褲",
#     "迷人紗裙",
#     "經典黑色西裝",
#     "甜美荷葉邊上衣",
#     "舒適運動套裝",
#     "知性格紋襯衫",
#     "高貴晚禮服",
#     "魅力露肩洋裝",
#     "清新連身裙",
#     "可愛泳衣"
#   ]
# }
# 女裝
# []
# ['優雅花朵洋裝', '時尚牛仔褲', '迷人紗裙', '經典黑色西裝', '甜美荷葉邊上衣', '舒適運動套裝', '知性格紋襯衫', '高貴晚禮服', '魅力露肩洋裝', '清新連身裙', '可愛泳衣']
# ----------
# [debug] prompt
# Please generate 11 product names for 男裝 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "潮流百搭男裝外套",
#     "時尚休閒男裝襯衫",
#     "經典風格男裝西裝",
#     "舒適日常男裝長褲",
#     "時尚潮牌男裝運動鞋",
#     "品味大方男裝背心",
#     "時尚簡約男裝T恤",
#     "個性搶眼男裝配件",
#     "商務正裝男裝皮鞋",
#     "時尚街頭男裝帽子",
#     "舒適休閒男裝短褲"
#   ]
# }
# 男裝
# []
# ['潮流百搭男裝外套', '時尚休閒男裝襯衫', '經典風格男裝西裝', '舒適日常男裝長褲', '時尚潮牌男裝運動鞋', '品味大方男裝背心', '時尚簡約男裝T恤', '個性搶眼男裝配件', '商務正裝男裝皮鞋', '時尚街頭男裝帽子', '舒適休閒男裝短褲']
# ----------
# [debug] prompt
# Please generate 11 product names for 個人服飾配件 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "時尚項鍊",
#     "可愛耳環",
#     "流行手錶",
#     "潮流帽子",
#     "獨特眼鏡",
#     "時尚手套",
#     "迷人腰帶",
#     "舒適襪子",
#     "時尚圍巾",
#     "個性手帕",
#     "高品質手提包"
#   ]
# }
# 個人服飾配件
# []
# ['時尚項鍊', '可愛耳環', '流行手錶', '潮流帽子', '獨特眼鏡', '時尚手套', '迷人腰帶', '舒適襪子', '時尚圍巾', '個性手帕', '高品質手提包']
# ----------
# [debug] prompt
# Please generate 11 product names for 運動機能服飾 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "運動爽快快乾服",
#     "透氣輕盈運動T恤",
#     "功能高效運動褲",
#     "防風透氣運動外套",
#     "高彈力運動緊身衣",
#     "舒適吸濕運動襪",
#     "防曬透氣運動帽",
#     "防水防風運動手套",
#     "排汗透氣運動頭帶",
#     "防滑運動手套",
#     "運動保護護具"
#   ]
# }
# 運動機能服飾
# []
# ['運動爽快快乾服', '透氣輕盈運動T恤', '功能高效運動褲', '防風透氣運動外套', '高彈力運動緊身衣', '舒適吸濕運動襪', '防曬透氣運動帽', '防水防風運動手套', '排汗透氣運動頭帶', '防滑運動手套', '運動保護護具']
# ----------
# [debug] prompt
# Please generate 11 product names for 鑽石 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "璀璨之星",
#     "閃亮之夢",
#     "無瑕寶石",
#     "冰晶之愛",
#     "耀眼之光",
#     "夢幻鑽石",
#     "光芒四射",
#     "閃耀之星",
#     "絕美鑽石",
#     "閃亮之星",
#     "星光閃耀"
#   ]
# }
# 鑽石
# []
# ['璀璨之星', '閃亮之夢', '無瑕寶石', '冰晶之愛', '耀眼之光', '夢幻鑽石', '光芒四射', '閃耀之星', '絕美鑽石', '閃亮之星', '星光閃耀']
# ----------
# [debug] prompt
# Please generate 11 product names for 珠寶／玉石 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "翡翠手鍊",
#     "黃金戒指",
#     "鑽石耳環",
#     "琥珀吊墜",
#     "翡翠佛牌",
#     "珍珠項鍊",
#     "紅寶石戒指",
#     "翡翠手鐲",
#     "玉石手鍊",
#     "鑽石手鐲",
#     "琥珀手鍊"
#   ]
# }
# 珠寶／玉石
# []
# ['翡翠手鍊', '黃金戒指', '鑽石耳環', '琥珀吊墜', '翡翠佛牌', '珍珠項鍊', '紅寶石戒指', '翡翠手鐲', '玉石手鍊', '鑽石手鐲', '琥珀手鍊']
# ----------
# [debug] prompt
# Please generate 11 product names for 精品／飾品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "經典時尚項鍊",
#     "時尚鑽石手鍊",
#     "精緻銀飾手鍊",
#     "高級水晶耳環",
#     "流行韓國彩妝",
#     "品味潮流腕錶",
#     "奢華手工皮包",
#     "優雅珠寶戒指",
#     "時尚墨鏡",
#     "迷人絲巾",
#     "時尚手錶盒"
#   ]
# }
# 精品／飾品
# []
# ['經典時尚項鍊', '時尚鑽石手鍊', '精緻銀飾手鍊', '高級水晶耳環', '流行韓國彩妝', '品味潮流腕錶', '奢華手工皮包', '優雅珠寶戒指', '時尚墨鏡', '迷人絲巾', '時尚手錶盒']
# ----------
# [debug] prompt
# Please generate 11 product names for 手錶 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "時尚機械手錶",
#     "經典商務手錶",
#     "運動數位手錶",
#     "精緻女士手錶",
#     "個性學生手錶",
#     "豪華鑽石手錶",
#     "簡約時尚手錶",
#     "浪漫情侶手錶",
#     "時尚智能手錶",
#     "高端商務手錶",
#     "迷人腕錶"
#   ]
# }
# 手錶
# []
# ['時尚機械手錶', '經典商務手錶', '運動數位手錶', '精緻女士手錶', '個性學生手錶', '豪華鑽石手錶', '簡約時尚手錶', '浪漫情侶手錶', '時尚智能手錶', '高端商務手錶', '迷人腕錶']
# ----------
# [debug] prompt
# Please generate 11 product names for 黃金 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "黃金手鍊",
#     "黃金項鍊",
#     "黃金戒指",
#     "黃金耳環",
#     "黃金手錶",
#     "黃金吊墜",
#     "黃金頭飾",
#     "黃金手帶",
#     "黃金手機殼",
#     "黃金筆記本",
#     "黃金香水"
#   ]
# }
# 黃金
# []
# ['黃金手鍊', '黃金項鍊', '黃金戒指', '黃金耳環', '黃金手錶', '黃金吊墜', '黃金頭飾', '黃金手帶', '黃金手機殼', '黃金筆記本', '黃金香水']
# ----------
# [debug] prompt
# Please generate 11 product names for 家飾 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {"product_name": ["綠意盆栽", "時尚擺設", "日式壁掛", "簡約時鐘", "創意畫框", "個性燈飾", "風格壁貼", "可愛抱枕", "迷人花瓶", "舒適地毯", "悠閒風鈴"]}
# 家飾
# []
# ['綠意盆栽', '時尚擺設', '日式壁掛', '簡約時鐘', '創意畫框', '個性燈飾', '風格壁貼', '可愛抱枕', '迷人花瓶', '舒適地毯', '悠閒風鈴']
# ----------
# [debug] prompt
# Please generate 11 product names for 寢具 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "柔軟羽絨被",
#     "舒適記憶枕",
#     "純棉床包組",
#     "溫暖電熱毯",
#     "涼爽夏季涼被",
#     "舒適羽絨枕",
#     "保護床套",
#     "透氣床墊",
#     "溫暖毯子",
#     "柔軟抱枕",
#     "舒適睡眠枕"
#   ]
# }
# 寢具
# []
# ['柔軟羽絨被', '舒適記憶枕', '純棉床包組', '溫暖電熱毯', '涼爽夏季涼被', '舒適羽絨枕', '保護床套', '透氣床墊', '溫暖毯子', '柔軟抱枕', '舒適睡眠枕']
# ----------
# [debug] prompt
# Please generate 11 product names for 傢俱 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "优雅床",
#     "简约桌椅",
#     "时尚沙发",
#     "舒适座椅",
#     "实用书柜",
#     "美观装饰架",
#     "多功能衣柜",
#     "高品质地毯",
#     "现代风格橱柜",
#     "创意餐桌",
#     "经典电视柜"
#   ]
# }
# 傢俱
# []
# ['优雅床', '简约桌椅', '时尚沙发', '舒适座椅', '实用书柜', '美观装饰架', '多功能衣柜', '高品质地毯', '现代风格橱柜', '创意餐桌', '经典电视柜']
# ----------
# [debug] prompt
# Please generate 11 product names for 床墊 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_names": [
#     "夢幻麵包床墊",
#     "綠意森林床墊",
#     "精選乳膠床墊",
#     "舒適雲朵床墊",
#     "時尚流行床墊",
#     "淨淨寶寶床墊",
#     "奢華浪漫床墊",
#     "健康保護床墊",
#     "超薄防水床墊",
#     "純棉透氣床墊",
#     "高彈力彈簧床墊"
#   ]
# }
#
# [debug] prompt
# Please generate 11 product names for 床墊 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "舒適睡眠床墊",
#     "高回彈床墊",
#     "純棉床墊",
#     "記憶床墊",
#     "手工編織床墊",
#     "冷感床墊",
#     "超輕質床墊",
#     "全天然床墊",
#     "防水床墊",
#     "椰棕床墊",
#     "羽絨床墊"
#   ]
# }
# 床墊
# []
# ['舒適睡眠床墊', '高回彈床墊', '純棉床墊', '記憶床墊', '手工編織床墊', '冷感床墊', '超輕質床墊', '全天然床墊', '防水床墊', '椰棕床墊', '羽絨床墊']
# ----------
# [debug] prompt
# Please generate 11 product names for 燈具 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "綠意燈光",
#     "奢華水晶燈",
#     "北歐風吊燈",
#     "復古工業燈",
#     "現代風格燈具",
#     "簡約設計燈",
#     "創意懸浮燈",
#     "經典台燈",
#     "迷你個性燈",
#     "藝術壁燈",
#     "風情車床燈"
#   ]
# }
# 燈具
# []
# ['綠意燈光', '奢華水晶燈', '北歐風吊燈', '復古工業燈', '現代風格燈具', '簡約設計燈', '創意懸浮燈', '經典台燈', '迷你個性燈', '藝術壁燈', '風情車床燈']
# ----------
# [debug] prompt
# Please generate 11 product names for 菸品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "雲煙魅力",
#     "玫瑰香煙",
#     "清新薄荷",
#     "經典紅標",
#     "煙酒組合",
#     "綠色健康",
#     "夜色濃煙",
#     "特製混合",
#     "煙花盛宴",
#     "藍色海洋",
#     "黃金時光"
#   ]
# }
# 菸品
# []
# ['雲煙魅力', '玫瑰香煙', '清新薄荷', '經典紅標', '煙酒組合', '綠色健康', '夜色濃煙', '特製混合', '煙花盛宴', '藍色海洋', '黃金時光']
# ----------
# [debug] prompt
# Please generate 11 product names for 威士忌 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "金牌威士忌",
#     "香檳威士忌",
#     "紅酒威士忌",
#     "蘋果威士忌",
#     "辣椒威士忌",
#     "巧克力威士忌",
#     "橡木桶威士忌",
#     "檸檬威士忌",
#     "咖啡威士忌",
#     "松露威士忌",
#     "蜂蜜威士忌"
#   ]
# }
# 威士忌
# []
# ['金牌威士忌', '香檳威士忌', '紅酒威士忌', '蘋果威士忌', '辣椒威士忌', '巧克力威士忌', '橡木桶威士忌', '檸檬威士忌', '咖啡威士忌', '松露威士忌', '蜂蜜威士忌']
# ----------
# [debug] prompt
# Please generate 11 product names for 清酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "櫻花",
#     "龍泉",
#     "富士山",
#     "雲海",
#     "黃金時代",
#     "銀河",
#     "秋之露",
#     "櫻花風味",
#     "純米",
#     "獨山子",
#     "酒藏"
#   ]
# }
# 清酒
# []
# ['櫻花', '龍泉', '富士山', '雲海', '黃金時代', '銀河', '秋之露', '櫻花風味', '純米', '獨山子', '酒藏']
# ----------
# [debug] prompt
# Please generate 11 product names for 調酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "酒館桃園",
#     "星光綠洲",
#     "金色夢幻",
#     "醉心檸檬",
#     "夜空之吻",
#     "琥珀之舞",
#     "綠茶甘露",
#     "櫻花之恋",
#     "琥珀咖啡",
#     "藍色熱情",
#     "紅石榴"
#   ]
# }
# 調酒
# []
# ['酒館桃園', '星光綠洲', '金色夢幻', '醉心檸檬', '夜空之吻', '琥珀之舞', '綠茶甘露', '櫻花之恋', '琥珀咖啡', '藍色熱情', '紅石榴']
# ----------
# [debug] prompt
# Please generate 11 product names for 啤酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {"product_name": ["雪花啤酒", "台灣啤酒", "麒麟啤酒", "燕京啤酒", "易初軒啤酒", "珍禽啤酒", "福佳麥啤酒", "青島啤酒", "哈爾濱啤酒", "百威啤酒", "金牛啤酒"]}
# 啤酒
# []
# ['雪花啤酒', '台灣啤酒', '麒麟啤酒', '燕京啤酒', '易初軒啤酒', '珍禽啤酒', '福佳麥啤酒', '青島啤酒', '哈爾濱啤酒', '百威啤酒', '金牛啤酒']
# ----------
# [debug] prompt
# Please generate 11 product names for 紅白酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "紅白酒融合",
#     "雙色紅白酒",
#     "紅白交融",
#     "紅白酒結合",
#     "紅白酒搭配",
#     "紅白酒混合",
#     "紅白酒融和",
#     "紅白酒匹配",
#     "紅白酒相融",
#     "紅白酒和諧",
#     "紅白酒互補"
#   ]
# }
# 紅白酒
# []
# ['紅白酒融合', '雙色紅白酒', '紅白交融', '紅白酒結合', '紅白酒搭配', '紅白酒混合', '紅白酒融和', '紅白酒匹配', '紅白酒相融', '紅白酒和諧', '紅白酒互補']
# ----------
# [debug] prompt
# Please generate 11 product names for 香檳氣泡酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "馥郁香檳氣泡酒",
#     "經典香檳氣泡酒",
#     "精選香檳氣泡酒",
#     "特級香檳氣泡酒",
#     "極品香檳氣泡酒",
#     "尊貴香檳氣泡酒",
#     "珍藏香檳氣泡酒",
#     "限量香檳氣泡酒",
#     "純正香檳氣泡酒",
#     "頂級香檳氣泡酒",
#     "優雅香檳氣泡酒"
#   ]
# }
# 香檳氣泡酒
# []
# ['馥郁香檳氣泡酒', '經典香檳氣泡酒', '精選香檳氣泡酒', '特級香檳氣泡酒', '極品香檳氣泡酒', '尊貴香檳氣泡酒', '珍藏香檳氣泡酒', '限量香檳氣泡酒', '純正香檳氣泡酒', '頂級香檳氣泡酒', '優雅香檳氣泡酒']
# ----------
# [debug] prompt
# Please generate 11 product names for 藥酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "藥酒醉仙草",
#     "藥酒安神酒",
#     "藥酒活血酒",
#     "藥酒百年陳釀",
#     "藥酒舒筋活絡",
#     "藥酒壯陽酒",
#     "藥酒滋陰酒",
#     "藥酒抗疲勞酒",
#     "藥酒益氣酒",
#     "藥酒滋補酒",
#     "藥酒調理酒"
#   ]
# }
# 藥酒
# []
# ['藥酒醉仙草', '藥酒安神酒', '藥酒活血酒', '藥酒百年陳釀', '藥酒舒筋活絡', '藥酒壯陽酒', '藥酒滋陰酒', '藥酒抗疲勞酒', '藥酒益氣酒', '藥酒滋補酒', '藥酒調理酒']
# ----------
# [debug] prompt
# Please generate 11 product names for 高粱 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "高粱大米",
#     "高粱糖",
#     "高粱酒",
#     "高粱麵",
#     "高粱粉",
#     "高粱麥片",
#     "高粱油",
#     "高粱茶",
#     "高粱脆片",
#     "高粱蔬菜",
#     "高粱果醬"
#   ]
# }
# 高粱
# []
# ['高粱大米', '高粱糖', '高粱酒', '高粱麵', '高粱粉', '高粱麥片', '高粱油', '高粱茶', '高粱脆片', '高粱蔬菜', '高粱果醬']
# ----------
# [debug] prompt
# Please generate 11 product names for 禮盒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name:  .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
#
# The json result is:
#
# [debug] content {
#   "product_name": [
#     "浪漫之夜禮盒",
#     "精緻茶禮盒",
#     "美食探索禮盒",
#     "健康生活禮盒",
#     "芳香浴品禮盒",
#     "精美文具禮盒",
#     "迎新春禮盒",
#     "甜蜜婚禮禮盒",
#     "家庭廚房禮盒",
#     "慶生禮盒",
#     "旅行必備禮盒"
#   ]
# }
# 禮盒
# []
# ['浪漫之夜禮盒', '精緻茶禮盒', '美食探索禮盒', '健康生活禮盒', '芳香浴品禮盒', '精美文具禮盒', '迎新春禮盒', '甜蜜婚禮禮盒', '家庭廚房禮盒', '慶生禮盒', '旅行必備禮盒']
# ----------

# %%
with open('workflow_asset/catogory_generate.json', 'w') as f:
    f.write((json.dumps(generated)))

# %%
1
