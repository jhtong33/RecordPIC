# %%
import pandas as pd

# %%
df_pic = pd.read_csv('data/category.csv')

# %%
df_momo = pd.read_csv('data/category_momo.csv', index_col=0)

# %% [markdown]
# # 大分類

# %%
for i in sorted(set(df_pic.item_type)):
    print(i)
# Out:
# 3C類
# 乳品類
# 保健食品類
# 傢俱/家飾類
# 冰品類
# 冷凍食品類
# 咖啡類
# 家電類
# 寵物用品類
# 戶外休閒用品類
# 日用百貨類
# 書本/文教用品類
# 服飾鞋包類
# 民生食材類
# 水類
# 洗浴清潔/保養類
# 烘焙/甜點類
# 生鮮食品類
# 禮盒類
# 精品類
# 菸酒類
# 蛋品類
# 豆米漿/植物奶
# 飲料類
# 鮮食類
# 點心/零食類

# %%
for i in sorted(set(df_momo.tier1_category_name)):
    print(i)
# Out:
# 修繕園藝
# 傢飾寢具
# 內衣
# 加值/軟體
# 圖書影音
# 宗教/藝術
# 家電
# 戶外用品
# 手機/相機
# 文具樂器
# 旅遊/住宿
# 服飾
# 母嬰玩具
# 票券
# 車
# 運動/按摩
# 鞋包箱

# %%
set(df_momo.tier2_category_name)
# Out:
# {'3C福利品',
#  'Apple週邊',
#  'GPS/行車紀錄',
#  'MyBook電子書',
#  '一般手機',
#  '五金工具',
#  '人文史地',
#  '健身器材',
#  '冰箱',
#  '商業理財',
#  '國外旅遊',
#  '地板/裝潢',
#  '宗教命理',
#  '居安防護',
#  '廚房設備',
#  '影音',
#  '心理勵志',
#  '戶外露營',
#  '手機/平板殼貼',
#  '按摩器材',
#  '按摩椅',
#  '擺飾/壁飾',
#  '政府出版/教科書',
#  '數位加值/遊戲',
#  '文具用品',
#  '文學小說',
#  '旅遊',
#  '書店排行榜',
#  '有聲書',
#  '桌遊',
#  '樂器',
#  '模型/公仔/動漫',
#  '機車/用品',
#  '毛巾/浴巾',
#  '水上運動',
#  '汽車百貨',
#  '沙發墊/坐墊/抱枕',
#  '油漆',
#  '泡腳機/桑拿屋',
#  '泳裝/比基尼',
#  '漫畫',
#  '烤肉/野餐',
#  '燈泡/燈飾',
#  '玩樂/生活券',
#  '球類運動',
#  '瑜珈/體適能',
#  '生活風格',
#  '登山健行',
#  '社會科學',
#  '積木',
#  '童書/教具',
#  '美容舒壓券',
#  '美食餐券',
#  '考試用書',
#  '自然科普',
#  '自行車',
#  '花束園藝',
#  '藝術品/禮品',
#  '藝術設計',
#  '衛浴設備',
#  '親子教養',
#  '語言學習',
#  '軍迷用品',
#  '輕小說',
#  '辦公用品',
#  '運動護具',
#  '運動鞋',
#  '運動館',
#  '醫療保健',
#  '重量訓練器材',
#  '釣具',
#  '開運風水',
#  '陸上運動',
#  '雜誌訂閱',
#  '雨傘/雨衣',
#  '電動工具',
#  '電動車/滑板',
#  '電腦資訊',
#  '電腦軟體',
#  '飯店/住宿券',
#  '飲食',
#  '香品/祈福/親算'}

# %%
set(df_pic.category)
# Out:
# {'三明治',
#  '中式糕點',
#  '仙草/愛玉',
#  '保久乳',
#  '保健/養生',
#  '個人服飾配件',
#  '傢俱',
#  '優格',
#  '優酪乳',
#  '其他冰品',
#  '其他冷凍商品',
#  '其他寵物食品',
#  '其他日用百貨',
#  '其他植物奶',
#  '其他民生食材',
#  '其他現調飲品',
#  '其他甜食',
#  '其他生鮮食品',
#  '其他零食',
#  '其他鮮食商品',
#  '冰塊',
#  '冰棒/雪糕',
#  '冰淇淋',
#  '冷凍微波料理',
#  '冷凍水果',
#  '冷凍水餃/點心類',
#  '冷凍海鮮',
#  '冷凍肉品',
#  '冷凍蔬菜',
#  '冷藏調理',
#  '加工蛋',
#  '南北乾貨/雜糧食材',
#  '即溶咖啡',
#  '即飲甜品',
#  '口腔保健',
#  '口香糖',
#  '各式麵條/拌麵',
#  '咖啡相關食用品',
#  '品牌鞋款',
#  '啤酒',
#  '地瓜',
#  '堅果',
#  '報紙',
#  '大型家電',
#  '女性衛生用品',
#  '女裝',
#  '奶粉',
#  '威士忌',
#  '嬰幼兒用品',
#  '嬰幼兒食品',
#  '家庭清潔洗劑',
#  '家庭清潔用品',
#  '家飾',
#  '寢具',
#  '寵物用品',
#  '小菜/滷味',
#  '巧克力',
#  '布丁/果凍',
#  '床墊',
#  '廚房家電',
#  '彩妝/卸妝',
#  '戶外露營',
#  '手機/通訊/週邊',
#  '手錶',
#  '數位內容',
#  '文教用品',
#  '料理調味',
#  '晴雨相關用具',
#  '書籍',
#  '有機食品',
#  '果乾',
#  '果汁/果醋飲',
#  '果醬/抹醬',
#  '桌機/筆電/平板',
#  '機能水',
#  '民生紙品',
#  '氣泡水',
#  '水果冰品',
#  '水餃/點心',
#  '汽機車用品類',
#  '沖泡即食品',
#  '沖泡式咖啡',
#  '沖泡類飲品',
#  '油',
#  '泡麵',
#  '洗衣用具',
#  '流行鞋襪',
#  '海苔',
#  '清酒',
# ...

# %%
df_pic
# Out:
#     item_type category                                        description
# 0         咖啡類   現做咖啡飲品                                 從咖啡廳、超商、超市中現煮的咖啡商品  \
# 1         咖啡類  罐裝/瓶裝咖啡                                使用鋁罐或寶特瓶裝可馬上飲用的咖啡液體
# 2         咖啡類    沖泡式咖啡                                      多合一的沖泡式咖啡(粉末)
# 3         咖啡類    濾掛式咖啡                                            使用濾掛的咖啡
# 4         咖啡類     即溶咖啡               具有顆粒加水便可馬上融化的咖啡，通常為罐裝。(排除多合一且多數為黑咖啡)
# ..        ...      ...                                                ...
# 171       菸酒類      紅白酒  在商店販賣的葡萄酒，紅酒由葡萄製成，白酒由白葡萄製成，可參考https://www.nmpl...
# 172       菸酒類    香檳氣泡酒  在商店販賣的香檳或有發泡性的酒，可參考https://www.my9.com.tw/coll...
# 173       菸酒類       藥酒  將藥物置於75％酒精或白酒中浸泡而成的保健食品(這邊暫時歸類在酒類，後續調整至保健食品類)，...
# 174       菸酒類       高粱  如類別名稱，可參考https://www.my9.com.tw/collections/ba...
# 175       禮盒類       禮盒                                  只要商品被組合成禮盒，就歸在這一類
#
#                          item1                                  item2
# ...
