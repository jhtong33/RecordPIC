# %%
import pandas as pd
df = pd.read_csv('data/samples.csv', index_col=0)
dfc = pd.read_csv('data/category.csv')

# %%
pd.options.display.max_rows=300

# %%
dfc[dfc.item_type=='點心/零食類']
# Out:
#    item_type category               description                  item1
# 80    點心/零食類       餅乾                包含鹹甜等口味的餅乾                   蘇打餅乾  \
# 81    點心/零食類       堅果                   乾燥堅果類商品                萬歲牌起司堅果
# 82    點心/零食類    肉乾/肉紙                  乾燥加工肉類商品                    牛肉乾
# 83    點心/零食類       豆乾         由豆腐經過脫水、壓縮製成的豆乾商品                   五香豆乾
# 84    點心/零食類      魷魚絲   乾燥、切絲、調味的海鮮產品，大多魷魚或墨魚製成                   鱈魚香絲
# 85    點心/零食類       海苔                      海苔商品                    元本山
# 86    點心/零食類    布丁/果凍    添加凝固劑（如吉利丁、果凍粉、洋菜粉）的甜品  舉杯低卡蒟蒻凍機能款396g(4盒24根)
# 87    點心/零食類       果乾               乾燥水果食品、醃漬水果    義美太陽牌加州梅340g(340公克)
# 88    點心/零食類      蔬片乾           乾燥脫水或油炸根莖類、蔬菜食品     南瓜先生-芥末南瓜脆片70g 三入組
# 89    點心/零食類     即飲甜品              有附湯匙的罐裝拜拜用甜點       【泰山】八寶粥375gx6入/組
# 90    點心/零食類       糖果                     硬糖、軟糖                寶潤無糖潤喉糖
# 91    點心/零食類      巧克力             巧克力球、可可塊、巧克力塊     堅果乳加-178g(屏東可可 乳加)
# 92    點心/零食類      口香糖  供咀嚼而不是吞食的糖果，以及訴求為口氣清新的硬糖        無糖口香糖-極酷嗆涼薄荷62g
# 93    點心/零食類     其他零食              不屬於81到93類之零食               低卡纖果棒30g
#
#                                   item2
# 80                        波的多洋芋片(蚵仔煎口味)
# 81                              盛香珍葵香瓜子
# 82                                  牛肉條
# 83                                 沙茶豆乾
# 84                                  魷魚片
# 85                                  烤海苔
# 86         【台灣森永】威德in果凍-180gx24入/盒(維他命)
# 87                 真甘純草莓35g(冷凍真空乾燥整顆草莓)
# 88                            連城記地瓜酥-黑糖
# 89                    【愛之味】牛奶花生340gx12入
# 90                            聖祖貢糖】原味貢糖
# 91                    【Twix特趣】迷你焦糖夾心巧克力
# 92                【Eclipse 易口舒】無糖薄荷錠2入裝
# 93  長榮生醫】L-阿拉伯糖高鈣乳酪絲-超值組(原味12包組/乳酪絲/零食)

# %%
list(df.category.drop_duplicates())
# Out:
# ['各式麵條/拌麵',
#  '南北乾貨/雜糧食材',
#  '料理調味',
#  '果醬/抹醬',
#  '有機食品',
#  '泡麵',
#  '米',
#  '罐頭',
#  '嬰幼兒食品',
#  '其他民生食材',
#  '沖泡即食品',
#  '奶粉',
#  '油',
#  '女性衛生用品',
#  '口腔保健',
#  '彩妝/卸妝',
#  '美容保養',
#  '男性用品/保養',
#  '髮部清潔/保養',
#  '身體清潔/保養',
#  '中式糕點',
#  '其他甜食',
#  '麵包',
#  '蛋糕',
#  '氣泡水',
#  '礦泉水',
#  '機能水',
#  '傢俱',
#  '寢具',
#  '家飾',
#  '床墊',
#  '燈具',
#  '啤酒',
#  '威士忌',
#  '紅白酒',
#  '清酒',
#  '菸品',
#  '藥酒',
#  '香檳氣泡酒',
#  '調酒',
#  '高粱',
#  '三明治',
#  '地瓜',
#  '水餃/點心',
#  '小菜/滷味',
#  '湯品',
#  '漢堡',
#  '米飯類',
#  '熱狗',
#  '蒸箱食品',
#  '關東煮',
#  '麵食類',
#  '其他鮮食商品',
#  '生鮮蔬果/沙拉',
#  '茶葉蛋/水煮蛋',
#  '雞胸肉',
#  '肉品',
#  '戶外露營',
#  '行李箱/配件',
#  '運動健身',
#  '手機/通訊/週邊',
#  '個人服飾配件',
#  '女裝',
#  '品牌鞋款',
#  '童裝',
#  '流行鞋襪',
#  '男女內著',
#  '男裝',
#  '運動機能服飾',
#  '沖泡類飲品',
#  '碳酸/汽水',
#  '果汁/果醋飲',
#  '現做茶飲品',
#  '運動飲料',
#  '能量飲料',
#  '其他現調飲品',
#  '特殊風味飲品',
#  '茶飲',
#  '現調果汁',
#  '養生飲品',
#  '桌機/筆電/平板',
#  '相機/攝影/DV',
#  '電腦螢幕/硬碟',
#  '虛擬/點數商品',
#  '週邊/耗材',
#  '加工蛋',
#  '生雞蛋',
#  '大型家電',
#  '廚房家電',
#  '視聽娛樂家電',
#  '美容家電',
#  '電池充電相關',
#  '生活家電',
#  '保久乳',
#  '優格',
#  '優酪乳',
#  '發酵乳',
#  '調味乳',
#  '鮮乳類',
#  '嬰幼兒用品',
#  '家庭清潔洗劑',
#  '汽機車用品類',
#  '家庭清潔用品',
#  '洗衣用具',
#  '餐廚用品',
#  '民生紙品',
#  '衣物清潔',
#  '晴雨相關用具',
#  '衛浴用品',
#  '其他日用百貨',
#  '冷凍微波料理',
#  '冷凍肉品',
#  '冷凍海鮮',
#  '冷凍蔬菜',
#  '其他冷凍商品',
#  '冷凍水果',
#  '火鍋用料',
#  '冷凍水餃/點心類',
#  '禮盒',
#  '冷藏調理',
#  '生鮮水果',
#  '生鮮海鮮',
#  '生鮮蔬菜',
#  '生鮮肉品',
#  '其他生鮮食品',
#  '豆腐',
#  '速食調理包',
#  '現做咖啡飲品',
#  '罐裝/瓶裝咖啡',
#  '沖泡式咖啡',
#  '即溶咖啡',
#  '濾掛式咖啡',
#  '咖啡相關食用品',
#  '書籍',
#  '文教用品',
#  '數位內容',
#  '報紙',
#  '保健/養生',
#  '醫材/藥品',
#  '美肌/纖體',
#  '堅果',
#  '其他零食',
#  '巧克力',
#  '布丁/果凍',
#  '即飲甜品',
#  '果乾',
#  '糖果',
#  '海苔',
#  '豆乾',
#  '魷魚絲',
#  '口香糖',
#  '肉乾/肉紙',
#  '餅乾',
#  '蔬片乾',
#  '其他寵物食品',
#  '寵物用品',
#  '狗食',
#  '貓食',
#  '其他植物奶',
#  '燕麥奶',
#  '豆漿',
#  '米漿',
#  '手錶',
#  '黃金',
#  '鑽石',
#  '精品／飾品',
#  '珠寶／玉石',
#  '冰淇淋',
#  '冰棒/雪糕',
#  '水果冰品',
#  '現做霜淇淋/聖代',
#  '甜筒',
#  '仙草/愛玉',
#  '現調冰品',
#  '其他冰品',
#  '冰塊']

# %%
dfc[dfc.category.apply(lambda x: '其他' in x or '其它' in x)]
# Out:
#     item_type category               description
# 16        飲料類   其他現調飲品                現調版的特殊風味飲品  \
# 29    豆米漿/植物奶    其他植物奶              不屬於27到29之植物奶
# 38        冰品類     其他冰品               有冰塊而不在上列的商品
# 54        鮮食類   其他鮮食商品              不在上述鮮食中分類的商品
# 58     烘焙/甜點類     其他甜食       派塔類和其他非56到58類之烘焙類甜食
# 68      生鮮食品類   其他生鮮食品            不在上述生鮮食品中分類的商品
# 76      冷凍食品類   其他冷凍商品              不在上述冷凍中分類的商品
# 93     點心/零食類     其他零食              不屬於81到93類之零食
# 106     民生食材類   其他民生食材        不屬於95到107類之可存放民生食材
# 117     日用百貨類   其他日用百貨  非108-117分類的日用百貨(ex. 收納 )
# 127     寵物用品類   其他寵物食品           非主流寵物(魚、兔、鳥)的食品
#
#                              item1                                item2
# 16                    可可風味小農鮮奶 (熱)                                 檸檬多多
# 29   【員山鄉農會】養生黑芝麻豆奶箱購(２５０ｍｌ＊２４瓶／箱)                             美國密蘇里鮮豆乳
# 38                            檸檬冰磚                           爆刨冰（哈密瓜風味）
# 54                           黃金玉米棒                                  玉米筍
# 58                           法式檸檬塔                             焦糖奶油夾心餅乾
# 68                              豆皮                                  甜不辣
# 76                              湯圓                                   披薩
# 93                        低卡纖果棒30g  長榮生醫】L-阿拉伯糖高鈣乳酪絲-超值組(原味12包組/乳酪絲/零食)
# 106           德國製PowR1乾糧 德軍採購同款(軍糧                                  MRE
# 117                 25面寬夾縫收納櫃(儲物櫃)                                   螺絲
# 127                    鸚鵡鳥飼料(650g)                     9合1烏龜飼料900ml(2罐)
