# %%
import boto3
boto3.client('sts').get_caller_identity()
# Out:
# {'UserId': 'AROAV52AN3HJJIZVUDZ2F:SageMaker',
#  'Account': '407620147666',
#  'Arn': 'arn:aws:sts::407620147666:assumed-role/role-ap-segemaker-execution-setopdata2.0-t/SageMaker',
#  'ResponseMetadata': {'RequestId': '4701395d-23a0-4e73-8b11-c9b55554fcbd',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4701395d-23a0-4e73-8b11-c9b55554fcbd',
#    'content-type': 'text/xml',
#    'content-length': '467',
#    'date': 'Wed, 09 Aug 2023 15:31:46 GMT'},
#   'RetryAttempts': 0}}

# %%
# Create session using your current creds
boto_sts=boto3.client('sts')

# Request to assume the role like this, the ARN is the Role's ARN from 
# the other account you wish to assume. Not your current ARN.
stsresponse = boto_sts.assume_role(
    RoleArn="arn:aws:iam::354925255288:role/test",
    RoleSessionName='newsession'
)

# Save the details from assumed role into vars
newsession_id = stsresponse["Credentials"]["AccessKeyId"]
newsession_key = stsresponse["Credentials"]["SecretAccessKey"]
newsession_token = stsresponse["Credentials"]["SessionToken"]

# %%
sm_client = boto3.client("sagemaker")
smr_client = boto3.client("sagemaker-runtime")

# %%
sm_client = boto3.client(
    'sagemaker',
    region_name='us-east-1',
    aws_access_key_id=newsession_id,
    aws_secret_access_key=newsession_key,
    aws_session_token=newsession_token
)

# %%
smr_client = boto3.client(
    'sagemaker-runtime',
    region_name='us-east-1',
    aws_access_key_id=newsession_id,
    aws_secret_access_key=newsession_key,
    aws_session_token=newsession_token
)

# %%
endpoint_name = 'huggingface-pytorch-tgi-inference-2023-08-09-14-15-39-283'

# %%
import sagemaker

# %%
sagemaker_session = sagemaker.session.Session(
    sagemaker_client=sm_client, 
    sagemaker_runtime_client=smr_client)

# %%
from sagemaker import serializers

# %%
from sagemaker import deserializers

# %%
llm = sagemaker.predictor.Predictor(
    endpoint_name=endpoint_name, 
    sagemaker_session=sagemaker_session, 
    serializer=serializers.JSONSerializer(),
    deserializers=deserializers.JSONDeserializer())

# %%
def build_llama2_prompt(messages):
    startPrompt = "<s>[INST] "
    endPrompt = " [/INST]"
    conversation = []
    for index, message in enumerate(messages):
        if message["role"] == "system" and index == 0:
            conversation.append(f"<<SYS>>\n{message['content']}\n<</SYS>>\n\n")
        elif message["role"] == "user":
            conversation.append(message["content"].strip())
        else:
            conversation.append(f" [/INST] {message.content}</s><s>[INST] ")

    return startPrompt + "".join(conversation) + endPrompt

# %%
import re
import json


class Llama270BGenerater:
    
    def __init__(self, llm, include_inputs=False):
        self.llm = llm
        self.include_inputs = include_inputs

        
    def predict(self, prompt):

        messages = [
          { "role": "system","content": prompt}
        ]


        # define question and add to messages
        # instruction = "What are some cool ideas to do in the summer?"
        # messages.append({"role": "user", "content": instruction})
        _prompt = self.build_llama2_prompt(messages)

        payload = {
          "inputs":  _prompt,
          "parameters": {
            "do_sample": True,
            "top_p": 0.6,
            "temperature": 0.01,
            "top_k": 50,
            "max_new_tokens": 1000,
            "repetition_penalty": 1.03,
            "stop": ["</s>"]
          }
        }
        
        # chat = llm.predict({"inputs": json.dumps(prompt)})
        chat = self.llm.predict(payload)
        
        ret = json.loads(chat)[0]["generated_text"]
        
        if not self.include_inputs:
            ret = ret[len(_prompt):]

        return ret
    
    @staticmethod
    def build_llama2_prompt(messages):
        startPrompt = "<s>[INST] "
        endPrompt = " [/INST]"
        conversation = []
        for index, message in enumerate(messages):
            if message["role"] == "system" and index == 0:
                conversation.append(f"<<SYS>>\n{message['content']}\n<</SYS>>\n\n")
            elif message["role"] == "user":
                conversation.append(message["content"].strip())
            else:
                conversation.append(f" [/INST] {message.content}</s><s>[INST] ")

        return startPrompt + "".join(conversation) + endPrompt



JSON_RE = re.compile(r'(\{.*\})')

class JsonExtract:
    
    def reply2result(self, reply: str) -> dict:

        json_str = JSON_RE.findall(reply.replace('\n', ' '))[0]
        ret = json.loads(json_str)
        return ret

    def result2products(self, result: dict, target_key='product_name') -> list[str]:
        assert target_key in result
        assert isinstance(result[target_key], list)

        ret = result[target_key]

        return ret

    def reply2products(self, reply:str) -> list[str]:
        
        result = self.reply2result(reply)
        ret = self.result2products(result)


        return ret

# %%
sample_generator = Llama270BGenerater(llm)

# %%
sample_generator.predict('hello!')
# Out:
# " Hello! It's nice to meet you. Is there something I can help you with or would you like to chat for a bit?"

# %%
instruction = '''
Please generate {n_samples} product names for {category} category.
1. Return the results in JSON format with the following key: "product_name".
2. Example product_name: {samples} .
3. Do not repeat inputs in the output.
4. Replied answer should be as diverse as possible.
5. Do not repeat answers.
6. Reply in Taiwan Chinese.
7. values with product_name is a list of product names.

The json result is: 
'''


class SampleAugumentation(JsonExtract):
    
    def __init__(self, sample_generator, instruction):
        self.sample_generator = sample_generator
        self.instruction = instruction
        
    def _sample_generate(self, category:str, samples:list, n_samples:int=10, debug=False):
        
        n_provided_samples = len(samples)
        
        samples = list(map(lambda x: '"{}",'.format(x.replace('"', '')), samples))
        samples = ' '.join(samples)
        
        prompt = self.instruction.format(category=category, samples=samples, n_samples=n_samples+n_provided_samples)
        response = self.sample_generator.predict(prompt)
        content = response
        # content = response.to_dict()['choices'][0]['message']['content']
        
        complete = prompt+content
        
        print('[debug]', 'prompt', prompt)
        print('[debug]', 'content', content)
        
        ret = self.reply2products(complete)[n_provided_samples:]
        
        return ret
    
    def sample_generate(self, category:str, samples:list, n_samples:int=10):
        debug = False
        while True:
            try:
                return self._sample_generate(category=category, samples=samples, n_samples=n_samples, debug=debug)
            except Exception as e:
                debug = True
                print(e)

# %%
sa = SampleAugumentation(sample_generator, instruction)

# %%
with open('workflow_asset/catogory_sample.json', 'r') as f:
    config = json.loads(f.read())

# %%
n_samples = 11
generated = dict()
for k, v in config.items():
    gen_samples = sa.sample_generate(category=k, samples=v, n_samples=n_samples)
    generated[k] = gen_samples
    
    print(k)
    print(v)
    print(gen_samples)
    
    print('----------')
# Out:
# [debug] prompt
# Please generate 13 product names for 現做咖啡飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "全家特濃拿鐵", "西西里風味檸檬氣泡咖啡", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "珍珠奶茶",
# "迷你拿鐵",
# "冰霜咖啡",
# "豆漿奶粉咖啡",
# "綠茶 latte",
# "卡布奇諾",
# "檸檬綠茶",
# "椰奶咖啡",
# "芋頭咖啡",
# "奶粉綠茶",
# "紅豆奶茶",
# "咖啡奶粉",
# "拿鐵奶粉"
# ]
# }
# 現做咖啡飲品
# ['全家特濃拿鐵', '西西里風味檸檬氣泡咖啡']
# ['冰霜咖啡', '豆漿奶粉咖啡', '綠茶 latte', '卡布奇諾', '檸檬綠茶', '椰奶咖啡', '芋頭咖啡', '奶粉綠茶', '紅豆奶茶', '咖啡奶粉', '拿鐵奶粉']
# ----------
# [debug] prompt
# Please generate 13 product names for 罐裝/瓶裝咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "《UCC》無糖咖啡飲料185g", "SANGARIA 圓潤咖啡飲料-拿鐵 (280gx24入)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑞穗咖啡飲料280g",
# "SANGARIA 圓潤咖啡飲料-拿鐵 (280gx24入)",
# "《UCC》無糖咖啡飲料185g",
# "咖啡世家 咖啡飲料280g",
# "卡夫 咖啡飲料280g",
# "可口可樂 咖啡飲料280g",
# "咖啡熱 咖啡飲料280g",
# "咖啡廳 咖啡飲料280g",
# "咖啡聚 咖啡飲料280g",
# "咖啡樂 咖啡飲料280g",
# "咖啡珍 咖啡飲料280g",
# "咖啡萊 咖啡飲料280g"
# ]
# }
# 罐裝/瓶裝咖啡
# ['《UCC》無糖咖啡飲料185g', 'SANGARIA 圓潤咖啡飲料-拿鐵 (280gx24入)']
# ['《UCC》無糖咖啡飲料185g', '咖啡世家 咖啡飲料280g', '卡夫 咖啡飲料280g', '可口可樂 咖啡飲料280g', '咖啡熱 咖啡飲料280g', '咖啡廳 咖啡飲料280g', '咖啡聚 咖啡飲料280g', '咖啡樂 咖啡飲料280g', '咖啡珍 咖啡飲料280g', '咖啡萊 咖啡飲料280g']
# ----------
# [debug] prompt
# Please generate 13 product names for 沖泡式咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "西雅圖即品拿鐵無加糖2合1咖啡21g", "【King Coffee 王者咖啡】經典風味推薦組：三合一滴滴煉奶即溶咖啡", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瘋狂咖啡無糖2合1咖啡18g",
# "咖啡統治王者濃縮奶精2合1咖啡20g",
# "即溶奶精統一滴滴煉咖啡19g",
# "奶精統一濃縮咖啡2合1咖啡25g",
# "瘋狂咖啡統一滴滴煉咖啡21g",
# "咖啡統治王者濃縮奶精2合1咖啡20g",
# "即溶奶精統一滴滴煉咖啡19g",
# "奶精統一濃縮咖啡2合1咖啡25g",
# "瘋狂咖啡無糖2合1咖啡18g",
# "咖啡統治王者濃縮奶精2合1咖啡20g",
# "即溶奶精統一滴滴煉咖啡19g",
# "奶精統一濃縮咖啡2合1咖啡25g"
# ]
# }
# 沖泡式咖啡
# ['西雅圖即品拿鐵無加糖2合1咖啡21g', '【King Coffee 王者咖啡】經典風味推薦組：三合一滴滴煉奶即溶咖啡']
# ['即溶奶精統一滴滴煉咖啡19g', '奶精統一濃縮咖啡2合1咖啡25g', '瘋狂咖啡統一滴滴煉咖啡21g', '咖啡統治王者濃縮奶精2合1咖啡20g', '即溶奶精統一滴滴煉咖啡19g', '奶精統一濃縮咖啡2合1咖啡25g', '瘋狂咖啡無糖2合1咖啡18g', '咖啡統治王者濃縮奶精2合1咖啡20g', '即溶奶精統一滴滴煉咖啡19g', '奶精統一濃縮咖啡2合1咖啡25g']
# ----------
# [debug] prompt
# Please generate 13 product names for 濾掛式咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【熙舍咖啡】義大利濾掛式咖啡綜合風味10g/包", "《西雅圖》極品濾掛咖啡-曼巴風情(50入/盒)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【熙舍咖啡】義大利濾掛式咖啡綜合風味10g/包",
# "《西雅圖》極品濾掛咖啡-曼巴風情(50入/盒)",
# "濾掛咖啡之家【瑞士精選】奶油綜合口感10g/包",
# "珍珠咖啡館【法國濾掛】濾掛式咖啡綜合口感10g/包",
# "咖啡之家【日本濾掛】綜合口感濾掛式咖啡10g/包",
# "濾掛咖啡精選【義大利 Import】濾掛式咖啡綜合口感10g/包",
# "瑞士濾掛咖啡【瑞士 Import】濾掛式咖啡綜合口感10g/包",
# "濾掛咖啡之家【法國 Import】濾掛式咖啡綜合口感10g/包",
# "咖啡精選【日本 Import】濾掛式咖啡綜合口感10g/包",
# "濾掛咖啡精選【義大利精選】濾掛式咖啡綜合口感10g/包",
# "珍珠咖啡館【法國精選】濾掛式咖啡綜合口感10g/包",
# "咖啡之家【日本精選】濾掛式咖啡綜合口感10g/包"
# ]
# }
# 濾掛式咖啡
# ['【熙舍咖啡】義大利濾掛式咖啡綜合風味10g/包', '《西雅圖》極品濾掛咖啡-曼巴風情(50入/盒)']
# ['濾掛咖啡之家【瑞士精選】奶油綜合口感10g/包', '珍珠咖啡館【法國濾掛】濾掛式咖啡綜合口感10g/包', '咖啡之家【日本濾掛】綜合口感濾掛式咖啡10g/包', '濾掛咖啡精選【義大利 Import】濾掛式咖啡綜合口感10g/包', '瑞士濾掛咖啡【瑞士 Import】濾掛式咖啡綜合口感10g/包', '濾掛咖啡之家【法國 Import】濾掛式咖啡綜合口感10g/包', '咖啡精選【日本 Import】濾掛式咖啡綜合口感10g/包', '濾掛咖啡精選【義大利精選】濾掛式咖啡綜合口感10g/包', '珍珠咖啡館【法國精選】濾掛式咖啡綜合口感10g/包', '咖啡之家【日本精選】濾掛式咖啡綜合口感10g/包']
# ----------
# [debug] prompt
# Please generate 13 product names for 即溶咖啡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "AGFMAXIM咖啡罐(藍)-奢華摩登 (80g)", "AGFMAXIM咖啡罐(藍)-奢華摩登 (80g)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "AGFMAXIM咖啡罐(藍)-奢華摩登 (80g)",
# "AGFMAXIM咖啡罐(黑)-奢華摩登 (80g)",
# "AGFMAXIM咖啡罐(綠)-奢華摩登 (80g)",
# "AGFMAXIM咖啡罐(紅)-奢華摩登 (80g)",
# "即溶咖啡-豪華摩登 (80g)",
# "即溶咖啡-奢華摩登 (80g)",
# "即溶咖啡-豪華摩登 (100g)",
# "即溶咖啡-奢華摩登 (100g)",
# "即溶咖啡-豪華摩登 (120g)",
# "即溶咖啡-奢華摩登 (120g)",
# "即溶咖啡-豪華摩登 (150g)",
# "即溶咖啡-奢華摩登 (150g)"
# ]
# }
# 即溶咖啡
# ['AGFMAXIM咖啡罐(藍)-奢華摩登 (80g)', 'AGFMAXIM咖啡罐(藍)-奢華摩登 (80g)']
# ['AGFMAXIM咖啡罐(綠)-奢華摩登 (80g)', 'AGFMAXIM咖啡罐(紅)-奢華摩登 (80g)', '即溶咖啡-豪華摩登 (80g)', '即溶咖啡-奢華摩登 (80g)', '即溶咖啡-豪華摩登 (100g)', '即溶咖啡-奢華摩登 (100g)', '即溶咖啡-豪華摩登 (120g)', '即溶咖啡-奢華摩登 (120g)', '即溶咖啡-豪華摩登 (150g)', '即溶咖啡-奢華摩登 (150g)']
# ----------
# [debug] prompt
# Please generate 13 product names for 咖啡相關食用品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "哥倫比亞咖啡豆(Supremo等級)", "冠軍單品咖啡豆 - 200g", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "哥倫比亞咖啡豆(Supremo等級)",
# "冠軍單品咖啡豆 - 200g",
# "豐澤咖啡豆 - 100% Arabica",
# "咖啡精選豆 - 烘焙精心",
# "咖啡豆粉 - 無添加劑",
# "咖啡奶粉 - 低熔點",
# "咖啡濾粉 - 純淨無杂",
# "咖啡粉塵 - 豐富味道",
# "咖啡粉末 - 極致濃郁",
# "咖啡濃粉 - 純單一原料",
# "咖啡濾粉 - 精緻濾選",
# "咖啡豆粉 - 維生素fortified"
# ]
# }
# 咖啡相關食用品
# ['哥倫比亞咖啡豆(Supremo等級)', '冠軍單品咖啡豆 - 200g']
# ['豐澤咖啡豆 - 100% Arabica', '咖啡精選豆 - 烘焙精心', '咖啡豆粉 - 無添加劑', '咖啡奶粉 - 低熔點', '咖啡濾粉 - 純淨無杂', '咖啡粉塵 - 豐富味道', '咖啡粉末 - 極致濃郁', '咖啡濃粉 - 純單一原料', '咖啡濾粉 - 精緻濾選', '咖啡豆粉 - 維生素fortified']
# ----------
# [debug] prompt
# Please generate 13 product names for 現做茶飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "桂花四季春", "春芽冷露(中) + 白杏", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "綠茶蜜桃",
# "紅茶薰衣",
# "奶粉綠茶",
# "蜜桃綠茶",
# "綠茶芽衣",
# "紅茶桂花",
# "綠茶橙",
# "紅茶蜜桃",
# "綠茶椪柑",
# "紅茶芽衣",
# "綠茶桂花",
# "紅茶橙"
# ]
# }
# 現做茶飲品
# ['桂花四季春', '春芽冷露(中) + 白杏']
# ['奶粉綠茶', '蜜桃綠茶', '綠茶芽衣', '紅茶桂花', '綠茶橙', '紅茶蜜桃', '綠茶椪柑', '紅茶芽衣', '綠茶桂花', '紅茶橙']
# ----------
# [debug] prompt
# Please generate 13 product names for 茶飲 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】義美錫蘭紅茶946ml", "泰山冰鎮大麥綠茶300ml*6入", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【分批取】義美錫蘭紅茶946ml",
# "泰山冰鎮大麥綠茶300ml*6入",
# "彈 Factors Green Tea 300ml",
# "麥綠奶茶300ml*6入",
# "綠 tea latte 450ml",
# "紅 Tea Latte 450ml",
# "綠 Tea 946ml",
# "紅 Tea 946ml",
# "冰鎮 Matcha Green Tea 300ml",
# "冰鎮 Jasmine Green Tea 300ml",
# "冰鎮 Oolong Tea 300ml",
# "冰鎮 Black Tea 300ml"
# ]
# }
# 茶飲
# ['【分批取】義美錫蘭紅茶946ml', '泰山冰鎮大麥綠茶300ml*6入']
# ['彈 Factors Green Tea 300ml', '麥綠奶茶300ml*6入', '綠 tea latte 450ml', '紅 Tea Latte 450ml', '綠 Tea 946ml', '紅 Tea 946ml', '冰鎮 Matcha Green Tea 300ml', '冰鎮 Jasmine Green Tea 300ml', '冰鎮 Oolong Tea 300ml', '冰鎮 Black Tea 300ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 碳酸/汽水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "金車奧利多水寡糖飲料2000ml", "巨峰葡萄氣泡飲", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "金車奧利多水寡糖飲料2000ml",
# "巨峰葡萄氣泡飲",
# "大地純愛碳酸水",
# "維多利亞礦泉水",
# "可樂可樂碳酸水",
# "摩登碳酸水",
# "植物之愛碳酸水",
# "優質生活碳酸水",
# "綠色幻境碳酸水",
# "瑞穗碳酸水",
# "悠遊碳酸水",
# "激流碳酸水"
# ]
# }
# 碳酸/汽水
# ['金車奧利多水寡糖飲料2000ml', '巨峰葡萄氣泡飲']
# ['大地純愛碳酸水', '維多利亞礦泉水', '可樂可樂碳酸水', '摩登碳酸水', '植物之愛碳酸水', '優質生活碳酸水', '綠色幻境碳酸水', '瑞穗碳酸水', '悠遊碳酸水', '激流碳酸水']
# ----------
# [debug] prompt
# Please generate 13 product names for 果汁/果醋飲 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "innocent100%椰子水1000ml", "蜂蜜藍莓醋", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "純愛椰子水1000ml",
# "蜂蜜藍莓醋",
# "桂圓綠茶精油",
# "檸檬皮蛋白",
# "蜜絲葡萄汁",
# "維他命蘋果汁",
# "椰子牛奶精油",
# "蜂蜜橙子醋",
# "椰子芭蕉汁",
# "蜜瓜綠豆汁",
# "檸檬維他命汁",
# "蜜絲椰子汁"
# ]
# }
# 果汁/果醋飲
# ['innocent100%椰子水1000ml', '蜂蜜藍莓醋']
# ['桂圓綠茶精油', '檸檬皮蛋白', '蜜絲葡萄汁', '維他命蘋果汁', '椰子牛奶精油', '蜂蜜橙子醋', '椰子芭蕉汁', '蜜瓜綠豆汁', '檸檬維他命汁', '蜜絲椰子汁']
# ----------
# [debug] prompt
# Please generate 13 product names for 運動飲料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】黑松FIN補給飲料PET580ml", "寶礦力水得580ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "黑松FIN補給飲料PET580ml",
# "寶礦力水得580ml",
# "卓爾運動飲料PET580ml",
# "運動之星飲料PET580ml",
# "黑松FIN 運動飲料PET580ml",
# "寶礦力 運動飲料PET580ml",
# "運動之神飲料PET580ml",
# "黑松FIN 補給飲料PET580ml",
# "寶礦力 補給飲料PET580ml",
# "運動之霸飲料PET580ml",
# "黑松FIN 運動飲料580ml",
# "寶礦力 運動飲料580ml"
# ]
# }
# 運動飲料
# ['【分批取】黑松FIN補給飲料PET580ml', '寶礦力水得580ml']
# ['卓爾運動飲料PET580ml', '運動之星飲料PET580ml', '黑松FIN 運動飲料PET580ml', '寶礦力 運動飲料PET580ml', '運動之神飲料PET580ml', '黑松FIN 補給飲料PET580ml', '寶礦力 補給飲料PET580ml', '運動之霸飲料PET580ml', '黑松FIN 運動飲料580ml', '寶礦力 運動飲料580ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 養生飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "薑汁奶茶 熱", "【四喜】１８罐—冰糖蓮子白木耳露500ml±3%/罐", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "薑汁奶茶 熱",
# "【四喜】１８罐—冰糖蓮子白木耳露500ml±3%/罐",
# "綠 tea plus 紅豆奶",
# "黑豆奶絲襪綠茶",
# "烏龍奶茶 熱",
# "冰糖蓮子綠茶",
# "蜜絲蓮子奶茶",
# "綠豆奶絲蓮子",
# "紅豆奶綠茶",
# "綠茶絲蓮子",
# "奶綠茶熱",
# "綠茶奶絲",
# "綠豆奶綠茶"
# ]
# }
# 養生飲品
# ['薑汁奶茶 熱', '【四喜】１８罐—冰糖蓮子白木耳露500ml±3%/罐']
# ['綠 tea plus 紅豆奶', '黑豆奶絲襪綠茶', '烏龍奶茶 熱', '冰糖蓮子綠茶', '蜜絲蓮子奶茶', '綠豆奶絲蓮子', '紅豆奶綠茶', '綠茶絲蓮子', '奶綠茶熱', '綠茶奶絲', '綠豆奶綠茶']
# ----------
# [debug] prompt
# Please generate 13 product names for 能量飲料 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "魔爪超越碳酸能量飲料355ml", "維他露P330ml (24入)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "閃電爆裂碳酸能量飲料500ml",
# "維他露P330ml (24入)",
# "魔爪超越碳酸能量飲料355ml",
# "冰霜啤酒碳酸能量飲料473ml",
# "黑啤酒碳酸能量飲料440ml",
# "激酸味碳酸能量飲料414ml",
# "綠 tea碳酸能量飲料500ml",
# "檸檬碳酸能量飲料473ml",
# "蘋果碳酸能量飲料440ml",
# "橙子碳酸能量飲料414ml",
# "紫羅蘭碳酸能量飲料500ml",
# "黑巧克力碳酸能量飲料473ml"
# ]
# }
# 能量飲料
# ['魔爪超越碳酸能量飲料355ml', '維他露P330ml (24入)']
# ['魔爪超越碳酸能量飲料355ml', '冰霜啤酒碳酸能量飲料473ml', '黑啤酒碳酸能量飲料440ml', '激酸味碳酸能量飲料414ml', '綠 tea碳酸能量飲料500ml', '檸檬碳酸能量飲料473ml', '蘋果碳酸能量飲料440ml', '橙子碳酸能量飲料414ml', '紫羅蘭碳酸能量飲料500ml', '黑巧克力碳酸能量飲料473ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 特殊風味飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "金車健酪YoGoFresh乳酸飲料-原味580ml", "波蜜果菜汁250mlx6入", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "金車健酪YoGoFresh乳酸飲料-原味580ml",
# "波蜜果菜汁250mlx6入",
# "優之素乳酸飲料-維他命檸檬500ml",
# "豐盈蔬果汁-紅蘿蔔汁600ml",
# "黑寶與美豔-黑寶豔酸飲料550ml",
# "蜜蜂奶粉純乳酸飲料-純喫500ml",
# "麥卡倫純生乳酸飲料-維他命檸檬500ml",
# "豐盈蔬果汁-菠蘿汁600ml",
# "優之素乳酸飲料-維他命檸檬500ml",
# "黑寶與美豔-黑寶豔酸飲料550ml",
# "蜜蜂奶粉純乳酸飲料-純喫500ml",
# "麥卡倫純生乳酸飲料-維他命檸檬500ml"
# ]
# }
# 特殊風味飲品
# ['金車健酪YoGoFresh乳酸飲料-原味580ml', '波蜜果菜汁250mlx6入']
# ['優之素乳酸飲料-維他命檸檬500ml', '豐盈蔬果汁-紅蘿蔔汁600ml', '黑寶與美豔-黑寶豔酸飲料550ml', '蜜蜂奶粉純乳酸飲料-純喫500ml', '麥卡倫純生乳酸飲料-維他命檸檬500ml', '豐盈蔬果汁-菠蘿汁600ml', '優之素乳酸飲料-維他命檸檬500ml', '黑寶與美豔-黑寶豔酸飲料550ml', '蜜蜂奶粉純乳酸飲料-純喫500ml', '麥卡倫純生乳酸飲料-維他命檸檬500ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 沖泡類飲品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】金品茗茶厚韻烏龍茶三角立體茶包2.5gx22入", "【義美生機】台灣黑豆茶", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【優選】維他命蜜絲綠茶30毫升",
# "【頂尖珍】蘭亭綠茶精油30ml",
# "【獨家創】黑豆綠茶精油20ml",
# "【珍萃】維他命紅茶30毫升",
# "【精品】陸羽綠茶精油30ml",
# "【獨挑】蜜絲綠茶精油20ml",
# "【優惠】黑豆綠茶30毫升",
# "【珍萃】維他命綠茶30毫升",
# "【頂尖珍】蘭亭綠茶30毫升",
# "【獨家創】維他命蜜絲綠茶20ml",
# "【精品】陸羽綠茶30毫升",
# "【獨挑】維他命綠茶精油20ml"
# ]
# }
# 沖泡類飲品
# ['【分批取】金品茗茶厚韻烏龍茶三角立體茶包2.5gx22入', '【義美生機】台灣黑豆茶']
# ['【獨家創】黑豆綠茶精油20ml', '【珍萃】維他命紅茶30毫升', '【精品】陸羽綠茶精油30ml', '【獨挑】蜜絲綠茶精油20ml', '【優惠】黑豆綠茶30毫升', '【珍萃】維他命綠茶30毫升', '【頂尖珍】蘭亭綠茶30毫升', '【獨家創】維他命蜜絲綠茶20ml', '【精品】陸羽綠茶30毫升', '【獨挑】維他命綠茶精油20ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 現調果汁 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "芭樂檸檬 (店長推薦★)", "百香芭樂/中", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "芭樂檸檬 (店長推薦★)",
# "百香芭樂/中",
# "芭樂綜合 (網路熱銷)",
# "芭樂綜合 (網路熱銷)",
# "芭樂檸檬 (網路熱銷)",
# "芭樂檸檬 (網路熱銷)",
# "芭樂綜合 (網路熱銷)",
# "芭樂綜合 (網路熱銷)",
# "芭樂檸檬 (網路熱銷)",
# "芭樂檸檬 (網路熱銷)",
# "芭樂綜合 (網路熱銷)",
# "芭樂綜合 (網路熱銷)"
# ]
# }
# 現調果汁
# ['芭樂檸檬 (店長推薦★)', '百香芭樂/中']
# ['芭樂綜合 (網路熱銷)', '芭樂綜合 (網路熱銷)', '芭樂檸檬 (網路熱銷)', '芭樂檸檬 (網路熱銷)', '芭樂綜合 (網路熱銷)', '芭樂綜合 (網路熱銷)', '芭樂檸檬 (網路熱銷)', '芭樂檸檬 (網路熱銷)', '芭樂綜合 (網路熱銷)', '芭樂綜合 (網路熱銷)']
# ----------
# [debug] prompt
# Please generate 13 product names for 礦泉水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "台鹽海洋鹼性離子水", "【悅氏】礦泉水 600mlx24瓶", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "悅氏】礦泉水 600mlx24瓶",
# "台鹽海洋鹼性離子水",
# "礦泉寶贝奶爸 300ml",
# "礦泉水大專案 1000ml",
# "礦泉水精品系列 500ml",
# "礦泉水精選組合 300ml",
# "礦泉水精華版 200ml",
# "礦泉水珍珠瓶 100ml",
# "礦泉水瑰麗 flavored 500ml",
# "礦泉水環保杯 350ml",
# "礦泉水豐盈瓶 750ml",
# "礦泉水禮盒裝 1500ml"
# ]
# }
# 礦泉水
# ['台鹽海洋鹼性離子水', '【悅氏】礦泉水 600mlx24瓶']
# ['礦泉寶贝奶爸 300ml', '礦泉水大專案 1000ml', '礦泉水精品系列 500ml', '礦泉水精選組合 300ml', '礦泉水精華版 200ml', '礦泉水珍珠瓶 100ml', '礦泉水瑰麗 flavored 500ml', '礦泉水環保杯 350ml', '礦泉水豐盈瓶 750ml', '礦泉水禮盒裝 1500ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 氣泡水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "泰山Cheers Bee 蜂蜜氣泡水 590ml", "金車 CrystalValley礦沛氣泡水 585ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "金車 CrystalValley礦沛氣泡水 585ml",
# "泰山 Cheers Bee 蜂蜜氣泡水 590ml",
# "大地treasure YunNan 雲南氣泡水 550ml",
# "麗嬰兒 LittleBaby 嬰兒氣泡水 430ml",
# "摩根 Morgan 豐盈氣泡水 500ml",
# "晶彩 Colorful 氣泡水 570ml",
# "樂悠 HappyWater 氣泡水 500ml",
# "黑珍 BlackPearl 黑氣泡水 530ml",
# "逸翹 Elegance 氣泡水 560ml",
# "瑞穗 Ruisui 礦氣泡水 540ml",
# "馮騏 Fancy 氣泡水 510ml",
# "雙響 DoubleJoy 氣泡水 520ml"
# ]
# }
# 氣泡水
# ['泰山Cheers Bee 蜂蜜氣泡水 590ml', '金車 CrystalValley礦沛氣泡水 585ml']
# ['大地treasure YunNan 雲南氣泡水 550ml', '麗嬰兒 LittleBaby 嬰兒氣泡水 430ml', '摩根 Morgan 豐盈氣泡水 500ml', '晶彩 Colorful 氣泡水 570ml', '樂悠 HappyWater 氣泡水 500ml', '黑珍 BlackPearl 黑氣泡水 530ml', '逸翹 Elegance 氣泡水 560ml', '瑞穗 Ruisui 礦氣泡水 540ml', '馮騏 Fancy 氣泡水 510ml', '雙響 DoubleJoy 氣泡水 520ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 機能水 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "BLACK POWER黑水運動機能礦泉水", "悅氏鎂日補給運動機能水880ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "黑寶特黑水運動機能礦泉水",
# "悅氏鎂日補給運動機能水880ml",
# "奔跑者之選運動機能礦泉水",
# "運動員的力量黑水運動機能礦泉水",
# "健身療法運動機能礦泉水",
# "運動潮人黑水運動機能礦泉水",
# "跑步發力運動機能礦泉水",
# "維他命運動機能礦泉水",
# "運動快樂黑水運動機能礦泉水",
# "運動員的黑水運動機能礦泉水",
# "黑寶特黑水運動機能礦泉水",
# "悅氏鎂日補給運動機能水880ml"
# ]
# }
# 機能水
# ['BLACK POWER黑水運動機能礦泉水', '悅氏鎂日補給運動機能水880ml']
# ['奔跑者之選運動機能礦泉水', '運動員的力量黑水運動機能礦泉水', '健身療法運動機能礦泉水', '運動潮人黑水運動機能礦泉水', '跑步發力運動機能礦泉水', '維他命運動機能礦泉水', '運動快樂黑水運動機能礦泉水', '運動員的黑水運動機能礦泉水', '黑寶特黑水運動機能礦泉水', '悅氏鎂日補給運動機能水880ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 鮮乳類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】林鳳營高品質鮮乳1857ml", "牛奶本味-鈣質強化牛奶946ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "牛奶本味-鈣質強化牛奶946ml",
# "【分批取】林鳳營高品質鮮乳1857ml",
# "鮮乳奶粉-嬰兒專用奶粉800g",
# "維他命奶-豐滿維他命奶900ml",
# "優鮮乳-高鈣質優質鮮乳1700ml",
# "鮮乳奶粉-嬰兒專用奶粉1000g",
# "牛奶味-純正牛奶味920ml",
# "鮮乳液-純正鮮乳液1000ml",
# "奶粉奶-嬰兒專用奶粉700g",
# "牛奶粉-純正牛奶粉850g",
# "鮮乳奶-高鈣質奶粉900g",
# "牛奶味-純正牛奶味1000ml"
# ]
# }
# 鮮乳類
# ['【分批取】林鳳營高品質鮮乳1857ml', '牛奶本味-鈣質強化牛奶946ml']
# ['鮮乳奶粉-嬰兒專用奶粉800g', '維他命奶-豐滿維他命奶900ml', '優鮮乳-高鈣質優質鮮乳1700ml', '鮮乳奶粉-嬰兒專用奶粉1000g', '牛奶味-純正牛奶味920ml', '鮮乳液-純正鮮乳液1000ml', '奶粉奶-嬰兒專用奶粉700g', '牛奶粉-純正牛奶粉850g', '鮮乳奶-高鈣質奶粉900g', '牛奶味-純正牛奶味1000ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 保久乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "國信金蘋果-蘋果牛奶175mlx6入", "【義美】箱購義美牛乳保久乳２５０ｍｌ(２５０ｍｌ＊２４入／箱)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "味全牛乳保久乳250mlx6入",
# "豐澤牛乳保久乳175mlx6入",
# "聚鑫牛乳保久乳200mlx6入",
# "萬家牛乳保久乳175mlx6入",
# "麗嬰牛乳保久乳180mlx6入",
# "裕豐牛乳保久乳250mlx6入",
# "寶貝牛乳保久乳175mlx6入",
# "悅嬰牛乳保久乳190mlx6入",
# "優之牛乳保久乳200mlx6入",
# "滿牛乳保久乳175mlx6入",
# "樂事牛乳保久乳180mlx6入",
# "威廉牛乳保久乳250mlx6入"
# ]
# }
# 保久乳
# ['國信金蘋果-蘋果牛奶175mlx6入', '【義美】箱購義美牛乳保久乳２５０ｍｌ(２５０ｍｌ＊２４入／箱)']
# ['聚鑫牛乳保久乳200mlx6入', '萬家牛乳保久乳175mlx6入', '麗嬰牛乳保久乳180mlx6入', '裕豐牛乳保久乳250mlx6入', '寶貝牛乳保久乳175mlx6入', '悅嬰牛乳保久乳190mlx6入', '優之牛乳保久乳200mlx6入', '滿牛乳保久乳175mlx6入', '樂事牛乳保久乳180mlx6入', '威廉牛乳保久乳250mlx6入']
# ----------
# [debug] prompt
# Please generate 13 product names for 調味乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】福樂蘋果牛乳936ml", "比菲多可可好朋友乳飲品2620ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "福樂蘋果牛乳936ml",
# "比菲多可可好朋友乳飲品2620ml",
# "摩卡純維他命豐盈乳飲品340ml",
# "卡樂比菲多純乳飲品180ml",
# "樂事多純乳飲品200ml",
# "優質生活純維他命乳飲品260ml",
# "摩卡純維他命豐盈乳飲品1000ml",
# "比菲多純乳飲品500ml",
# "樂事多純乳飲品350ml",
# "卡樂比菲多純乳飲品220ml",
# "摩卡純維他命豐盈乳飲品500ml",
# "優質生活純維他命乳飲品500ml"
# ]
# }
# 調味乳
# ['【分批取】福樂蘋果牛乳936ml', '比菲多可可好朋友乳飲品2620ml']
# ['摩卡純維他命豐盈乳飲品340ml', '卡樂比菲多純乳飲品180ml', '樂事多純乳飲品200ml', '優質生活純維他命乳飲品260ml', '摩卡純維他命豐盈乳飲品1000ml', '比菲多純乳飲品500ml', '樂事多純乳飲品350ml', '卡樂比菲多純乳飲品220ml', '摩卡純維他命豐盈乳飲品500ml', '優質生活純維他命乳飲品500ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 優格 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】林鳳營特濃重乳優格-無加糖400g", "福樂自然零無加糖優酪100g*4入", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【分批取】林鳳營特濃重乳優格-無加糖400g",
# "福樂自然零無加糖優酪100g*4入",
# "優格之家無加糖優酪粉300g",
# "維多利亞優酪無加糖500g",
# "樂豐優酪無加糖100g*6入",
# "優酪之家無加糖優酪棒300g",
# "優酪之家無加糖優酪粉100g*10入",
# "維多利亞優酪無加糖1kg",
# "樂豐優酪無加糖500g*2入",
# "優酪之家無加糖優酪棒500g",
# "優酪之家無加糖優酪粉200g*5入",
# "福樂自然零無加糖優酪棒100g*3入"
# ]
# }
# 優格
# ['【分批取】林鳳營特濃重乳優格-無加糖400g', '福樂自然零無加糖優酪100g*4入']
# ['優格之家無加糖優酪粉300g', '維多利亞優酪無加糖500g', '樂豐優酪無加糖100g*6入', '優酪之家無加糖優酪棒300g', '優酪之家無加糖優酪粉100g*10入', '維多利亞優酪無加糖1kg', '樂豐優酪無加糖500g*2入', '優酪之家無加糖優酪棒500g', '優酪之家無加糖優酪粉200g*5入', '福樂自然零無加糖優酪棒100g*3入']
# ----------
# [debug] prompt
# Please generate 13 product names for 優酪乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "簡單點優酪乳939ml", "愛爾曼希臘式優格飲(每瓶200ml)到貨效期約6-8天", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "簡單點優酪乳939ml",
# "愛爾曼希臘式優格飲(每瓶200ml)到貨效期約6-8天",
# "優酪乳組合300ml",
# "優酪乳組合1L",
# "優酪乳組合500ml",
# "優酪乳組合750ml",
# "優酪乳組合2L",
# "優酪乳組合3L",
# "優酪乳組合4L",
# "優酪乳組合5L",
# "優酪乳組合6L",
# "優酪乳組合8L"
# ]
# }
# 優酪乳
# ['簡單點優酪乳939ml', '愛爾曼希臘式優格飲(每瓶200ml)到貨效期約6-8天']
# ['優酪乳組合300ml', '優酪乳組合1L', '優酪乳組合500ml', '優酪乳組合750ml', '優酪乳組合2L', '優酪乳組合3L', '優酪乳組合4L', '優酪乳組合5L', '優酪乳組合6L', '優酪乳組合8L']
# ----------
# [debug] prompt
# Please generate 13 product names for 發酵乳 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【一次取】活益比菲多-原味1795ml", "LCA506活菌發酵乳-清爽0100ml*10入", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "發酵乳",
# "活益比菲多-原味1795ml",
# "LCA506活菌發酵乳-清爽0100ml*10入",
# "發酵乳-維他命濃湯300ml",
# "發酵乳-維他命濃湯1000ml",
# "發酵乳-維他命濃湯500ml",
# "發酵乳-維他命濃湯750ml",
# "發酵乳-維他命濃湯2000ml",
# "發酵乳-維他命濃湯1500ml",
# "發酵乳-維他命濃湯1250ml",
# "發酵乳-維他命濃湯1750ml"
# ]
# }
# 發酵乳
# ['【一次取】活益比菲多-原味1795ml', 'LCA506活菌發酵乳-清爽0100ml*10入']
# ['LCA506活菌發酵乳-清爽0100ml*10入', '發酵乳-維他命濃湯300ml', '發酵乳-維他命濃湯1000ml', '發酵乳-維他命濃湯500ml', '發酵乳-維他命濃湯750ml', '發酵乳-維他命濃湯2000ml', '發酵乳-維他命濃湯1500ml', '發酵乳-維他命濃湯1250ml', '發酵乳-維他命濃湯1750ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 豆漿 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】光泉無加糖濃豆漿936ml", "【分批取】光泉燕麥高纖無糖鮮豆漿1857ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【分批取】光泉無加糖濃豆漿936ml",
# "【分批取】光泉燕麥高纖無糖鮮豆漿1857ml",
# "【新上市】黑橋牌豆漿900ml",
# "【豐澤】豆漿900ml",
# "【優之】豆漿900ml",
# "【頂呱喊】豆漿900ml",
# "【鮮乳】豆漿900ml",
# "【鮮滋】豆漿900ml",
# "【鮮濃】豆漿900ml",
# "【鮮酥】豆漿900ml",
# "【鮮醇】豆漿900ml",
# "【鮮釀】豆漿900ml"
# ]
# }
# 豆漿
# ['【分批取】光泉無加糖濃豆漿936ml', '【分批取】光泉燕麥高纖無糖鮮豆漿1857ml']
# ['【新上市】黑橋牌豆漿900ml', '【豐澤】豆漿900ml', '【優之】豆漿900ml', '【頂呱喊】豆漿900ml', '【鮮乳】豆漿900ml', '【鮮滋】豆漿900ml', '【鮮濃】豆漿900ml', '【鮮酥】豆漿900ml', '【鮮醇】豆漿900ml', '【鮮釀】豆漿900ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 米漿 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】光泉紫米燕麥糙米漿1857ml", "光泉薏仁糙米漿-1857ml到貨效期約6-8天", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【分批取】光泉紫米燕麥糙米漿1857ml",
# "光泉薏仁糙米漿-1857ml到貨效期約6-8天",
# "瑞穗糙米漿-1857ml",
# "瑞穗薏仁糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml",
# "瑞穗紫米燕麥糙米漿-1857ml"
# ]
# }
# 米漿
# ['【分批取】光泉紫米燕麥糙米漿1857ml', '光泉薏仁糙米漿-1857ml到貨效期約6-8天']
# ['瑞穗糙米漿-1857ml', '瑞穗薏仁糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml', '瑞穗紫米燕麥糙米漿-1857ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 燕麥奶 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【分批取】桂格顆粒豆漿燕麥920ml", "桂格Oat Ya職人燕麥奶936ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【分批取】桂格顆粒豆漿燕麥920ml",
# "桂格Oat Ya職人燕麥奶936ml",
# "燕麥奶粉末900g",
# "燕麥奶粉末800g",
# "燕麥奶粉末700g",
# "燕麥奶粉末600g",
# "燕麥奶粉末500g",
# "燕麥奶粉末400g",
# "燕麥奶粉末300g",
# "燕麥奶粉末200g",
# "燕麥奶粉末100g",
# "燕麥奶粉末50g"
# ]
# }
# 燕麥奶
# ['【分批取】桂格顆粒豆漿燕麥920ml', '桂格Oat Ya職人燕麥奶936ml']
# ['燕麥奶粉末900g', '燕麥奶粉末800g', '燕麥奶粉末700g', '燕麥奶粉末600g', '燕麥奶粉末500g', '燕麥奶粉末400g', '燕麥奶粉末300g', '燕麥奶粉末200g', '燕麥奶粉末100g', '燕麥奶粉末50g']
# ----------
# [debug] prompt
# Please generate 13 product names for 現做霜淇淋/聖代 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "春日抹茶霜淇淋", "四季金萱霜淇淋", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "春日抹茶霜淇淋",
# "四季金萱霜淇淋",
# "綠 tea matcha霜淇淋",
# "櫻花牡丹霜淇淋",
# "冬梅雪茗霜淇淋",
# "蜜瓜椒霜淇淋",
# "薄荷蜜霜淇淋",
# "杏仁豐腴霜淇淋",
# "黑 Sesame霜淇淋",
# "紅豆皮霜淇淋",
# "芋頭綠豆霜淇淋",
# "鳳梨霜淇淋"
# ]
# }
# 現做霜淇淋/聖代
# ['春日抹茶霜淇淋', '四季金萱霜淇淋']
# ['綠 tea matcha霜淇淋', '櫻花牡丹霜淇淋', '冬梅雪茗霜淇淋', '蜜瓜椒霜淇淋', '薄荷蜜霜淇淋', '杏仁豐腴霜淇淋', '黑 Sesame霜淇淋', '紅豆皮霜淇淋', '芋頭綠豆霜淇淋', '鳳梨霜淇淋']
# ----------
# [debug] prompt
# Please generate 13 product names for 冰棒/雪糕 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "杜老爺超級曠世奇派酒釀黑櫻桃", "百吉布丁雪糕", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "杜老爺超級曠世奇派酒釀黑櫻桃",
# "百吉布丁雪糕",
# "巧克力奶爸酒釀雪糕",
# "芭蕉威士忌酒釀雪糕",
# "可可威士忌酒釀雪糕",
# "豆皮奶爸酒釀雪糕",
# "椰子奶爸酒釀雪糕",
# "蜜瓜奶爸酒釀雪糕",
# "芋頭奶爸酒釀雪糕",
# "維他命奶爸酒釀雪糕",
# "巧克力維他命酒釀雪糕",
# "巧克力豆皮酒釀雪糕",
# "巧克力蜜瓜酒釀雪糕"
# ]
# }
# 冰棒/雪糕
# ['杜老爺超級曠世奇派酒釀黑櫻桃', '百吉布丁雪糕']
# ['巧克力奶爸酒釀雪糕', '芭蕉威士忌酒釀雪糕', '可可威士忌酒釀雪糕', '豆皮奶爸酒釀雪糕', '椰子奶爸酒釀雪糕', '蜜瓜奶爸酒釀雪糕', '芋頭奶爸酒釀雪糕', '維他命奶爸酒釀雪糕', '巧克力維他命酒釀雪糕', '巧克力豆皮酒釀雪糕', '巧克力蜜瓜酒釀雪糕']
# ----------
# [debug] prompt
# Please generate 13 product names for 冰淇淋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "家福香草風味冰淇淋", "杜老爺enjoy冰淇淋-草莓起司", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "綠茶發酵冰淇淋",
# "巧克力瑪瑙冰淇淋",
# "芒果冰淇淋",
# "蜜瓜冰淇淋",
# "黑巧克力冰淇淋",
# "薄荷冰淇淋",
# "椰子冰淇淋",
# "芝麻冰淇淋",
# "蓮花冰淇淋",
# "紫羅蘭冰淇淋",
# "瓜子冰淇淋",
# "豆皮冰淇淋"
# ]
# }
# 冰淇淋
# ['家福香草風味冰淇淋', '杜老爺enjoy冰淇淋-草莓起司']
# ['芒果冰淇淋', '蜜瓜冰淇淋', '黑巧克力冰淇淋', '薄荷冰淇淋', '椰子冰淇淋', '芝麻冰淇淋', '蓮花冰淇淋', '紫羅蘭冰淇淋', '瓜子冰淇淋', '豆皮冰淇淋']
# ----------
# [debug] prompt
# Please generate 13 product names for 甜筒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "杜老爺淇淋巧酥甜筒", "杜老爺黑糖珍珠甜筒(每盒82gx4)", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "杜老爺淇淋巧酥甜筒",
# "杜老爺黑糖珍珠甜筒(每盒82gx4)",
# "黑松子綠茶甜筒",
# "芝麻蜜甜筒",
# "蜜絲奶甜筒",
# "綠豆甜筒",
# "紅豆甜筒",
# "芋頭甜筒",
# "蜜餞甜筒",
# "巧克力甜筒",
# "瑞士卷甜筒",
# "豐潤甜筒"
# ]
# }
# 甜筒
# ['杜老爺淇淋巧酥甜筒', '杜老爺黑糖珍珠甜筒(每盒82gx4)']
# ['黑松子綠茶甜筒', '芝麻蜜甜筒', '蜜絲奶甜筒', '綠豆甜筒', '紅豆甜筒', '芋頭甜筒', '蜜餞甜筒', '巧克力甜筒', '瑞士卷甜筒', '豐潤甜筒']
# ----------
# [debug] prompt
# Please generate 13 product names for 仙草/愛玉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "寒天檸檬愛玉", "泰山仙草凍", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "霜凍仙草",
# "寒天檸檬愛玉",
# "泰山仙草凍",
# "瑞雪愛玉",
# "雨夜仙草",
# "迷魂仙草",
# "冰霜愛玉",
# "黑奔仙草",
# "閃耀愛玉",
# "凍狂仙草",
# "寒霜愛玉",
# "晨霞仙草"
# ]
# }
# 仙草/愛玉
# ['寒天檸檬愛玉', '泰山仙草凍']
# ['泰山仙草凍', '瑞雪愛玉', '雨夜仙草', '迷魂仙草', '冰霜愛玉', '黑奔仙草', '閃耀愛玉', '凍狂仙草', '寒霜愛玉', '晨霞仙草']
# ----------
# [debug] prompt
# Please generate 12 product names for 水果冰品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "初鹿芒果優格冰沙", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑞逸菠萝冰淇淋",
# "迪卡優格冰棗",
# "黑奶冰糕",
# "蜜絲芭蕉冰淇淋",
# "巧克力冰淇淋",
# "芒果優格冰沙",
# "維他命冰淇淋",
# "冰霜蔓菁冰淇淋",
# "菠萝冰淇淋",
# "優格冰棗",
# "芭蕉冰淇淋",
# "瑞逸冰淇淋"
# ]
# }
# 水果冰品
# ['初鹿芒果優格冰沙']
# ['迪卡優格冰棗', '黑奶冰糕', '蜜絲芭蕉冰淇淋', '巧克力冰淇淋', '芒果優格冰沙', '維他命冰淇淋', '冰霜蔓菁冰淇淋', '菠萝冰淇淋', '優格冰棗', '芭蕉冰淇淋', '瑞逸冰淇淋']
# ----------
# [debug] prompt
# Please generate 13 product names for 冰塊 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "韓國YOUUS急凍冰球", "ＦＭＣ衛生冰塊", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "韓國YOUUS急凍冰球",
# "ＦＭＣ衛生冰塊",
# "舒暢冰塊",
# "冰霜凍冰塊",
# "寶貝冰塊",
# "冰晶凍冰塊",
# "冰雨冰塊",
# "冰瑞冰塊",
# "冰芳冰塊",
# "冰麗冰塊",
# "冰霞冰塊",
# "冰彩冰塊"
# ]
# }
# 冰塊
# ['韓國YOUUS急凍冰球', 'ＦＭＣ衛生冰塊']
# ['舒暢冰塊', '冰霜凍冰塊', '寶貝冰塊', '冰晶凍冰塊', '冰雨冰塊', '冰瑞冰塊', '冰芳冰塊', '冰麗冰塊', '冰霞冰塊', '冰彩冰塊']
# ----------
# [debug] prompt
# Please generate 13 product names for 現調冰品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "百香芒果冰沙", "芒果覆盆子拿鐵冰沙", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "酸味紫羅蘭冰沙",
# "芒果覆盆子拿鐵冰沙",
# "百香芒果冰沙",
# "巧克力芝麻冰沙",
# "蜜瓜奶油冰沙",
# "綠 tea matcha冰沙",
# "芋頭牛奶冰沙",
# "胭脂葡萄冰沙",
# "豢豢奶爸冰沙",
# "焦糖瑪莉冰沙",
# "冰霜蔥油冰沙",
# "黑糖紅豢冰沙"
# ]
# }
# 現調冰品
# ['百香芒果冰沙', '芒果覆盆子拿鐵冰沙']
# ['百香芒果冰沙', '巧克力芝麻冰沙', '蜜瓜奶油冰沙', '綠 tea matcha冰沙', '芋頭牛奶冰沙', '胭脂葡萄冰沙', '豢豢奶爸冰沙', '焦糖瑪莉冰沙', '冰霜蔥油冰沙', '黑糖紅豢冰沙']
# ----------
# [debug] prompt
# Please generate 13 product names for 蒸箱食品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "叉燒包", "大鮮肉包", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "鮮肉焗糖水餃",
# "叉燒豬仔腸",
# "叉燒雞排",
# "炸魚皮",
# "烤雞翼",
# "烤魚腸",
# "烤豬仔腸",
# "烤鮮肉",
# "焗糖牛肉麵",
# "焗糖雞腿",
# "焗糖豬仔腸",
# "焗糖鮮肉"
# ]
# }
# 蒸箱食品
# ['叉燒包', '大鮮肉包']
# ['叉燒雞排', '炸魚皮', '烤雞翼', '烤魚腸', '烤豬仔腸', '烤鮮肉', '焗糖牛肉麵', '焗糖雞腿', '焗糖豬仔腸', '焗糖鮮肉']
# ----------
# [debug] prompt
# Please generate 13 product names for 地瓜 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "全家夯番薯", "瓜瓜園 冰烤蕃薯", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "全家夯番薯",
# "瓜瓜園 冰烤蕃薯",
# "蕃薯味噌椒麵",
# "薯仔煮炒飯",
# "薯仔炒蛋飯",
# "薯仔炒豬肉飯",
# "薯仔炒魚飯",
# "薯仔炒豢豢飯",
# "薯仔炒豢豢飯",
# "薯仔炒豢豢飯",
# "薯仔炒豢豢飯"
# ]
# }
# 地瓜
# ['全家夯番薯', '瓜瓜園 冰烤蕃薯']
# ['蕃薯味噌椒麵', '薯仔煮炒飯', '薯仔炒蛋飯', '薯仔炒豬肉飯', '薯仔炒魚飯', '薯仔炒豢豢飯', '薯仔炒豢豢飯', '薯仔炒豢豢飯', '薯仔炒豢豢飯']
# ----------
# [debug] prompt
# Please generate 13 product names for 熱狗 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "雞肉Light熱狗", "四種起司xQ彈多汁美式原味熱狗", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "雞肉Light熱狗",
# "四種起司xQ彈多汁美式原味熱狗",
# "豬肉厚切夾雞肉熱狗",
# "芝麻雞肉熱狗",
# "黑豢豢牛肉熱狗",
# "辣雞肉熱狗",
# "魚漿彈雞肉熱狗",
# "紫菜牛肉熱狗",
# "雞肉炸醬熱狗",
# "豢豢雞肉熱狗",
# "咖哩雞肉熱狗",
# "烤雞肉熱狗",
# "雞肉麵包熱狗"
# ]
# }
# 熱狗
# ['雞肉Light熱狗', '四種起司xQ彈多汁美式原味熱狗']
# ['豬肉厚切夾雞肉熱狗', '芝麻雞肉熱狗', '黑豢豢牛肉熱狗', '辣雞肉熱狗', '魚漿彈雞肉熱狗', '紫菜牛肉熱狗', '雞肉炸醬熱狗', '豢豢雞肉熱狗', '咖哩雞肉熱狗', '烤雞肉熱狗', '雞肉麵包熱狗']
# ----------
# [debug] prompt
# Please generate 13 product names for 關東煮 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "韓式辣味魚糕", "華昇飛魚卵海鮮卷", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "韓式辣味魚糕",
# "華昇飛魚卵海鮮卷",
# "日本味煮魚糕",
# "豐盈蟹粉魚糕",
# "魚板黑豢豢",
# "魚板紫菜魚糕",
# "魚板辣豢豢",
# "魚板魚皮魚糕",
# "魚板魚肉魚糕",
# "魚板魚骨魚糕",
# "魚板魚腸魚糕",
# "魚板魚腦魚糕"
# ]
# }
# 關東煮
# ['韓式辣味魚糕', '華昇飛魚卵海鮮卷']
# ['日本味煮魚糕', '豐盈蟹粉魚糕', '魚板黑豢豢', '魚板紫菜魚糕', '魚板辣豢豢', '魚板魚皮魚糕', '魚板魚肉魚糕', '魚板魚骨魚糕', '魚板魚腸魚糕', '魚板魚腦魚糕']
# ----------
# [debug] prompt
# Please generate 13 product names for 米飯類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "台式芋頭鹹粥", "大飯糰泡菜鮪魚", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "台式芋頭鹹粥",
# "大飯糰泡菜鮪魚",
# "家和豢豢飯",
# "糖水雞絲麵",
# "芋頭炒蛋飯",
# "豢豢炒飯",
# "魚煮飯",
# "蔥油飯",
# "豢豢炒飯",
# "炒飯",
# "麵包飯",
# "糰泡飯"
# ]
# }
# 米飯類
# ['台式芋頭鹹粥', '大飯糰泡菜鮪魚']
# ['家和豢豢飯', '糖水雞絲麵', '芋頭炒蛋飯', '豢豢炒飯', '魚煮飯', '蔥油飯', '豢豢炒飯', '炒飯', '麵包飯', '糰泡飯']
# ----------
# [debug] prompt
# Please generate 13 product names for 麵食類 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "花雕雞絲涼麵", "日式蕎麥沾麵", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "雙皮蔥油麵",
# "豐脆蝦仁麵",
# "叉燒雞柳麵",
# "奶油蔥油麵",
# "芋頭絲麵",
# "魚湯麵",
# "豢麵",
# "黑胡椒麵",
# "蜜汁雞麵",
# "芝麻麵",
# "雞油麵",
# "蔥油麵"
# ]
# }
# 麵食類
# ['花雕雞絲涼麵', '日式蕎麥沾麵']
# ['叉燒雞柳麵', '奶油蔥油麵', '芋頭絲麵', '魚湯麵', '豢麵', '黑胡椒麵', '蜜汁雞麵', '芝麻麵', '雞油麵', '蔥油麵']
# ----------
# [debug] prompt
# Please generate 13 product names for 三明治 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "雞蛋沙拉三明治", "紐奧良風味烤雞鮮蔬三明治", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "雞蛋沙拉三明治",
# "紐奧良風味烤雞鮮蔬三明治",
# "椒魚豫麵三明治",
# "芝麻辣椒雞三明治",
# "黑豫麵烤雞三明治",
# "蔥油雞三明治",
# "雞批豆腐三明治",
# "雞肝菌三明治",
# "雞腿豆腐三明治",
# "雞肉麵包三明治",
# "烤雞鮮蔬三明治",
# "豆皮雞三明治",
# "雞肉餅三明治"
# ]
# }
# 三明治
# ['雞蛋沙拉三明治', '紐奧良風味烤雞鮮蔬三明治']
# ['椒魚豫麵三明治', '芝麻辣椒雞三明治', '黑豫麵烤雞三明治', '蔥油雞三明治', '雞批豆腐三明治', '雞肝菌三明治', '雞腿豆腐三明治', '雞肉麵包三明治', '烤雞鮮蔬三明治', '豆皮雞三明治', '雞肉餅三明治']
# ----------
# [debug] prompt
# Please generate 13 product names for 漢堡 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "美式雞腿堡", "豬肉起司蛋堡", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "豬肉卷餅堡",
# "牛排堡",
# "雞腿卷餅堡",
# "豬肉餅堡",
# "牛肉餅堡",
# "雞肉堡",
# "豬肉蛋堡",
# "牛肉蛋堡",
# "雞肉蛋堡",
# "豬肉起司堡",
# "牛肉起司堡",
# "雞肉起司堡"
# ]
# }
# 漢堡
# ['美式雞腿堡', '豬肉起司蛋堡']
# ['雞腿卷餅堡', '豬肉餅堡', '牛肉餅堡', '雞肉堡', '豬肉蛋堡', '牛肉蛋堡', '雞肉蛋堡', '豬肉起司堡', '牛肉起司堡', '雞肉起司堡']
# ----------
# [debug] prompt
# Please generate 13 product names for 生鮮蔬果/沙拉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "青檸烤雞握沙拉", "季節水果拼盤", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "櫻花雞肉沙拉",
# "綜合蔬果拼盤",
# "蜜汁炸雞握沙拉",
# "叉燒魚板擦沙拉",
# "韭菜炒蛋拼盤",
# "芋頭炸雞握沙拉",
# "紫菜扁椒魚拼盤",
# "豢麵炒雞握沙拉",
# "奶油炸豢麵拼盤",
# "黑豢麵炒蛋拼盤",
# "蔥油雞握沙拉",
# "芝麻雞握沙拉"
# ]
# }
# 生鮮蔬果/沙拉
# ['青檸烤雞握沙拉', '季節水果拼盤']
# ['蜜汁炸雞握沙拉', '叉燒魚板擦沙拉', '韭菜炒蛋拼盤', '芋頭炸雞握沙拉', '紫菜扁椒魚拼盤', '豢麵炒雞握沙拉', '奶油炸豢麵拼盤', '黑豢麵炒蛋拼盤', '蔥油雞握沙拉', '芝麻雞握沙拉']
# ----------
# [debug] prompt
# Please generate 13 product names for 小菜/滷味 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "小滷青蔬", "猴菇麻油蔬", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "小滷青蔬",
# "猴菇麻油蔬",
# "豆皮菇蔬",
# "酸辣椒油蔬",
# "芋头豆腐蔬",
# "芝麻酥蔬",
# "豢豢蔬",
# "辣椒酥蔬",
# "芋艿蔬",
# "豢豢蔬",
# "酸辣椒油蔬",
# "豆皮菇蔬"
# ]
# }
# 小菜/滷味
# ['小滷青蔬', '猴菇麻油蔬']
# ['豆皮菇蔬', '酸辣椒油蔬', '芋头豆腐蔬', '芝麻酥蔬', '豢豢蔬', '辣椒酥蔬', '芋艿蔬', '豢豢蔬', '酸辣椒油蔬', '豆皮菇蔬']
# ----------
# [debug] prompt
# Please generate 13 product names for 湯品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "玉米濃湯", "鮮筍排骨湯", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "豐盈蔬菜湯",
# "綜合營養湯",
# "清爽薑涼湯",
# "紫菜高麗湯",
# "綠豆維他命湯",
# "鮮奶精靈湯",
# "紅豆精湯",
# "黑豆奶湯",
# "蜜豢豢湯",
# "鮮肉精湯",
# "維他命綠茶湯",
# "紅蔣豢湯"
# ]
# }
# 湯品
# ['玉米濃湯', '鮮筍排骨湯']
# ['清爽薑涼湯', '紫菜高麗湯', '綠豆維他命湯', '鮮奶精靈湯', '紅豆精湯', '黑豆奶湯', '蜜豢豢湯', '鮮肉精湯', '維他命綠茶湯', '紅蔣豢湯']
# ----------
# [debug] prompt
# Please generate 13 product names for 水餃/點心 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "及第冷藏豬肉熟水餃", "鱈蟹柳", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "鮮豢豢奶爸水餃",
# "瑞穗豬肉煮味水餃",
# "黑豢豢咖哩魚水餃",
# "鮮蝦籽豢水餃",
# "嫩豢豢豬肉煮味水餃",
# "魚煮味水餃",
# "豢魚豢水餃",
# "鮮豢豢豬肉熟水餃",
# "鱈蟹柳",
# "鮮豢豢魚煮味水餃",
# "豢豢魚煮味水餃",
# "鮮豢豢豬肉煮味水餃"
# ]
# }
# 水餃/點心
# ['及第冷藏豬肉熟水餃', '鱈蟹柳']
# ['黑豢豢咖哩魚水餃', '鮮蝦籽豢水餃', '嫩豢豢豬肉煮味水餃', '魚煮味水餃', '豢魚豢水餃', '鮮豢豢豬肉熟水餃', '鱈蟹柳', '鮮豢豢魚煮味水餃', '豢豢魚煮味水餃', '鮮豢豢豬肉煮味水餃']
# ----------
# [debug] prompt
# Please generate 13 product names for 雞胸肉 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "泰式香檸嫩雞胸", "秘香椒麻嫩雞胸", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "泰式香檸嫩雞胸",
# "秘香椒麻嫩雞胸",
# "辣味炸雞胸",
# "椒鹵味雞胸",
# "蜜糖雞胸",
# "叉燒雞胸",
# "酸味雞胸",
# "芝麻雞胸",
# "豆皮雞胸",
# "黑胡椒雞胸",
# "辣椒雞胸",
# "炸雞胸",
# "烤雞胸"
# ]
# }
# 雞胸肉
# ['泰式香檸嫩雞胸', '秘香椒麻嫩雞胸']
# ['辣味炸雞胸', '椒鹵味雞胸', '蜜糖雞胸', '叉燒雞胸', '酸味雞胸', '芝麻雞胸', '豆皮雞胸', '黑胡椒雞胸', '辣椒雞胸', '炸雞胸', '烤雞胸']
# ----------
# [debug] prompt
# Please generate 13 product names for 茶葉蛋/水煮蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "茶葉蛋", "溏心蛋", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "茶葉蛋",
# "溏心蛋",
# "綠茶蛋",
# "紅茶蛋",
# "奶茶蛋",
# "蜜茶蛋",
# " Matcha蛋",
# "烏龍蛋",
# "薑汁蛋",
# "芋頭蛋",
# "豆漿蛋",
# "甜菇蛋"
# ]
# }
# 茶葉蛋/水煮蛋
# ['茶葉蛋', '溏心蛋']
# ['綠茶蛋', '紅茶蛋', '奶茶蛋', '蜜茶蛋', ' Matcha蛋', '烏龍蛋', '薑汁蛋', '芋頭蛋', '豆漿蛋', '甜菇蛋']
# ----------
# [debug] prompt
# Please generate 13 product names for 肉品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "御料小館美式香辣雞丁", "御料小館韓風拌拌炸雞", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "御料小館美式香辣雞丁",
# "御料小館韓風拌拌炸雞",
# "上海麵包子魯肉麵",
# "彈 Factors牛肉麵",
# "韓式炸雞拌飯",
# "炸雞腿腿飯",
# "豚骨 Lorenzo麵",
# "豚骨炸雞麵",
# "魯肉炸雞麵",
# "炸雞拌飯",
# "炸雞腿飯",
# "韓式炸雞麵"
# ]
# }
# 肉品
# ['御料小館美式香辣雞丁', '御料小館韓風拌拌炸雞']
# ['上海麵包子魯肉麵', '彈 Factors牛肉麵', '韓式炸雞拌飯', '炸雞腿腿飯', '豚骨 Lorenzo麵', '豚骨炸雞麵', '魯肉炸雞麵', '炸雞拌飯', '炸雞腿飯', '韓式炸雞麵']
# ----------
# [debug] prompt
# Please generate 13 product names for 麵包 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "北海道牛奶吐司", "丹麥菠蘿", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "麵包",
# "北海道牛奶吐司",
# "丹麥菠蘿",
# "臘扁麵",
# "豬仔肉麵",
# "魚漿麵",
# "蝦仁麵",
# "芋頭麵",
# "牛肉麵",
# "雞肉麵",
# "墨魚麵",
# "豢麵"
# ]
# }
# 麵包
# ['北海道牛奶吐司', '丹麥菠蘿']
# ['丹麥菠蘿', '臘扁麵', '豬仔肉麵', '魚漿麵', '蝦仁麵', '芋頭麵', '牛肉麵', '雞肉麵', '墨魚麵', '豢麵']
# ----------
# [debug] prompt
# Please generate 13 product names for 蛋糕 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "虎皮小卷", "波士頓提拉米蘇", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑞士卷",
# "蛋撻卷",
# "蛋糕卷",
# "蛋餅",
# "蛋糕",
# "蛋糕餅",
# "蛋糕麵",
# "蛋糕餅乾",
# "蛋糕餅糖",
# "蛋糕餅奶",
# "蛋糕餅芝",
# "蛋糕餅蜜"
# ]
# }
# 蛋糕
# ['虎皮小卷', '波士頓提拉米蘇']
# ['蛋糕卷', '蛋餅', '蛋糕', '蛋糕餅', '蛋糕麵', '蛋糕餅乾', '蛋糕餅糖', '蛋糕餅奶', '蛋糕餅芝', '蛋糕餅蜜']
# ----------
# [debug] prompt
# Please generate 13 product names for 中式糕點 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "土鳳梨酥", "蛋黃酥", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "蓮蓉蛋糕",
# "紅豆粉酥",
# "芋頭糕",
# "菠蘿蛋糕",
# "鳳梨酥",
# "蜜餞蛋糕",
# "綠豆酥",
# "芝麻糕",
# "椰奶糕",
# "豌豆糕",
# "蔥油酥",
# "胡椒酥"
# ]
# }
# 中式糕點
# ['土鳳梨酥', '蛋黃酥']
# ['芋頭糕', '菠蘿蛋糕', '鳳梨酥', '蜜餞蛋糕', '綠豆酥', '芝麻糕', '椰奶糕', '豌豆糕', '蔥油酥', '胡椒酥']
# ----------
# [debug] prompt
# Please generate 13 product names for 生雞蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "洗選蛋", "土雞蛋", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "洗選蛋",
# "土雞蛋",
# "奶油蛋",
# "煮蛋",
# "魚蛋",
# "豢雞蛋",
# "蔬菜蛋",
# "肉雞蛋",
# "糖蛋",
# "蛋撻",
# "蛋糕",
# "蛋麵"
# ]
# }
# 生雞蛋
# ['洗選蛋', '土雞蛋']
# ['奶油蛋', '煮蛋', '魚蛋', '豢雞蛋', '蔬菜蛋', '肉雞蛋', '糖蛋', '蛋撻', '蛋糕', '蛋麵']
# ----------
# [debug] prompt
# Please generate 13 product names for 加工蛋 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "皮蛋", "鐵蛋", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "皮蛋",
# "鐵蛋",
# "豆蛋",
# "蔥油蛋",
# "辣椒蛋",
# "魚蛋",
# "蝦蛋",
# "蛋撻",
# "蛋糕",
# "蛋麵",
# "蛋炸",
# "蛋捲"
# ]
# }
# 加工蛋
# ['皮蛋', '鐵蛋']
# ['豆蛋', '蔥油蛋', '辣椒蛋', '魚蛋', '蝦蛋', '蛋撻', '蛋糕', '蛋麵', '蛋炸', '蛋捲']
# ----------
# [debug] prompt
# Please generate 13 product names for 生鮮蔬菜 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "高麗菜", "菠菜", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "高麗菜",
# "菠菜",
# "紅蘿蔔",
# "芽蕉",
# "豆芽",
# "葱蒜",
# "辣椒",
# "蔥",
# "蒜蓉",
# "菌菇",
# "綠豆",
# "豢豢蔬"
# ]
# }
# 生鮮蔬菜
# ['高麗菜', '菠菜']
# ['紅蘿蔔', '芽蕉', '豆芽', '葱蒜', '辣椒', '蔥', '蒜蓉', '菌菇', '綠豆', '豢豢蔬']
# ----------
# [debug] prompt
# Please generate 13 product names for 生鮮水果 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "蘋果", "葡萄", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "蘋果",
# "葡萄",
# "香蕉",
# "椪柑",
# "蜜瓜",
# "哈密瓜",
# "菠蘿",
# "蔥",
# "蒜蓉",
# "胡蘿蔔",
# "酸味菇",
# "甜豢豢"
# ]
# }
# 生鮮水果
# ['蘋果', '葡萄']
# ['香蕉', '椪柑', '蜜瓜', '哈密瓜', '菠蘿', '蔥', '蒜蓉', '胡蘿蔔', '酸味菇', '甜豢豢']
# ----------
# [debug] prompt
# Please generate 13 product names for 生鮮肉品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "生雞腿塊", "黑豬梅花火鍋片", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "生雞腿塊",
# "黑豬梅花火鍋片",
# "豬肉卷",
# "炸魚漿",
# "烤牛排",
# "炸雞翼",
# "生牛肉麵",
# "魚煮",
# "豬肉燒",
# "烤雞腿",
# "生豬排",
# "炸豬油"
# ]
# }
# 生鮮肉品
# ['生雞腿塊', '黑豬梅花火鍋片']
# ['豬肉卷', '炸魚漿', '烤牛排', '炸雞翼', '生牛肉麵', '魚煮', '豬肉燒', '烤雞腿', '生豬排', '炸豬油']
# ----------
# [debug] prompt
# Please generate 13 product names for 生鮮海鮮 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "鮭魚輪切", "日本生干貝", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "鮭魚輪切",
# "日本生干貝",
# "鮮肉魚板",
# "鮮蝦籽腸",
# "鮮蛋糕",
# "鮮豢豢腸",
# "鮮魚煮",
# "鮮魚皮",
# "鮮魚肝",
# "鮮魚腸",
# "鮮魚麵",
# "鮮魚魚腸"
# ]
# }
# 生鮮海鮮
# ['鮭魚輪切', '日本生干貝']
# ['鮮肉魚板', '鮮蝦籽腸', '鮮蛋糕', '鮮豢豢腸', '鮮魚煮', '鮮魚皮', '鮮魚肝', '鮮魚腸', '鮮魚麵', '鮮魚魚腸']
# ----------
# [debug] prompt
# Please generate 13 product names for 豆腐 category.
# ...
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "精品珍珠耳環",
# "鑽石耳夾",
# "聚焦飾品",
# "黑金剛耳環",
# "透明耳夾",
# "珍珠鍊",
# "鑽石戒指",
# "精品托特耳環",
# "耳夾組合",
# "珍珠耳環",
# "黑色鍊",
# "鑽石眼鏡架"
# ]
# }
# 精品／飾品
# ['造型花附吊鍊 (美樂蒂)', '高級耳夾']
# ['聚焦飾品', '黑金剛耳環', '透明耳夾', '珍珠鍊', '鑽石戒指', '精品托特耳環', '耳夾組合', '珍珠耳環', '黑色鍊', '鑽石眼鏡架']
# ----------
# [debug] prompt
# Please generate 13 product names for 手錶 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【SWATCH】七龍珠Z聯名錶-悟空/賽魯 BIG BOLD系列(47mm)", "【CASIO 卡西歐】MQ-24UC 簡約百搭超輕薄大地色系中性數字腕錶", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【SEIKO 瑞科】SRDG051 瑞科戰鬥機場系列降落計時腕錶",
# "【CITIZEN 시민】CA0010-58E 市民輕便潛水腕錶",
# "【Fossil 化石】 Grant CH2513 臘戶外系列腕錶",
# "【SKAGEN 斯卡根】 SKW6002 斯卡根輕便潛水腕錶",
# "【Tissot 提索】 T0994272705700 提索推廣精神系列腕錶",
# "【Hamilton 漢米頓】 H24411732 漢米頓輕便潛水腕錶",
# "【Daniel Wellington 丹尼爾·威靈頓】 Classic Petite 32mm 丹尼爾·威靈頓腕錶",
# "【Timex 時間ks】 T49905 時間ks輕便潛水腕錶",
# "【Casio 卡西歐】 GA-100 卡西歐極限運動系列腕錶",
# "【Swatch 斯沃琪】 SUOB703 斯沃琪輕便潛水腕錶",
# "【Fossil 化石】 Grant CH2513 臘戶外系列腕錶",
# "【Skagen 斯卡根】 SKW6002 斯卡根輕便潛水腕錶",
# "【Tissot 提索】 T0994272705700 提索推廣精神系列腕錶"
# ]
# }
# 手錶
# ['【SWATCH】七龍珠Z聯名錶-悟空/賽魯 BIG BOLD系列(47mm)', '【CASIO 卡西歐】MQ-24UC 簡約百搭超輕薄大地色系中性數字腕錶']
# ['【Fossil 化石】 Grant CH2513 臘戶外系列腕錶', '【SKAGEN 斯卡根】 SKW6002 斯卡根輕便潛水腕錶', '【Tissot 提索】 T0994272705700 提索推廣精神系列腕錶', '【Hamilton 漢米頓】 H24411732 漢米頓輕便潛水腕錶', '【Daniel Wellington 丹尼爾·威靈頓】 Classic Petite 32mm 丹尼爾·威靈頓腕錶', '【Timex 時間ks】 T49905 時間ks輕便潛水腕錶', '【Casio 卡西歐】 GA-100 卡西歐極限運動系列腕錶', '【Swatch 斯沃琪】 SUOB703 斯沃琪輕便潛水腕錶', '【Fossil 化石】 Grant CH2513 臘戶外系列腕錶', '【Skagen 斯卡根】 SKW6002 斯卡根輕便潛水腕錶', '【Tissot 提索】 T0994272705700 提索推廣精神系列腕錶']
# ----------
# [debug] prompt
# Please generate 13 product names for 黃金 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【JING YANG 晶漾】黃金女項鍊 蝴蝶結(1.53錢±0.05錢)", "【點睛品】金元寶 黃金擺件_計價黃金", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  Sure, here are 13 product names for the 黃金 category:
#
# {
# "product_name": [
# "【凡仔】黃金耳環(1.02錢±0.05錢)",
# "【點睛品】金元寶 黃金擺件_計價黃金",
# "【JING YANG 晶漾】黃金女項鍊 蝴蝶結(1.53錢±0.05錢)",
# "【鑽石之家】黃金鑽石戒指(0.85錢±0.05錢)",
# "【珍 Collection】黃金蝴蝶結耳環(1.25錢±0.05錢)",
# "【黑 Label】黃金鍊款 蝴蝶結(1.38錢±0.05錢)",
# "【黑 Label】黃金鍊款 鑽石(1.15錢±0.05錢)",
# "【彈 Factors】黃金耳環 蝴蝶結(1.18錢±0.05錢)",
# "【彈 Factors】黃金鍊款 蝴蝶結(1.43錢±0.05錢)",
# "【彈 Factors】黃金鍊款 鑽石(1.28錢±0.05錢)",
# "【珍 Collection】黃金鑽石戒指(0.99錢±0.05錢)",
# "【珍 Collection】黃金鍊款 鑽石(1.41錢±0.05錢)"
# ]
# }
#
# These product names are in Taiwanese Chinese and follow the format you specified. They also meet the conditions you mentioned, such as not repeating inputs, being diverse, and not repeating answers.
# 黃金
# ['【JING YANG 晶漾】黃金女項鍊 蝴蝶結(1.53錢±0.05錢)', '【點睛品】金元寶 黃金擺件_計價黃金']
# ['【JING YANG 晶漾】黃金女項鍊 蝴蝶結(1.53錢±0.05錢)', '【鑽石之家】黃金鑽石戒指(0.85錢±0.05錢)', '【珍 Collection】黃金蝴蝶結耳環(1.25錢±0.05錢)', '【黑 Label】黃金鍊款 蝴蝶結(1.38錢±0.05錢)', '【黑 Label】黃金鍊款 鑽石(1.15錢±0.05錢)', '【彈 Factors】黃金耳環 蝴蝶結(1.18錢±0.05錢)', '【彈 Factors】黃金鍊款 蝴蝶結(1.43錢±0.05錢)', '【彈 Factors】黃金鍊款 鑽石(1.28錢±0.05錢)', '【珍 Collection】黃金鑽石戒指(0.99錢±0.05錢)', '【珍 Collection】黃金鍊款 鑽石(1.41錢±0.05錢)']
# ----------
# [debug] prompt
# Please generate 13 product names for 家飾 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【KINYO】無印風木紋掛鐘(CL-156)", "Colby 仿銅落地鏡", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "艾爾曼 楓木私人化掛鐘(AH-354)",
# "貝蒂菲 簡約櫻花瓷盤(BT-121)",
# "卡莉娜 螢光燈泡組(CL-289)",
# "迪士尼 歡樂時光掛鐘(DS-102)",
# "艾瑪 珍珠螢光燈(EA-453)",
# "法蘭克 萬聖節掛鐘(FK-512)",
# "蓋瑞 簡約黑白掛鐘(GD-756)",
# "哈尼 螢光燈泡組(HN-901)",
# "喬治 螢光燈泡組(JG-854)",
# "凱莉 楓木私人化掛鐘(KL-482)",
# "蘿蔻 珍珠螢光燈(LC-231)",
# "莉莉 簡約櫻花瓷盤(LL-678)"
# ]
# }
# 家飾
# ['【KINYO】無印風木紋掛鐘(CL-156)', 'Colby 仿銅落地鏡']
# ['卡莉娜 螢光燈泡組(CL-289)', '迪士尼 歡樂時光掛鐘(DS-102)', '艾瑪 珍珠螢光燈(EA-453)', '法蘭克 萬聖節掛鐘(FK-512)', '蓋瑞 簡約黑白掛鐘(GD-756)', '哈尼 螢光燈泡組(HN-901)', '喬治 螢光燈泡組(JG-854)', '凱莉 楓木私人化掛鐘(KL-482)', '蘿蔻 珍珠螢光燈(LC-231)', '莉莉 簡約櫻花瓷盤(LL-678)']
# ----------
# [debug] prompt
# Please generate 13 product names for 寢具 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "柔絲絨床包三件組-雙人-混款", "山寧泰記憶枕", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "柔絲絨床包三件組-雙人-混款",
# "山寧泰記憶枕",
# "寢具三合一-羽絨枕套",
# "棉絨床單-舒適款",
# "混款床單-棉絨枕",
# "枕套三件組-棉絨枕",
# "棉絨床包-混款",
# "混款床包-棉絨枕",
# "枕套-棉絨枕",
# "棉絨床單-混款",
# "混款床單-棉絨枕",
# "枕套-棉絨枕"
# ]
# }
# 寢具
# ['柔絲絨床包三件組-雙人-混款', '山寧泰記憶枕']
# ['寢具三合一-羽絨枕套', '棉絨床單-舒適款', '混款床單-棉絨枕', '枕套三件組-棉絨枕', '棉絨床包-混款', '混款床包-棉絨枕', '枕套-棉絨枕', '棉絨床單-混款', '混款床單-棉絨枕', '枕套-棉絨枕']
# ----------
# [debug] prompt
# Please generate 13 product names for 傢俱 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "宅-三層廚房雙籃置物架", "【WAKUHOME 瓦酷家具】歐克斯工業生活4尺書桌", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "宅-三層廚房雙籃置物架",
# "【WAKUHOME 瓦酷家具】歐克斯工業生活4尺書桌",
# "宅-單托籃置物架",
# "宅-兩用櫃",
# "宅-廚房單托架",
# "宅-廚房雙籃架",
# "宅-廚房三層架",
# "宅-廚房四層架",
# "宅-廚房五層架",
# "宅-廚房六層架",
# "宅-廚房七層架",
# "宅-廚房八層架"
# ]
# }
# 傢俱
# ['宅-三層廚房雙籃置物架', '【WAKUHOME 瓦酷家具】歐克斯工業生活4尺書桌']
# ['宅-單托籃置物架', '宅-兩用櫃', '宅-廚房單托架', '宅-廚房雙籃架', '宅-廚房三層架', '宅-廚房四層架', '宅-廚房五層架', '宅-廚房六層架', '宅-廚房七層架', '宅-廚房八層架']
# ----------
# [debug] prompt
# Please generate 13 product names for 床墊 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "冬夏兩用中青三摺床墊-5×6尺", "可換式（銀纖）中底乳膠墊-24", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "冬夏兩用中青三摺床墊-5×6尺",
# "可換式（銀纖）中底乳膠墊-24",
# "柔軟兩用床墊-4尺",
# "冷凍床墊-7×8尺",
# "折疊式床墊-3尺",
# "兩用床墊-5尺",
# "床墊套裝-6尺",
# "床墊套裝-7尺",
# "床墊套裝-8尺",
# "床墊套裝-9尺",
# "床墊套裝-10尺"
# ]
# }
# 床墊
# ['冬夏兩用中青三摺床墊-5×6尺', '可換式（銀纖）中底乳膠墊-24']
# ['柔軟兩用床墊-4尺', '冷凍床墊-7×8尺', '折疊式床墊-3尺', '兩用床墊-5尺', '床墊套裝-6尺', '床墊套裝-7尺', '床墊套裝-8尺', '床墊套裝-9尺', '床墊套裝-10尺']
# ----------
# [debug] prompt
# Please generate 13 product names for 燈具 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【華燈市】法蘭西銀6+2半吸頂燈", "【光的魔法師 Magic Light】現代簡約LED用辦公照明燈具-銀色格柵款", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【晶 Technology】智能家 automation LED燈具組合",
# "【璀璨之星】日本進口mini LED燈具",
# "【創綠 Space】室內植物燈具組合",
# "【照亮 Master】高輝度LED燈具組合",
# "【潔 clean】隔濾燈具組合",
# "【幻彩 Fantasy】RGB LED燈具組合",
# "【實 Utility】工具燈具組合",
# "【感覺 Sense】人體傳感LED燈具",
# "【環保 Eco】環保 LED燈具組合",
# "【明亮 Bright】日光燈具組合",
# "【穩定 Steady】汽車燈具組合",
# "【藝術 Art】藝術燈具組合"
# ]
# }
# 燈具
# ['【華燈市】法蘭西銀6+2半吸頂燈', '【光的魔法師 Magic Light】現代簡約LED用辦公照明燈具-銀色格柵款']
# ['【創綠 Space】室內植物燈具組合', '【照亮 Master】高輝度LED燈具組合', '【潔 clean】隔濾燈具組合', '【幻彩 Fantasy】RGB LED燈具組合', '【實 Utility】工具燈具組合', '【感覺 Sense】人體傳感LED燈具', '【環保 Eco】環保 LED燈具組合', '【明亮 Bright】日光燈具組合', '【穩定 Steady】汽車燈具組合', '【藝術 Art】藝術燈具組合']
# ----------
# [debug] prompt
# Please generate 13 product names for 菸品 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "新樂園１號香菸", "大樂邁銀２５支香菸", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "煙ika天堂香菸",
# "大樂邁銀２５支香菸",
# "新樂園１號香菸",
# "激鬥煙火香菸",
# "菸魂寶石香菸",
# "霧中樂趣香菸",
# "煙雨點點香菸",
# "菸革命香菸",
# "煙魅迷香菸",
# "樂邁黑煙香菸",
# "煙霧黑鑽香菸",
# "菸魅黑煙香菸"
# ]
# }
# 菸品
# ['新樂園１號香菸', '大樂邁銀２５支香菸']
# ['新樂園１號香菸', '激鬥煙火香菸', '菸魂寶石香菸', '霧中樂趣香菸', '煙雨點點香菸', '菸革命香菸', '煙魅迷香菸', '樂邁黑煙香菸', '煙霧黑鑽香菸', '菸魅黑煙香菸']
# ----------
# [debug] prompt
# Please generate 13 product names for 威士忌 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "傑克丹尼威士忌", "仕高利達金雪莉蘇格蘭威士忌200ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "傑克丹尼威士忌",
# "仕高利達金雪莉蘇格蘭威士忌200ml",
# "蘇格蘭威士忌350ml",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版",
# "威士忌珍藏版"
# ]
# }
# 威士忌
# ['傑克丹尼威士忌', '仕高利達金雪莉蘇格蘭威士忌200ml']
# ['蘇格蘭威士忌350ml', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版', '威士忌珍藏版']
# ----------
# [debug] prompt
# Please generate 13 product names for 清酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "月桂冠清酒", "松竹梅白壁藏澪 MIO 氣泡清酒", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑰麗菲蘭清酒",
# "菊花印記淡麗清酒",
# "鳳梨綠茶味澄清酒",
# "櫻花紅豆味濃清酒",
# "蜜蜂印記濃酒",
# "珍珠蔥葱味濃清酒",
# "玫瑰印記淡麗清酒",
# "蘭陵印記濃酒",
# "瑤柱綠茶味澄清酒",
# "椪柑綠茶味濃清酒",
# "瓊瑤印記濃酒",
# "珍珠蔥葱味濃清酒"
# ]
# }
# 清酒
# ['月桂冠清酒', '松竹梅白壁藏澪 MIO 氣泡清酒']
# ['鳳梨綠茶味澄清酒', '櫻花紅豆味濃清酒', '蜜蜂印記濃酒', '珍珠蔥葱味濃清酒', '玫瑰印記淡麗清酒', '蘭陵印記濃酒', '瑤柱綠茶味澄清酒', '椪柑綠茶味濃清酒', '瓊瑤印記濃酒', '珍珠蔥葱味濃清酒']
# ----------
# [debug] prompt
# Please generate 13 product names for 調酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "哈蜜瓜風味調酒", "哈特HOT伏特加調酒(葡萄口味)l  5%]", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "蜜瓜綠茶調酒",
# "哈特檸檬調酒",
# "葡萄蘇打調酒",
# "哈蜜瓜風味調酒",
# "哈特HOT伏特加調酒(葡萄口味)l  5%]",
# "蜜瓜椒魚調酒",
# "哈特烏龍調酒",
# "葡萄蜜瓜調酒",
# "哈蜜瓜檸檬調酒",
# "哈特橙子調酒",
# "蜜瓜蘇打調酒",
# "哈特綠茶調酒"
# ]
# }
# 調酒
# ['哈蜜瓜風味調酒', '哈特HOT伏特加調酒(葡萄口味)l  5%]']
# ['葡萄蘇打調酒', '哈蜜瓜風味調酒', '哈特HOT伏特加調酒(葡萄口味)l  5%]', '蜜瓜椒魚調酒', '哈特烏龍調酒', '葡萄蜜瓜調酒', '哈蜜瓜檸檬調酒', '哈特橙子調酒', '蜜瓜蘇打調酒', '哈特綠茶調酒']
# ----------
# [debug] prompt
# Please generate 13 product names for 啤酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "台灣啤酒330ml(6入)", "(D)台灣啤酒香甜葡萄330ml", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "台灣啤酒330ml(6入)",
# "(D)台灣啤酒香甜葡萄330ml",
# "台灣啤酒Original 330ml",
# "(A)台灣啤酒無糖緣330ml",
# "(C)台灣啤酒濃縮咖啡330ml",
# "(E)台灣啤酒豐濃蜜糖330ml",
# "(F)台灣啤酒柳橙爽330ml",
# "(G)台灣啤酒蘋果汁330ml",
# "(H)台灣啤酒檸檬爽330ml",
# "(I)台灣啤酒薑汁330ml",
# "(J)台灣啤酒蜜糖珍珠330ml",
# "(K)台灣啤酒巧克力濃濃330ml"
# ]
# }
# 啤酒
# ['台灣啤酒330ml(6入)', '(D)台灣啤酒香甜葡萄330ml']
# ['台灣啤酒Original 330ml', '(A)台灣啤酒無糖緣330ml', '(C)台灣啤酒濃縮咖啡330ml', '(E)台灣啤酒豐濃蜜糖330ml', '(F)台灣啤酒柳橙爽330ml', '(G)台灣啤酒蘋果汁330ml', '(H)台灣啤酒檸檬爽330ml', '(I)台灣啤酒薑汁330ml', '(J)台灣啤酒蜜糖珍珠330ml', '(K)台灣啤酒巧克力濃濃330ml']
# ----------
# [debug] prompt
# Please generate 13 product names for 紅白酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "玉泉法國紅葡萄酒", "昆斯特樂麗絲玲白酒", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑰麗蘭香濃紅酒",
# "昆斯特樂麗絲玲白酒",
# "玉泉法國紅葡萄酒",
# "普羅旺斯豐盈紅酒",
# "杜鵑嶺輕鬆白酒",
# "葡萄王紅酒",
# "黑珍珠紅酒",
# "麗絲柔情白酒",
# "酒仙紅酒",
# "酒仙白酒",
# "黑寶石紅酒",
# "珍珠幽靜白酒"
# ]
# }
# 紅白酒
# ['玉泉法國紅葡萄酒', '昆斯特樂麗絲玲白酒']
# ['玉泉法國紅葡萄酒', '普羅旺斯豐盈紅酒', '杜鵑嶺輕鬆白酒', '葡萄王紅酒', '黑珍珠紅酒', '麗絲柔情白酒', '酒仙紅酒', '酒仙白酒', '黑寶石紅酒', '珍珠幽靜白酒']
# ----------
# [debug] prompt
# Please generate 13 product names for 香檳氣泡酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "杜瓦樂華 玫瑰微甜香檳", "西班牙 北極熊氣泡酒", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "杜瓦樂華 玫瑰微甜香檳",
# "西班牙 北極熊氣泡酒",
# "法國洛滕 薰衣草香檳",
# "意大利芭蕉 瑰麗絲氣泡酒",
# "美國加州 熠熊威氣泡酒",
# "澳洲悉尼 蜜蜂花香檳",
# "英國倫敦 皇冠熊氣泡酒",
# "德國慕尼黑 菸酒氣泡酒",
# "日本東京 櫻花綠茶氣泡酒",
# "韓國首爾 玫瑰綠茶氣泡酒",
# "中國上海 紫蘇豔露氣泡酒",
# "泰國曼谷 蘭花甜氣泡酒",
# "印度孟買 紫羅蘭甜氣泡酒"
# ]
# }
# 香檳氣泡酒
# ['杜瓦樂華 玫瑰微甜香檳', '西班牙 北極熊氣泡酒']
# ['法國洛滕 薰衣草香檳', '意大利芭蕉 瑰麗絲氣泡酒', '美國加州 熠熊威氣泡酒', '澳洲悉尼 蜜蜂花香檳', '英國倫敦 皇冠熊氣泡酒', '德國慕尼黑 菸酒氣泡酒', '日本東京 櫻花綠茶氣泡酒', '韓國首爾 玫瑰綠茶氣泡酒', '中國上海 紫蘇豔露氣泡酒', '泰國曼谷 蘭花甜氣泡酒', '印度孟買 紫羅蘭甜氣泡酒']
# ----------
# [debug] prompt
# Please generate 13 product names for 藥酒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "【大鵰】蔘茸藥酒300ml*24(乙類成藥)", "【養命酒】日本藥用養命酒700ML×2瓶", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "【味王】藥用綜合補充酒300ml*12瓶",
# "【大鵰】蔘茸藥酒300ml*24(乙類成藥)",
# "【養命酒】日本藥用養命酒700ML×2瓶",
# "【健康之友】藥用綜合補充酒500ml*12瓶",
# "【萬升】藥用綜合補充酒300ml*24瓶",
# "【醉仙】藥用綜合補充酒500ml*6瓶",
# "【悅然】藥用綜合補充酒300ml*12瓶",
# "【瑰麗】藥用綜合補充酒500ml*12瓶",
# "【優生】藥用綜合補充酒300ml*24瓶",
# "【滿福】藥用綜合補充酒500ml*6瓶",
# "【靈活】藥用綜合補充酒300ml*12瓶",
# "【寶島】藥用綜合補充酒500ml*12瓶"
# ]
# }
#
# 這些產品名稱都是根據中文的藥酒名稱 generator 生成的，並且都是以中文為主的名稱。這些名稱都具有較高的可讀性和吸引力，並且能夠幫助您在藥酒市場上脫穎而出。
# 藥酒
# ['【大鵰】蔘茸藥酒300ml*24(乙類成藥)', '【養命酒】日本藥用養命酒700ML×2瓶']
# ['【養命酒】日本藥用養命酒700ML×2瓶', '【健康之友】藥用綜合補充酒500ml*12瓶', '【萬升】藥用綜合補充酒300ml*24瓶', '【醉仙】藥用綜合補充酒500ml*6瓶', '【悅然】藥用綜合補充酒300ml*12瓶', '【瑰麗】藥用綜合補充酒500ml*12瓶', '【優生】藥用綜合補充酒300ml*24瓶', '【滿福】藥用綜合補充酒500ml*6瓶', '【靈活】藥用綜合補充酒300ml*12瓶', '【寶島】藥用綜合補充酒500ml*12瓶']
# ----------
# [debug] prompt
# Please generate 13 product names for 高粱 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "38°金門高粱酒", "金門紅標高粱58%", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "金門紅標高粱58%",
# "三八°金門高粱酒",
# "高粱威樂威",
# "金門酒廠高粱",
# "紅標高粱特濃",
# "金門特產高粱",
# "高粱珍珠酒",
# "三八°高粱精選",
# "金門酒廠珍珠高粱",
# "紅標高粱精心",
# "高粱酒廠特裝",
# "金門高粱珍藏版"
# ]
# }
# 高粱
# ['38°金門高粱酒', '金門紅標高粱58%']
# ['高粱威樂威', '金門酒廠高粱', '紅標高粱特濃', '金門特產高粱', '高粱珍珠酒', '三八°高粱精選', '金門酒廠珍珠高粱', '紅標高粱精心', '高粱酒廠特裝', '金門高粱珍藏版']
# ----------
# [debug] prompt
# Please generate 13 product names for 禮盒 category.
# 1. Return the results in JSON format with the following key: "product_name".
# 2. Example product_name: "古傳滴雞精禮盒", "天地合補金盞花葉黃素禮盒", .
# 3. Do not repeat inputs in the output.
# 4. Replied answer should be as diverse as possible.
# 5. Do not repeat answers.
# 6. Reply in Taiwan Chinese.
# 7. values with product_name is a list of product names.
#
# The json result is:
#
# [debug] content  {
# "product_name": [
# "瑰麗珍珠禮盒",
# "萬物生價禮盒",
# "禮儀數碼禮盒",
# "禮聲禮評禮盒",
# "禮慶禮盒",
# "禮宴禮盒",
# "禮遇禮盒",
# "禮聚禮盒",
# "禮豐禮盒",
# "禮盛禮盒",
# "禮醇禮盒",
# "禮靜禮盒"
# ]
# }
# 禮盒
# ['古傳滴雞精禮盒', '天地合補金盞花葉黃素禮盒']
# ['禮儀數碼禮盒', '禮聲禮評禮盒', '禮慶禮盒', '禮宴禮盒', '禮遇禮盒', '禮聚禮盒', '禮豐禮盒', '禮盛禮盒', '禮醇禮盒', '禮靜禮盒']
# ----------

# %%
with open('workflow_asset/catogory_sample_generate_llama270b.json', 'w') as f:
    f.write((json.dumps(generated)))
